# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Imports" data-toc-modified-id="Imports-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imports</a></span></li><li><span><a href="#Samstein-et-all" data-toc-modified-id="Samstein-et-all-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Samstein et all</a></span><ul class="toc-item"><li><span><a href="#Surival-Analysis" data-toc-modified-id="Surival-Analysis-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Surival Analysis</a></span><ul class="toc-item"><li><span><a href="#by-TMB-DDR-mutations" data-toc-modified-id="by-TMB-DDR-mutations-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>by TMB DDR mutations</a></span></li><li><span><a href="#Low-Big_BETS-DDR-Mutations" data-toc-modified-id="Low-Big_BETS-DDR-Mutations-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Low Big_BETS DDR Mutations</a></span></li><li><span><a href="#High-Big_BETS-DDR-Mutations" data-toc-modified-id="High-Big_BETS-DDR-Mutations-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>High Big_BETS DDR Mutations</a></span></li><li><span><a href="#Histone-modification-Genes" data-toc-modified-id="Histone-modification-Genes-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Histone modification Genes</a></span></li><li><span><a href="#Chromatin-Remodelling-genes" data-toc-modified-id="Chromatin-Remodelling-genes-2.1.5"><span class="toc-item-num">2.1.5&nbsp;&nbsp;</span>Chromatin Remodelling genes</a></span></li></ul></li></ul></li><li><span><a href="#IMVigor210" data-toc-modified-id="IMVigor210-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>IMVigor210</a></span><ul class="toc-item"><li><span><a href="#Surival-Analysis" data-toc-modified-id="Surival-Analysis-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Surival Analysis</a></span><ul class="toc-item"><li><span><a href="#Survival-by-TMB" data-toc-modified-id="Survival-by-TMB-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Survival by TMB</a></span></li><li><span><a href="#Low-Big_BETS-DDR-Mutations" data-toc-modified-id="Low-Big_BETS-DDR-Mutations-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Low Big_BETS DDR Mutations</a></span></li><li><span><a href="#High-Big_BETS-DDR-Mutations" data-toc-modified-id="High-Big_BETS-DDR-Mutations-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>High Big_BETS DDR Mutations</a></span></li><li><span><a href="#Chromatin-Remodelling-genes" data-toc-modified-id="Chromatin-Remodelling-genes-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>Chromatin Remodelling genes</a></span></li></ul></li><li><span><a href="#ICB-Response-Analyses" data-toc-modified-id="ICB-Response-Analyses-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>ICB Response Analyses</a></span><ul class="toc-item"><li><span><a href="#Response-TMB-only" data-toc-modified-id="Response-TMB-only-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Response TMB only</a></span></li><li><span><a href="#by-low-BiGBETS-DDR" data-toc-modified-id="by-low-BiGBETS-DDR-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>by low BiGBETS DDR</a></span><ul class="toc-item"><li><span><a href="#ICB-response-by-low-chromatin-genes-IMVIGOR" data-toc-modified-id="ICB-response-by-low-chromatin-genes-IMVIGOR-3.2.2.1"><span class="toc-item-num">3.2.2.1&nbsp;&nbsp;</span>ICB response by low chromatin genes IMVIGOR</a></span></li></ul></li></ul></li><li><span><a href="#Gene-signatures-analysis" data-toc-modified-id="Gene-signatures-analysis-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Gene signatures analysis</a></span><ul class="toc-item"><li><span><a href="#Gene-signatures-for-Low-BIG-BETS-DDR-genes" data-toc-modified-id="Gene-signatures-for-Low-BIG-BETS-DDR-genes-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Gene signatures for Low BIG-BETS DDR genes</a></span></li><li><span><a href="#Genes-signatures-for-low-chromatin-remodeling-genes" data-toc-modified-id="Genes-signatures-for-low-chromatin-remodeling-genes-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Genes signatures for low chromatin remodeling genes</a></span></li></ul></li><li><span><a href="#Overlap-of-DDR-genes-Samstein-and-IMVigor" data-toc-modified-id="Overlap-of-DDR-genes-Samstein-and-IMVigor-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Overlap of DDR genes Samstein and IMVigor</a></span><ul class="toc-item"><li><span><a href="#Samstein-Surival-with-Overlap-DDR-Genes" data-toc-modified-id="Samstein-Surival-with-Overlap-DDR-Genes-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Samstein Surival with Overlap DDR Genes</a></span></li></ul></li></ul></li><li><span><a href="#Weir-et-al-Meta-dataset" data-toc-modified-id="Weir-et-al-Meta-dataset-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Weir et al Meta-dataset</a></span><ul class="toc-item"><li><span><a href="#Surival-Analysis" data-toc-modified-id="Surival-Analysis-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Surival Analysis</a></span><ul class="toc-item"><li><span><a href="#Low-Big_BETS-DDR-Mutations" data-toc-modified-id="Low-Big_BETS-DDR-Mutations-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Low Big_BETS DDR Mutations</a></span></li><li><span><a href="#High-Big_BETS-DDR-Mutations" data-toc-modified-id="High-Big_BETS-DDR-Mutations-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>High Big_BETS DDR Mutations</a></span></li></ul></li><li><span><a href="#ICB-Response-Analyses" data-toc-modified-id="ICB-Response-Analyses-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>ICB Response Analyses</a></span></li></ul></li><li><span><a href="#Tumor-Specific-Survival-(Combined-Weir-meta,-Samstein,-IMVigor)" data-toc-modified-id="Tumor-Specific-Survival-(Combined-Weir-meta,-Samstein,-IMVigor)-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Tumor Specific Survival (Combined Weir-meta, Samstein, IMVigor)</a></span></li><li><span><a href="#TCGA-Survival-and-Gene-Signatures" data-toc-modified-id="TCGA-Survival-and-Gene-Signatures-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>TCGA Survival and Gene Signatures</a></span><ul class="toc-item"><li><span><a href="#Survival-analysis-by-Big-BET-mutations-TCGA" data-toc-modified-id="Survival-analysis-by-Big-BET-mutations-TCGA-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Survival analysis by Big-BET mutations TCGA</a></span><ul class="toc-item"><li><span><a href="#Low-Big-BETS-DDR" data-toc-modified-id="Low-Big-BETS-DDR-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Low Big-BETS DDR</a></span><ul class="toc-item"><li><span><a href="#All-cancer-types" data-toc-modified-id="All-cancer-types-6.1.1.1"><span class="toc-item-num">6.1.1.1&nbsp;&nbsp;</span>All cancer types</a></span></li><li><span><a href="#Types-to-match-samstein" data-toc-modified-id="Types-to-match-samstein-6.1.1.2"><span class="toc-item-num">6.1.1.2&nbsp;&nbsp;</span>Types to match samstein</a></span></li><li><span><a href="#broken-out-by-individual-cancer-types" data-toc-modified-id="broken-out-by-individual-cancer-types-6.1.1.3"><span class="toc-item-num">6.1.1.3&nbsp;&nbsp;</span>broken out by individual cancer types</a></span></li></ul></li><li><span><a href="#High-BiG-BETS-DDR-TCGA-Survival" data-toc-modified-id="High-BiG-BETS-DDR-TCGA-Survival-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>High BiG-BETS DDR TCGA Survival</a></span></li></ul></li><li><span><a href="#immune-signatures-analysis" data-toc-modified-id="immune-signatures-analysis-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>immune signatures analysis</a></span><ul class="toc-item"><li><span><a href="#All-tumor-types" data-toc-modified-id="All-tumor-types-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>All tumor types</a></span></li><li><span><a href="#Filtered-to-match-samstein" data-toc-modified-id="Filtered-to-match-samstein-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>Filtered to match samstein</a></span></li><li><span><a href="#BLCA-only" data-toc-modified-id="BLCA-only-6.2.3"><span class="toc-item-num">6.2.3&nbsp;&nbsp;</span>BLCA only</a></span></li></ul></li></ul></li><li><span><a href="#Other-datasets" data-toc-modified-id="Other-datasets-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Other datasets</a></span><ul class="toc-item"><li><span><a href="#Braun-et-all-2020-RCC-dataset" data-toc-modified-id="Braun-et-all-2020-RCC-dataset-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Braun et all 2020 RCC dataset</a></span><ul class="toc-item"><li><span><a href="#Survival-Analyses" data-toc-modified-id="Survival-Analyses-7.1.1"><span class="toc-item-num">7.1.1&nbsp;&nbsp;</span>Survival Analyses</a></span><ul class="toc-item"><li><span><a href="#Low-Big_BETS-DDR-Mutations" data-toc-modified-id="Low-Big_BETS-DDR-Mutations-7.1.1.1"><span class="toc-item-num">7.1.1.1&nbsp;&nbsp;</span>Low Big_BETS DDR Mutations</a></span></li><li><span><a href="#High-Big_BETS-DDR-Mutations" data-toc-modified-id="High-Big_BETS-DDR-Mutations-7.1.1.2"><span class="toc-item-num">7.1.1.2&nbsp;&nbsp;</span>High Big_BETS DDR Mutations</a></span></li></ul></li></ul></li><li><span><a href="#ICB-Response-Analyses" data-toc-modified-id="ICB-Response-Analyses-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>ICB Response Analyses</a></span></li><li><span><a href="#Miao-et-al-2018-MSS-tumors-dataset" data-toc-modified-id="Miao-et-al-2018-MSS-tumors-dataset-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Miao et al 2018 MSS tumors dataset</a></span><ul class="toc-item"><li><span><a href="#Survival-Analyses" data-toc-modified-id="Survival-Analyses-7.3.1"><span class="toc-item-num">7.3.1&nbsp;&nbsp;</span>Survival Analyses</a></span><ul class="toc-item"><li><span><a href="#Low-Big_BETS-DDR-Mutations" data-toc-modified-id="Low-Big_BETS-DDR-Mutations-7.3.1.1"><span class="toc-item-num">7.3.1.1&nbsp;&nbsp;</span>Low Big_BETS DDR Mutations</a></span></li></ul></li><li><span><a href="#High-Big_BETS-DDR-Mutations" data-toc-modified-id="High-Big_BETS-DDR-Mutations-7.3.2"><span class="toc-item-num">7.3.2&nbsp;&nbsp;</span>High Big_BETS DDR Mutations</a></span></li></ul></li><li><span><a href="#ICB-Response-Analyses" data-toc-modified-id="ICB-Response-Analyses-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>ICB Response Analyses</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Imports

# %%
import os,sys,re
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.patches as patches
import matplotlib.lines as lines
import matplotlib.image as mpimg
import matplotlib.colors as mc
import matplotlib as mpl

mpl.rcParams['pdf.fonttype'] = 42
mpl.rc('font', family='sans-serif') 
mpl.rcParams['font.sans-serif']=['Arial']


mpl.rc('xtick',labelsize=18)
mpl.rc('ytick',labelsize=18)

import matplotlib_venn as venn

import numpy as np
import scipy.stats as stats
import pandas as pd
import seaborn as sbn

sys.path.insert(0,"..")
import bigbets
import lifelines

red=(200/255,58/255,52/255)
blue=(58/255,71/255,133/255)

dropdir="/Users/whweir/Dropbox/2020_Weir_TMB/CellRepMed Submission/R1_CellRepMed"
graphics_dir=os.path.join(dropdir,"updated_figures/")
supplements_dir=os.path.join(graphics_dir,"supplement_updated")

# %% [markdown]
# # Samstein et all

# %%
samstein=bigbets.SamsteinData()
# Out:
# 2021-12-21 19:43:06,637:root:INFO:Loading Samstein clinical data
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: DtypeWarning: Columns (47,85) have mixed types.Specify dtype option on import or set low_memory=False.
#   """Entry point for launching an IPython kernel.
# querying 1-469...done.
# Finished.
# 29 input query terms found no hit:
# 	['PARK2', 'HIST1H1C', 'FAM46C', 'HIST1H3B', 'HIST1H3A', 'FAM175A', 'RFWD2', 'PAK7', 'WHSC1L1', 'WHSC
# querying 1-29...done.
# Finished.
# 3 input query terms found dup hits:
# 	[('PARK2', 4), ('WHSC1L1', 2), ('HIST1H2BD', 2)]
# 2 input query terms found no hit:
# 	['RP11-145E5.5', 'RP11-211G3.3']
# 2021-12-21 19:43:11,132:root:INFO:Loading Samstein clinical data
# ../bigbets/load_clinical_datasets.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# ## Surival Analysis

# %% [markdown]
# ### by TMB DDR mutations

# %%
#by TMB genes survival analysis
outfile=os.path.join(supplements_dir,'R1_Figure_S4A_samstein_survival_low_zscore.pdf')

cph = lifelines.CoxPHFitter()
# vars2keep=['high_TMB','DDR','DDR:highTMB']
vars2keep=['DDR']

dummy_df=samstein.clinical_bigbets_df.loc[:,['os','censOS']]

for var in vars2keep:
    cdf=pd.get_dummies(samstein.clinical_bigbets_df.loc[:,var])
    cdf.columns=map(lambda x: var+"_"+str(x),cdf.columns.values)
    dummy_df=pd.concat([dummy_df,cdf.iloc[:,:-1]],axis=1)

dummy_df['log(TMB)']=np.log1p(samstein.clinical_bigbets_df.loc[:,'TMB'])
# dummy_df['TMB']=samstein.clinical_bigbets_df.loc[:,'high_TMB']


res=cph.fit(dummy_df, 'os', event_col='censOS')
llrstat=cph.log_likelihood_ratio_test()
llr=llrstat.test_statistic
df=llrstat.degrees_freedom
p_value=llrstat.p_value
summary=res.summary
print(res.summary)

var='high_TMB'



coms=samstein.clinical_bigbets_df[var].unique()
commap=dict(zip(coms,range(len(coms))))
clust=list(map(lambda x: commap[x],samstein.clinical_bigbets_df[var]))

plt.close()
f,a=plt.subplots(1,2,figsize=(7.5,10))

nrows=10
ncols=1

ncols1=1
nrows1=6

a=plt.subplot2grid((nrows,ncols),(0,0),rowspan=nrows1,colspan=1)

cols = [red + (1.0,), blue + (1.0,)]

kmf = lifelines.KaplanMeierFitter()
df2test=samstein.clinical_bigbets_df
i=0
for name,gdf in df2test.groupby(var):
    if re.search("WT",name):
        ls=':'
    else:
        ls='-'
    kmf.fit(gdf["os"], gdf["censOS"], label=name)
    kmf.plot(ax=a,ci_show=False,c=cols[i],linestyle=ls,
             show_censors=True, censor_styles={'ms': 5, 'marker': '+'})
    i+=1
# lg_lines=lg.get_lines()
# for j,ln in enumerate(a.get_lines()):
#     ln.set_color(cols[j])
#     lg_lines[j].set_color(cols[j])

handles, labels = a.get_legend_handles_labels()
new_labels=['TMB-H','TMB-L']
l=a.legend(loc=1,bbox_to_anchor=(.85,1.0),fontsize=14,
           frameon=False,handles=handles,labels=new_labels)
for i,text in enumerate(l.get_texts()):
    plt.setp(text, color = cols[i])
    
# a.annotate(s='TMB-H',fontsize=14,xy=(.83,.925),xytext=(.86,.925),
#        arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
#        xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

# a.annotate(s='TMB-L',fontsize=14,xy=(.83,.825),xytext=(.86,.825),
#        arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
#        xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

a.set_xlabel("months",fontsize=20)
a.set_ylabel("overall survival",fontsize=20)

# a.set_title("Kaplan-Meier Curve by TMB + low TMB Assoc.DDR Genes",fontsize=18,fontweight='bold')
pval_df=bigbets.bipartite_helper_functions.get_os_stats(clust=clust,samp_df=samstein.clinical_bigbets_df)
pval=pval_df['llr_pval'].values[0]
a.text(x=.85,y=.75,s="CPH pval={:.1e}".format(pval),horizontalalignment='center',
       fontsize=14,transform=a.transAxes)



a=plt.subplot2grid((nrows,ncols),(nrows1,0),rowspan=nrows-nrows1,colspan=1)
# a=plt.subplot(1,2,2)
# a.text(s='B)',fontsize=18,fontweight='bold',x=0.0,y=.95,transform=a.transAxes)
# a.text(s='B)',fontsize=18,fontweight='bold',x=-.07,y=1.0,transform=a.transAxes)

xlim_min=np.min(summary['coef']-1.96*summary['se(coef)'])
xlim_max=np.max(summary['coef']+1.96*summary['se(coef)'])

for i,ind in enumerate(summary.index):
    expcoef=summary.loc[ind,'exp(coef)']
    up=summary.loc[ind,'exp(coef) upper 95%']-expcoef
    low=expcoef-summary.loc[ind,'exp(coef) lower 95%']
    ebars=np.array([[low,up]]).T
    a.errorbar(x=[expcoef],alpha=.7,
               y=[summary.shape[0]-1-i],marker='s',color='k',uplims=True, lolims=True,
               xerr=ebars
#                xerr=[1.96*summary.loc[ind,'se(coef)'],
                    )

    
a.vlines(x=1.0,linestyle='--',alpha=.6,linewidth=1,color='k',
         ymin=0,ymax=summary.shape[0]-.9)

a.set_xscale('log')
a.set_xlim([.0000025,30])
a.spines['bottom'].set_position(('data', -.4))
a.spines['bottom'].set_bounds( 0.1,5)

a.spines['left'].set_visible(False)
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)
a.set_yticks([])
a.set_xticks([.1,1,5])
a.xaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
plt.minorticks_off()
a.set_ylim([-2,3])


# a.text(s="LLR pval={:.2e}".format(p_value),fontsize=18,
#        x=.2,y=.8,transform=a.transAxes)



axis_to_data = a.transAxes + a.transData.inverted()
data_to_axis = axis_to_data.inverted()

y=data_to_axis.transform((.1,summary.shape[0]-.55))[1]

print('y',y)
a.text(s="Covariate".format(p_value),fontsize=20,
       x=.01,y=y,transform=a.transAxes)

a.text(s="HR (95% CI)".format(p_value),fontsize=20,
       x=.375,y=y,transform=a.transAxes)

a.text(s="P-value".format(p_value),fontsize=20,
       x=.85,y=y,transform=a.transAxes)

a.hlines(y=y-.02,xmin=-2,color='k',xmax=50,transform=a.transAxes,linewidth=3,linestyle='-')
# a.hlines(y=y-.03,xmin=-1,xmax=2,transform=a.transAxes,linewidth=1,linestyle='-')

for i,ind in enumerate(summary.index):
    y=data_to_axis.transform((.1,summary.shape[0]-i-1.2))[1]
    print('y',y)
    if summary.loc[ind,'p']<.05:
        a.text(s="{}*".format(ind),fontsize=20,
       x=-.1,y=y,transform=a.transAxes)
    else:
        a.text(s=ind,fontsize=20,
           x=-.1,y=y,
           transform=a.transAxes)
    hrtext="{:.2f}  ({:.2f}-{:.2f})".format(*summary.loc[ind,['exp(coef)',
                                                         'exp(coef) lower 95%','exp(coef) upper 95%']])
    pvaltext="{:.2e}".format(*summary.loc[ind,['p']])
    a.text(s=hrtext,fontsize=20,
       x=.35,y=y,
           transform=a.transAxes)
    a.text(s=pvaltext,fontsize=20,
       x=.85,y=y,
           transform=a.transAxes)
    
    x1,y1=data_to_axis.transform((.01,summary.shape[0]-i*.9-1.5))
    x2,y2=data_to_axis.transform((.01,summary.shape[0]-i*.9-.8))
    

    if i%2==0:
        crect=patches.Rectangle((-.1,y1),width=1.2,height=y2-y1,transform=a.transAxes,fill=True,
                               alpha=.05,color='k',clip_on=False)
#         crect2=patches.Rectangle((x2,y1),width=1.1-x2,height=y2-y1,transform=a.transAxes,fill=True,
#                                alpha=.05,color='k')
        a.add_patch(crect)
#         a.add_patch(crect2)
        
    
    

# a.set_title("CPH Model Survival",fontsize=18,fontweight='bold')
# cph.plot(ax=a)
a.text(s="Hazard Ratio",fontsize=18,x=1.25,
       y=-1.1,
       horizontalalignment='center')

f.suptitle('Survival by TMB (Samstein)',fontsize=22,x=.5,y=.97,transform=f.transFigure)

f.subplots_adjust(top=.93,bottom=-.05,right=.95,left=.12,wspace=.0,hspace=1.5)
f.savefig(outfile,dpi=200)
plt.show()
# Out:
#               coef  exp(coef)  se(coef)  coef lower 95%  coef upper 95%  \
# DDR_MUT  -0.129879   0.878201  0.106530       -0.338675        0.078917
# log(TMB) -0.163483   0.849181  0.051712       -0.264837       -0.062130
#
#           exp(coef) lower 95%  exp(coef) upper 95%         z         p  \
# DDR_MUT              0.712714             1.082114 -1.219174  0.222778
# log(TMB)             0.767331             0.939761 -3.161420  0.001570
#
#           -log2(p)
# DDR_MUT   2.166321
# log(TMB)  9.315001
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/lifelines/fitters/kaplan_meier_fitter.py:268: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   self.confidence_interval_ = self._bounds(cumulative_sq_[:, None], alpha, ci_labels)
# ...

# %% [markdown]
# ### Low Big_BETS DDR Mutations

# %%
#low bigbets DDR genes survival analysis
outfile=os.path.join(graphics_dir,'R1_Figure_3B_samstein_survival_low_zscore.pdf')

cph = lifelines.CoxPHFitter()
# vars2keep=['high_TMB','DDR','DDR:highTMB']
vars2keep=['DDR_low_z']

dummy_df=samstein.clinical_bigbets_df.loc[:,['os','censOS']]

for var in vars2keep:
    cdf=pd.get_dummies(samstein.clinical_bigbets_df.loc[:,var])
    cdf.columns=map(lambda x: var+"_"+str(x),cdf.columns.values)
    dummy_df=pd.concat([dummy_df,cdf.iloc[:,:-1]],axis=1)

dummy_df['log(TMB)']=np.log1p(samstein.clinical_bigbets_df.loc[:,'TMB'])
# dummy_df['TMB']=samstein.clinical_bigbets_df.loc[:,'high_TMB']

dummy_df['DDRlow:highTMB']=samstein.clinical_bigbets_df.loc[:,'DDRlowz:highTMB']

res=cph.fit(dummy_df, 'os', event_col='censOS')
llrstat=cph.log_likelihood_ratio_test()
llr=llrstat.test_statistic
df=llrstat.degrees_freedom
p_value=llrstat.p_value
summary=res.summary
print(res.summary)

var='DDR_low_z_TMB'



coms=samstein.clinical_bigbets_df[var].unique()
commap=dict(zip(coms,range(len(coms))))
clust=list(map(lambda x: commap[x],samstein.clinical_bigbets_df[var]))

plt.close()
f,a=plt.subplots(1,2,figsize=(7.5,10))

nrows=10
ncols=1

ncols1=1
nrows1=6

a=plt.subplot2grid((nrows,ncols),(0,0),rowspan=nrows1,colspan=1)

cols = [red + (1.0,), red + (.5,), blue + (1.0,), blue + (.5,)]
cols=[red+(1.0,),red+(.7,),blue+(1.0,),blue+(.7,)]

kmf = lifelines.KaplanMeierFitter()
df2test=samstein.clinical_bigbets_df
i=0
for name,gdf in df2test.groupby(var):
    if re.search("WT",name):
        ls=':'
    else:
        ls='-'
    kmf.fit(gdf["os"], gdf["censOS"], label=name)
    kmf.plot(ax=a,ci_show=False,c=cols[i],linestyle=ls,
             show_censors=True, censor_styles={'ms': 5, 'marker': '+'})
    i+=1
# lg_lines=lg.get_lines()
# for j,ln in enumerate(a.get_lines()):
#     ln.set_color(cols[j])
#     lg_lines[j].set_color(cols[j])

handles, labels = a.get_legend_handles_labels()
new_labels=['Low-BiG-BETS DDR Mut','Low-BiG-BETS DDR WT','Low-BiG-BETS DDR Mut','Low-BiG-BETS DDR WT']
l=a.legend(loc=1,bbox_to_anchor=(.85,1.0),fontsize=14,
           frameon=False,handles=handles,labels=new_labels)
for i,text in enumerate(l.get_texts()):
    plt.setp(text, color = cols[i])
    
a.annotate(s='TMB-H',fontsize=14,xy=(.83,.925),xytext=(.86,.925),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.annotate(s='TMB-L',fontsize=14,xy=(.83,.825),xytext=(.86,.825),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

a.set_xlabel("months",fontsize=20)
a.set_ylabel("overall survival",fontsize=20)

# a.set_title("Kaplan-Meier Curve by TMB + low TMB Assoc.DDR Genes",fontsize=18,fontweight='bold')
pval_df=bigbets.bipartite_helper_functions.get_os_stats(clust=clust,samp_df=samstein.clinical_bigbets_df)
pval=pval_df['llr_pval'].values[0]
a.text(x=.85,y=.05,s="CPH pval={:.1e}".format(pval),horizontalalignment='center',
       fontsize=14,transform=a.transAxes)



a=plt.subplot2grid((nrows,ncols),(nrows1,0),rowspan=nrows-nrows1,colspan=1)
# a=plt.subplot(1,2,2)
# a.text(s='B)',fontsize=18,fontweight='bold',x=0.0,y=.95,transform=a.transAxes)
# a.text(s='B)',fontsize=18,fontweight='bold',x=-.07,y=1.0,transform=a.transAxes)

xlim_min=np.min(summary['coef']-1.96*summary['se(coef)'])
xlim_max=np.max(summary['coef']+1.96*summary['se(coef)'])

for i,ind in enumerate(summary.index):
    expcoef=summary.loc[ind,'exp(coef)']
    up=summary.loc[ind,'exp(coef) upper 95%']-expcoef
    low=expcoef-summary.loc[ind,'exp(coef) lower 95%']
    ebars=np.array([[low,up]]).T
    a.errorbar(x=[expcoef],alpha=.7,
               y=[summary.shape[0]-1-i],marker='s',color='k',uplims=True, lolims=True,
               xerr=ebars
#                xerr=[1.96*summary.loc[ind,'se(coef)'],
                    )

    
a.vlines(x=1.0,linestyle='--',alpha=.6,linewidth=1,
         ymin=0,ymax=summary.shape[0]-.9)

a.set_xscale('log')
a.set_xlim([.0000025,30])
a.spines['bottom'].set_position(('data', -.4))
a.spines['bottom'].set_bounds( 0.1,5)

a.spines['left'].set_visible(False)
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)
a.set_yticks([])
a.set_xticks([.1,1,5])
a.xaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
plt.minorticks_off()
a.set_ylim([-2,3])


# a.text(s="LLR pval={:.2e}".format(p_value),fontsize=18,
#        x=.2,y=.8,transform=a.transAxes)



axis_to_data = a.transAxes + a.transData.inverted()
data_to_axis = axis_to_data.inverted()

y=data_to_axis.transform((.1,summary.shape[0]-.55))[1]

print('y',y)
a.text(s="Covariate".format(p_value),fontsize=20,
       x=.01,y=y,transform=a.transAxes)

a.text(s="HR (95% CI)".format(p_value),fontsize=20,
       x=.375,y=y,transform=a.transAxes)

a.text(s="P-value".format(p_value),fontsize=20,
       x=.85,y=y,transform=a.transAxes)

a.hlines(y=y-.02,xmin=-2,xmax=50,transform=a.transAxes,linewidth=3,linestyle='-',color='k')
# a.hlines(y=y-.03,xmin=-1,xmax=2,transform=a.transAxes,linewidth=1,linestyle='-')

for i,ind in enumerate(summary.index):
    y=data_to_axis.transform((.1,summary.shape[0]-i-1.2))[1]
    print('y',y)
    if summary.loc[ind,'p']<.05:
        a.text(s="{}*".format(ind),fontsize=20,
       x=-.1,y=y,transform=a.transAxes)
    else:
        a.text(s=ind,fontsize=20,
           x=-.1,y=y,
           transform=a.transAxes)
    hrtext="{:.2f}  ({:.2f}-{:.2f})".format(*summary.loc[ind,['exp(coef)',
                                                         'exp(coef) lower 95%','exp(coef) upper 95%']])
    pvaltext="{:.2e}".format(*summary.loc[ind,['p']])
    a.text(s=hrtext,fontsize=20,
       x=.35,y=y,
           transform=a.transAxes)
    a.text(s=pvaltext,fontsize=20,
       x=.85,y=y,
           transform=a.transAxes)
    
    x1,y1=data_to_axis.transform((.01,summary.shape[0]-i*.9-1.5))
    x2,y2=data_to_axis.transform((.01,summary.shape[0]-i*.9-.8))
    

    if i%2==0:
        crect=patches.Rectangle((-.1,y1),width=1.2,height=y2-y1,transform=a.transAxes,fill=True,
                               alpha=.05,color='k',clip_on=False)
#         crect2=patches.Rectangle((x2,y1),width=1.1-x2,height=y2-y1,transform=a.transAxes,fill=True,
#                                alpha=.05,color='k')
        a.add_patch(crect)
#         a.add_patch(crect2)
        
    
    

# a.set_title("CPH Model Survival",fontsize=18,fontweight='bold')
# cph.plot(ax=a)
a.text(s="Hazard Ratio",fontsize=18,x=1.25,
       y=-1.1,
       horizontalalignment='center')

f.suptitle('Samstein',fontsize=22,x=.5,y=.97,transform=f.transFigure)

f.subplots_adjust(top=.93,bottom=-.05,right=.95,left=.12,wspace=.0,hspace=1.5)
f.savefig(outfile,dpi=200)
plt.show()
# Out:
#                     coef  exp(coef)  se(coef)  coef lower 95%  coef upper 95%  \
# DDR_low_z_MUT   0.251386   1.285806  0.153048       -0.048584        0.551355
# log(TMB)       -0.171307   0.842563  0.042954       -0.255497       -0.087118
# DDRlow:highTMB -0.801735   0.448550  0.267990       -1.326985       -0.276484
#
#                 exp(coef) lower 95%  exp(coef) upper 95%         z         p  \
# DDR_low_z_MUT              0.952577             1.735603  1.642523  0.100482
# log(TMB)                   0.774532             0.916569 -3.988117  0.000067
# DDRlow:highTMB             0.265276             0.758445 -2.991662  0.002775
#
#                  -log2(p)
# DDR_low_z_MUT    3.314995
# log(TMB)        13.874124
# DDRlow:highTMB   8.493488
# ...

# %%
#low bigbets DDR genes survival analysis
outfile=os.path.join(graphics_dir,'samstein_survival_TMB-L_only_low_zscore.pdf')

cph = lifelines.CoxPHFitter()
# vars2keep=['high_TMB','DDR','DDR:highTMB']
vars2keep=['DDR_low_z']

samstein_clinical_bigbets_low_tmb=samstein.clinical_bigbets_df.loc[samstein.clinical_bigbets_df['high_TMB']=='TMB-L',:]

dummy_df=samstein_clinical_bigbets_low_tmb.loc[:,['os','censOS']]

for var in vars2keep:
    cdf=pd.get_dummies(samstein_clinical_bigbets_low_tmb.loc[:,var])
    cdf.columns=map(lambda x: var+"_"+str(x),cdf.columns.values)
    dummy_df=pd.concat([dummy_df,cdf.iloc[:,:-1]],axis=1)

dummy_df['log(TMB)']=np.log1p(samstein_clinical_bigbets_low_tmb.loc[:,'TMB'])

res=cph.fit(dummy_df, 'os', event_col='censOS')
llrstat=cph.log_likelihood_ratio_test()
llr=llrstat.test_statistic
df=llrstat.degrees_freedom
p_value=llrstat.p_value
summary=res.summary
print(res.summary)

var='DDR_low_z_TMB'



coms=samstein_clinical_bigbets_low_tmb[var].unique()
commap=dict(zip(coms,range(len(coms))))
clust=list(map(lambda x: commap[x],samstein_clinical_bigbets_low_tmb[var]))

plt.close()
f,a=plt.subplots(1,2,figsize=(7.5,10))

nrows=10
ncols=1

ncols1=1
nrows1=6

a=plt.subplot2grid((nrows,ncols),(0,0),rowspan=nrows1,colspan=1)

cols = [red + (1.0,), red + (.5,), blue + (1.0,), blue + (.5,)]
cols=[blue+(1.0,),blue+(.7,)]

kmf = lifelines.KaplanMeierFitter()
df2test=samstein_clinical_bigbets_low_tmb
i=0
for name,gdf in df2test.groupby(var):
    if re.search("WT",name):
        ls=':'
    else:
        ls='-'
    kmf.fit(gdf["os"], gdf["censOS"], label=name)
    kmf.plot(ax=a,ci_show=False,c=cols[i],linestyle=ls,
             show_censors=True, censor_styles={'ms': 5, 'marker': '+'})
    i+=1
# lg_lines=lg.get_lines()
# for j,ln in enumerate(a.get_lines()):
#     ln.set_color(cols[j])
#     lg_lines[j].set_color(cols[j])

handles, labels = a.get_legend_handles_labels()
new_labels=['Low-BiG-BETS DDR Mut','Low-BiG-BETS DDR WT','Low-BiG-BETS DDR Mut','Low-BiG-BETS DDR WT']

l=a.legend(loc=1,bbox_to_anchor=(.85,1.0),fontsize=14,
           frameon=False,handles=handles,labels=new_labels)
for i,text in enumerate(l.get_texts()):
    plt.setp(text, color = cols[i])
    
a.annotate(s='TMB-L',fontsize=14,xy=(.83,.925),xytext=(.86,.925),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)


a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

a.set_xlabel("months",fontsize=20)
a.set_ylabel("overall survival",fontsize=20)

# a.set_title("Kaplan-Meier Curve by TMB + low TMB Assoc.DDR Genes",fontsize=18,fontweight='bold')
pval_df=bigbets.bipartite_helper_functions.get_os_stats(clust=clust,samp_df=samstein_clinical_bigbets_low_tmb)
pval=pval_df['llr_pval'].values[0]
a.text(x=.85,y=.05,s="CPH pval={:.1e}".format(pval),horizontalalignment='center',
       fontsize=14,transform=a.transAxes)



a=plt.subplot2grid((nrows,ncols),(nrows1,0),rowspan=nrows-nrows1,colspan=1)
# a=plt.subplot(1,2,2)
# a.text(s='B)',fontsize=18,fontweight='bold',x=0.0,y=.95,transform=a.transAxes)
# a.text(s='B)',fontsize=18,fontweight='bold',x=-.07,y=1.0,transform=a.transAxes)

xlim_min=np.min(summary['coef']-1.96*summary['se(coef)'])
xlim_max=np.max(summary['coef']+1.96*summary['se(coef)'])

for i,ind in enumerate(summary.index):
    expcoef=summary.loc[ind,'exp(coef)']
    up=summary.loc[ind,'exp(coef) upper 95%']-expcoef
    low=expcoef-summary.loc[ind,'exp(coef) lower 95%']
    ebars=np.array([[low,up]]).T
    a.errorbar(x=[expcoef],alpha=.7,
               y=[summary.shape[0]-1-i],marker='s',color='k',uplims=True, lolims=True,
               xerr=ebars
#                xerr=[1.96*summary.loc[ind,'se(coef)'],
                    )

    
a.vlines(x=1.0,linestyle='--',alpha=.6,linewidth=1,
         ymin=0,ymax=summary.shape[0]-.9)

a.set_xscale('log')
a.set_xlim([.0000025,30])
a.spines['bottom'].set_position(('data', -.4))
a.spines['bottom'].set_bounds( 0.1,5)

a.spines['left'].set_visible(False)
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)
a.set_yticks([])
a.set_xticks([.1,1,5])
a.xaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
plt.minorticks_off()
a.set_ylim([-2,3])


# a.text(s="LLR pval={:.2e}".format(p_value),fontsize=18,
#        x=.2,y=.8,transform=a.transAxes)



axis_to_data = a.transAxes + a.transData.inverted()
data_to_axis = axis_to_data.inverted()

y=data_to_axis.transform((.1,summary.shape[0]-.55))[1]

print('y',y)
a.text(s="Covariate".format(p_value),fontsize=20,
       x=.01,y=y,transform=a.transAxes)

a.text(s="HR (95% CI)".format(p_value),fontsize=20,
       x=.375,y=y,transform=a.transAxes)

a.text(s="P-value".format(p_value),fontsize=20,
       x=.85,y=y,transform=a.transAxes)

a.hlines(y=y-.02,xmin=-2,xmax=50,transform=a.transAxes,linewidth=3,linestyle='-',color='k')
# a.hlines(y=y-.03,xmin=-1,xmax=2,transform=a.transAxes,linewidth=1,linestyle='-')

for i,ind in enumerate(summary.index):
    y=data_to_axis.transform((.1,summary.shape[0]-i-1.2))[1]
    print('y',y)
    if summary.loc[ind,'p']<.05:
        a.text(s="{}*".format(ind),fontsize=20,
       x=-.1,y=y,transform=a.transAxes)
    else:
        a.text(s=ind,fontsize=20,
           x=-.1,y=y,
           transform=a.transAxes)
    hrtext="{:.2f}  ({:.2f}-{:.2f})".format(*summary.loc[ind,['exp(coef)',
                                                         'exp(coef) lower 95%','exp(coef) upper 95%']])
    pvaltext="{:.2e}".format(*summary.loc[ind,['p']])
    a.text(s=hrtext,fontsize=20,
       x=.35,y=y,
           transform=a.transAxes)
    a.text(s=pvaltext,fontsize=20,
       x=.85,y=y,
           transform=a.transAxes)
    
    x1,y1=data_to_axis.transform((.01,summary.shape[0]-i*.9-1.5))
    x2,y2=data_to_axis.transform((.01,summary.shape[0]-i*.9-.8))
    

    if i%2==0:
        crect=patches.Rectangle((-.1,y1),width=1.2,height=y2-y1,transform=a.transAxes,fill=True,
                               alpha=.05,color='k',clip_on=False)
#         crect2=patches.Rectangle((x2,y1),width=1.1-x2,height=y2-y1,transform=a.transAxes,fill=True,
#                                alpha=.05,color='k')
        a.add_patch(crect)
#         a.add_patch(crect2)
        
    
    

# a.set_title("CPH Model Survival",fontsize=18,fontweight='bold')
# cph.plot(ax=a)
a.text(s="Hazard Ratio",fontsize=18,x=1.25,
       y=-1.1,
       horizontalalignment='center')

f.suptitle('Samstein',fontsize=22,x=.5,y=.97,transform=f.transFigure)

f.subplots_adjust(top=.93,bottom=-.05,right=.95,left=.12,wspace=.0,hspace=1.5)
f.savefig(outfile,dpi=200)
plt.show()
# Out:
#                    coef  exp(coef)  se(coef)  coef lower 95%  coef upper 95%  \
# DDR_low_z_MUT  0.146842   1.158171   0.15653       -0.159951        0.453635
# log(TMB)       0.093733   1.098267   0.08156       -0.066122        0.253588
#
#                exp(coef) lower 95%  exp(coef) upper 95%         z         p  \
# DDR_low_z_MUT             0.852186             1.574024  0.938109  0.348189
# log(TMB)                  0.936017             1.288641  1.149251  0.250453
#
#                -log2(p)
# DDR_low_z_MUT  1.522059
# log(TMB)       1.997390
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/lifelines/fitters/kaplan_meier_fitter.py:268: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   self.confidence_interval_ = self._bounds(cumulative_sq_[:, None], alpha, ci_labels)
# ...

# %% [markdown]
# ### High Big_BETS DDR Mutations

# %%
#high bigbets DDR genes survival analysis
outfile=os.path.join(supplements_dir,'R1_Figure_S4C_samstein_survival_high_zscore.pdf')

cph = lifelines.CoxPHFitter()
# vars2keep=['high_TMB','DDR','DDR:highTMB']
vars2keep=['DDR_high_z']

dummy_df=samstein.clinical_bigbets_df.loc[:,['os','censOS']]

for var in vars2keep:
    cdf=pd.get_dummies(samstein.clinical_bigbets_df.loc[:,var])
    cdf.columns=map(lambda x: var+"_"+str(x),cdf.columns.values)
    dummy_df=pd.concat([dummy_df,cdf.iloc[:,:-1]],axis=1)

dummy_df['log(TMB)']=np.log1p(samstein.clinical_bigbets_df.loc[:,'TMB'])
# dummy_df['TMB']=samstein.clinical_bigbets_df.loc[:,'high_TMB']

dummy_df['DDRhigh:highTMB']=samstein.clinical_bigbets_df.loc[:,'DDRhighz:highTMB']

res=cph.fit(dummy_df, 'os', event_col='censOS')
llrstat=cph.log_likelihood_ratio_test()
llr=llrstat.test_statistic
df=llrstat.degrees_freedom
p_value=llrstat.p_value
summary=res.summary
print(res.summary)

var='DDR_high_z_TMB'



coms=samstein.clinical_bigbets_df[var].unique()
commap=dict(zip(coms,range(len(coms))))
clust=list(map(lambda x: commap[x],samstein.clinical_bigbets_df[var]))

plt.close()
f,a=plt.subplots(1,2,figsize=(7.5,10))

nrows=10
ncols=1

ncols1=1
nrows1=6

a=plt.subplot2grid((nrows,ncols),(0,0),rowspan=nrows1,colspan=1)

cols = [red + (1.0,), red + (.5,), blue + (1.0,), blue + (.5,)]
cols=[red+(1.0,),red+(.7,),blue+(1.0,),blue+(.7,)]

kmf = lifelines.KaplanMeierFitter()
df2test=samstein.clinical_bigbets_df
i=0
for name,gdf in df2test.groupby(var):
    if re.search("WT",name):
        ls=':'
    else:
        ls='-'
    kmf.fit(gdf["os"], gdf["censOS"], label=name)
    kmf.plot(ax=a,ci_show=False,c=cols[i],linestyle=ls,
             show_censors=True, censor_styles={'ms': 5, 'marker': '+'})
    i+=1
# lg_lines=lg.get_lines()
# for j,ln in enumerate(a.get_lines()):
#     ln.set_color(cols[j])
#     lg_lines[j].set_color(cols[j])

handles, labels = a.get_legend_handles_labels()
new_labels=['High-BiG-BETS DDR Mut','High-BiG-BETS DDR WT','High-BiG-BETS DDR Mut','High-BiG-BETS DDR WT']
l=a.legend(loc=1,bbox_to_anchor=(.85,1.0),fontsize=14,
           frameon=False,handles=handles,labels=new_labels)
for i,text in enumerate(l.get_texts()):
    plt.setp(text, color = cols[i])
    
a.annotate(s='TMB-H',fontsize=14,xy=(.83,.925),xytext=(.86,.925),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.annotate(s='TMB-L',fontsize=14,xy=(.83,.825),xytext=(.86,.825),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

a.set_xlabel("months",fontsize=20)
a.set_ylabel("overall survival",fontsize=20)

# a.set_title("Kaplan-Meier Curve by TMB + low TMB Assoc.DDR Genes",fontsize=18,fontweight='bold')
pval_df=bigbets.bipartite_helper_functions.get_os_stats(clust=clust,samp_df=samstein.clinical_bigbets_df)
pval=pval_df['llr_pval'].values[0]
a.text(x=.85,y=.015,s="CPH pval={:.1e}".format(pval),horizontalalignment='center',
       fontsize=14,transform=a.transAxes)



a=plt.subplot2grid((nrows,ncols),(nrows1,0),rowspan=nrows-nrows1,colspan=1)
# a=plt.subplot(1,2,2)
# a.text(s='B)',fontsize=18,fontweight='bold',x=0.0,y=.95,transform=a.transAxes)
# a.text(s='B)',fontsize=18,fontweight='bold',x=-.07,y=1.0,transform=a.transAxes)

xlim_min=np.min(summary['coef']-1.96*summary['se(coef)'])
xlim_max=np.max(summary['coef']+1.96*summary['se(coef)'])

for i,ind in enumerate(summary.index):
    expcoef=summary.loc[ind,'exp(coef)']
    up=summary.loc[ind,'exp(coef) upper 95%']-expcoef
    low=expcoef-summary.loc[ind,'exp(coef) lower 95%']
    ebars=np.array([[low,up]]).T
    a.errorbar(x=[expcoef],alpha=.7,
               y=[summary.shape[0]-1-i],marker='s',color='k',uplims=True, lolims=True,
               xerr=ebars
#                xerr=[1.96*summary.loc[ind,'se(coef)'],
                    )

    
a.vlines(x=1.0,linestyle='--',alpha=.6,linewidth=1,
         ymin=0,ymax=summary.shape[0]-.9)

a.set_xscale('log')
a.set_xlim([.0000025,30])
a.spines['bottom'].set_position(('data', -.4))
a.spines['bottom'].set_bounds( 0.1,5)

a.spines['left'].set_visible(False)
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)
a.set_yticks([])
a.set_xticks([.1,1,5])
a.xaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
plt.minorticks_off()
a.set_ylim([-2,3])


# a.text(s="LLR pval={:.2e}".format(p_value),fontsize=18,
#        x=.2,y=.8,transform=a.transAxes)



axis_to_data = a.transAxes + a.transData.inverted()
data_to_axis = axis_to_data.inverted()

y=data_to_axis.transform((.1,summary.shape[0]-.55))[1]

print('y',y)
a.text(s="Covariate".format(p_value),fontsize=20,
       x=.01,y=y,transform=a.transAxes)

a.text(s="HR (95% CI)".format(p_value),fontsize=20,
       x=.375,y=y,transform=a.transAxes)

a.text(s="P-value".format(p_value),fontsize=20,
       x=.85,y=y,transform=a.transAxes)

a.hlines(y=y-.02,xmin=-2,xmax=50,transform=a.transAxes,linewidth=3,linestyle='-',color='k')
# a.hlines(y=y-.03,xmin=-1,xmax=2,transform=a.transAxes,linewidth=1,linestyle='-')

for i,ind in enumerate(summary.index):
    y=data_to_axis.transform((.1,summary.shape[0]-i-1.2))[1]
    print('y',y)
    if summary.loc[ind,'p']<.05:
        a.text(s="{}*".format(ind),fontsize=20,
       x=-.1,y=y,transform=a.transAxes)
    else:
        a.text(s=ind,fontsize=20,
           x=-.1,y=y,
           transform=a.transAxes)
    hrtext="{:.2f}  ({:.2f}-{:.2f})".format(*summary.loc[ind,['exp(coef)',
                                                         'exp(coef) lower 95%','exp(coef) upper 95%']])
    pvaltext="{:.2e}".format(*summary.loc[ind,['p']])
    a.text(s=hrtext,fontsize=20,
       x=.35,y=y,
           transform=a.transAxes)
    a.text(s=pvaltext,fontsize=20,
       x=.85,y=y,
           transform=a.transAxes)
    
    x1,y1=data_to_axis.transform((.01,summary.shape[0]-i*.9-1.5))
    x2,y2=data_to_axis.transform((.01,summary.shape[0]-i*.9-.8))
    

    if i%2==0:
        crect=patches.Rectangle((-.1,y1),width=1.2,height=y2-y1,transform=a.transAxes,fill=True,
                               alpha=.05,color='k',clip_on=False)
#         crect2=patches.Rectangle((x2,y1),width=1.1-x2,height=y2-y1,transform=a.transAxes,fill=True,
#                                alpha=.05,color='k')
        a.add_patch(crect)
#         a.add_patch(crect2)
        
    
    

# a.set_title("CPH Model Survival",fontsize=18,fontweight='bold')
# cph.plot(ax=a)
a.text(s="Hazard Ratio",fontsize=18,x=1.25,
       y=-1.1,
       horizontalalignment='center')

f.suptitle('Samstein',fontsize=22,x=.5,y=.97,transform=f.transFigure)

f.subplots_adjust(top=.93,bottom=-.05,right=.95,left=.12,wspace=.0,hspace=1.5)
f.savefig(outfile,dpi=200)
plt.show()
# Out:
#                      coef  exp(coef)  se(coef)  coef lower 95%  \
# DDR_high_z_MUT   0.079559   1.082810  0.164052       -0.241978
# log(TMB)        -0.144713   0.865270  0.053306       -0.249190
# DDRhigh:highTMB -0.336716   0.714111  0.210988       -0.750245
#
#                  coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%  \
# DDR_high_z_MUT         0.401096             0.785074             1.493461
# log(TMB)              -0.040236             0.779432             0.960562
# DDRhigh:highTMB        0.076812             0.472251             1.079839
#
#                         z         p  -log2(p)
# DDR_high_z_MUT   0.484961  0.627704  0.671844
# log(TMB)        -2.714789  0.006632  7.236385
# DDRhigh:highTMB -1.595905  0.110510  3.177751
# ...

# %% [markdown]
# ###  Histone modification Genes

# %%
bigbets.ddr_data_object.myddr_obj.path_2_genes_dict['histone_modification_pathway']
# Out:
# array(['AEBP2', 'APLF', 'ASF1A', 'ASF1B', 'ASH1L', 'ASH2L', 'BAP1',
#        'BIRC5', 'BMI1', 'BPTF', 'BRCC3', 'BRD1', 'BRD2', 'BRD3', 'BRD4',
#        'BRD7', 'BRDT', 'BRF1', 'CARM1', 'CBX2', 'CBX4', 'CBX5', 'CBX6',
#        'CBX7', 'CBX8', 'CHAF1A', 'CHAF1B', 'CHD1', 'CREBBP', 'CXXC1',
#        'DAXX', 'DOT1L', 'DPF3', 'DPY30', 'EHMT1', 'EHMT2', 'EP300',
#        'EZH2', 'H2AX', 'H2AZ1', 'H3-3A', 'H3-3B', 'HAT1', 'HCFC1',
#        'HDAC1', 'HDAC10', 'HDAC11', 'HDAC2', 'HDAC3', 'HDAC4', 'HDAC5',
#        'HDAC6', 'HDAC7', 'HDAC8', 'HDAC9', 'HIRA', 'HJURP', 'ING2',
#        'JMJD1C', 'KAT2A', 'KAT2B', 'KAT5', 'KAT6A', 'KAT6B', 'KAT7',
#        'KAT8', 'KDM1A', 'KDM1B', 'KDM2A', 'KDM2B', 'KDM3A', 'KDM3B',
#        'KDM4A', 'KDM4B', 'KDM4C', 'KDM4D', 'KDM5A', 'KDM5B', 'KDM5C',
#        'KDM5D', 'KDM6A', 'KDM6B', 'KDM7A', 'KDM8', 'KMT2A', 'KMT2B',
#        'KMT2C', 'KMT2D', 'KMT2E', 'KMT5A', 'KMT5B', 'KMT5C', 'L3MBTL1',
# ...

# %%
#low bigbets DDR genes survival analysis
outfile=os.path.join(graphics_dir,'samstein_survival_low_histone.pdf')

cph = lifelines.CoxPHFitter()
# vars2keep=['high_TMB','DDR','DDR:highTMB']
vars2keep=['hist_lowz']

dummy_df=samstein.clinical_bigbets_df.loc[:,['os','censOS']]

for var in vars2keep:
    cdf=pd.get_dummies(samstein.clinical_bigbets_df.loc[:,var])
    cdf.columns=map(lambda x: var+"_"+str(x),cdf.columns.values)
    dummy_df=pd.concat([dummy_df,cdf.iloc[:,:-1]],axis=1)

dummy_df['log(TMB)']=np.log1p(samstein.clinical_bigbets_df.loc[:,'TMB'])
# dummy_df['TMB']=samstein.clinical_bigbets_df.loc[:,'high_TMB']

dummy_df['histlowz:highTMB']=samstein.clinical_bigbets_df.loc[:,'histlowz:highTMB']

res=cph.fit(dummy_df, 'os', event_col='censOS')
llrstat=cph.log_likelihood_ratio_test()
llr=llrstat.test_statistic
df=llrstat.degrees_freedom
p_value=llrstat.p_value
summary=res.summary
print(res.summary)

var='hist_lowz_TMB'



coms=samstein.clinical_bigbets_df[var].unique()
commap=dict(zip(coms,range(len(coms))))
clust=list(map(lambda x: commap[x],samstein.clinical_bigbets_df[var]))

plt.close()
f,a=plt.subplots(1,2,figsize=(7.5,10))

nrows=10
ncols=1

ncols1=1
nrows1=6

a=plt.subplot2grid((nrows,ncols),(0,0),rowspan=nrows1,colspan=1)

cols = [red + (1.0,), red + (.5,), blue + (1.0,), blue + (.5,)]
cols=[red+(1.0,),red+(.7,),blue+(1.0,),blue+(.7,)]

kmf = lifelines.KaplanMeierFitter()
df2test=samstein.clinical_bigbets_df
i=0
for name,gdf in df2test.groupby(var):
    if re.search("WT",name):
        ls=':'
    else:
        ls='-'
    kmf.fit(gdf["os"], gdf["censOS"], label=name)
    kmf.plot(ax=a,ci_show=False,c=cols[i],linestyle=ls,
             show_censors=True, censor_styles={'ms': 5, 'marker': '+'})
    i+=1
# lg_lines=lg.get_lines()
# for j,ln in enumerate(a.get_lines()):
#     ln.set_color(cols[j])
#     lg_lines[j].set_color(cols[j])

handles, labels = a.get_legend_handles_labels()
new_labels=['High-BiG-BETS Histone Mod. Mut','High-BiG-BETS Histone Mod. WT','High-BiG-BETS Histone Mod. Mut',
            'High-BiG-BETS Histone Mod. WT']
l=a.legend(loc=1,bbox_to_anchor=(.85,1.0),fontsize=14,
           frameon=False,handles=handles,labels=new_labels)
for i,text in enumerate(l.get_texts()):
    plt.setp(text, color = cols[i])
    
a.annotate(s='TMB-H',fontsize=14,xy=(.83,.925),xytext=(.86,.925),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.annotate(s='TMB-L',fontsize=14,xy=(.83,.825),xytext=(.86,.825),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

a.set_xlabel("months",fontsize=20)
a.set_ylabel("overall survival",fontsize=20)

# a.set_title("Kaplan-Meier Curve by TMB + low TMB Assoc.DDR Genes",fontsize=18,fontweight='bold')
pval_df=bigbets.bipartite_helper_functions.get_os_stats(clust=clust,samp_df=samstein.clinical_bigbets_df)
pval=pval_df['llr_pval'].values[0]
a.text(x=.85,y=.015,s="CPH pval={:.1e}".format(pval),horizontalalignment='center',
       fontsize=14,transform=a.transAxes)



a=plt.subplot2grid((nrows,ncols),(nrows1,0),rowspan=nrows-nrows1,colspan=1)
# a=plt.subplot(1,2,2)
# a.text(s='B)',fontsize=18,fontweight='bold',x=0.0,y=.95,transform=a.transAxes)
# a.text(s='B)',fontsize=18,fontweight='bold',x=-.07,y=1.0,transform=a.transAxes)

xlim_min=np.min(summary['coef']-1.96*summary['se(coef)'])
xlim_max=np.max(summary['coef']+1.96*summary['se(coef)'])

for i,ind in enumerate(summary.index):
    expcoef=summary.loc[ind,'exp(coef)']
    up=summary.loc[ind,'exp(coef) upper 95%']-expcoef
    low=expcoef-summary.loc[ind,'exp(coef) lower 95%']
    ebars=np.array([[low,up]]).T
    a.errorbar(x=[expcoef],alpha=.7,
               y=[summary.shape[0]-1-i],marker='s',color='k',uplims=True, lolims=True,
               xerr=ebars
#                xerr=[1.96*summary.loc[ind,'se(coef)'],
                    )

    
a.vlines(x=1.0,linestyle='--',alpha=.6,linewidth=1,
         ymin=0,ymax=summary.shape[0]-.9)

a.set_xscale('log')
a.set_xlim([.0000025,30])
a.spines['bottom'].set_position(('data', -.4))
a.spines['bottom'].set_bounds( 0.1,5)

a.spines['left'].set_visible(False)
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)
a.set_yticks([])
a.set_xticks([.1,1,5])
a.xaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
plt.minorticks_off()
a.set_ylim([-2,3])


# a.text(s="LLR pval={:.2e}".format(p_value),fontsize=18,
#        x=.2,y=.8,transform=a.transAxes)



axis_to_data = a.transAxes + a.transData.inverted()
data_to_axis = axis_to_data.inverted()

y=data_to_axis.transform((.1,summary.shape[0]-.55))[1]

print('y',y)
a.text(s="Covariate".format(p_value),fontsize=20,
       x=.01,y=y,transform=a.transAxes)

a.text(s="HR (95% CI)".format(p_value),fontsize=20,
       x=.375,y=y,transform=a.transAxes)

a.text(s="P-value".format(p_value),fontsize=20,
       x=.85,y=y,transform=a.transAxes)

a.hlines(y=y-.02,xmin=-2,xmax=50,transform=a.transAxes,linewidth=3,linestyle='-',color='k')
# a.hlines(y=y-.03,xmin=-1,xmax=2,transform=a.transAxes,linewidth=1,linestyle='-')

for i,ind in enumerate(summary.index):
    y=data_to_axis.transform((.1,summary.shape[0]-i-1.2))[1]
    print('y',y)
    if summary.loc[ind,'p']<.05:
        a.text(s="{}*".format(ind),fontsize=20,
       x=-.1,y=y,transform=a.transAxes)
    else:
        a.text(s=ind,fontsize=20,
           x=-.1,y=y,
           transform=a.transAxes)
    hrtext="{:.2f}  ({:.2f}-{:.2f})".format(*summary.loc[ind,['exp(coef)',
                                                         'exp(coef) lower 95%','exp(coef) upper 95%']])
    pvaltext="{:.2e}".format(*summary.loc[ind,['p']])
    a.text(s=hrtext,fontsize=20,
       x=.35,y=y,
           transform=a.transAxes)
    a.text(s=pvaltext,fontsize=20,
       x=.85,y=y,
           transform=a.transAxes)
    
    x1,y1=data_to_axis.transform((.01,summary.shape[0]-i*.9-1.5))
    x2,y2=data_to_axis.transform((.01,summary.shape[0]-i*.9-.8))
    

    if i%2==0:
        crect=patches.Rectangle((-.1,y1),width=1.2,height=y2-y1,transform=a.transAxes,fill=True,
                               alpha=.05,color='k',clip_on=False)
#         crect2=patches.Rectangle((x2,y1),width=1.1-x2,height=y2-y1,transform=a.transAxes,fill=True,
#                                alpha=.05,color='k')
        a.add_patch(crect)
#         a.add_patch(crect2)
        
    
    

# a.set_title("CPH Model Survival",fontsize=18,fontweight='bold')
# cph.plot(ax=a)
a.text(s="Hazard Ratio",fontsize=18,x=1.25,
       y=-1.1,
       horizontalalignment='center')

f.suptitle('Samstein',fontsize=22,x=.5,y=.97,transform=f.transFigure)

f.subplots_adjust(top=.93,bottom=-.05,right=.95,left=.12,wspace=.0,hspace=1.5)
f.savefig(outfile,dpi=200)
plt.show()
# Out:
#                       coef  exp(coef)  se(coef)  coef lower 95%  \
# hist_lowz_MUT    -0.074851   0.927882  0.094811       -0.260678
# log(TMB)         -0.110078   0.895764  0.060283       -0.228230
# histlowz:highTMB -0.243039   0.784241  0.155343       -0.547505
#
#                   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%  \
# hist_lowz_MUT           0.110975             0.770529             1.117367
# log(TMB)                0.008074             0.795941             1.008107
# histlowz:highTMB        0.061428             0.578391             1.063354
#
#                          z         p  -log2(p)
# hist_lowz_MUT    -0.789476  0.429834  1.218149
# log(TMB)         -1.826031  0.067846  3.881602
# histlowz:highTMB -1.564531  0.117693  3.086902
# ...

# %% [markdown]
# ### Chromatin Remodelling genes

# %%
pd.DataFrame(bigbets.ddr_data_object.myddr_obj.path_2_genes_dict['chromatin_remodel'],columns=['GO:0006338: Chromatin Remodeling']).to_csv(os.path.join(dropdir,"chromatin_remodeling_genes.csv"))

# %%
#low bigbets chromatin genes survival analysis
outfile=os.path.join(supplements_dir,'R1_Figure_S5B_samstein_survival_low_chromatin.pdf')

cph = lifelines.CoxPHFitter()
# vars2keep=['high_TMB','DDR','DDR:highTMB']
vars2keep=['chromatin_lowz']

dummy_df=samstein.clinical_bigbets_df.loc[:,['os','censOS']]

for var in vars2keep:
    cdf=pd.get_dummies(samstein.clinical_bigbets_df.loc[:,var])
    cdf.columns=map(lambda x: var+"_"+str(x),cdf.columns.values)
    dummy_df=pd.concat([dummy_df,cdf.iloc[:,:-1]],axis=1)

dummy_df['log(TMB)']=np.log1p(samstein.clinical_bigbets_df.loc[:,'TMB'])
# dummy_df['TMB']=samstein.clinical_bigbets_df.loc[:,'high_TMB']

dummy_df['chromatinlowz:highTMB']=samstein.clinical_bigbets_df.loc[:,'chromatinlowz:highTMB']

res=cph.fit(dummy_df, 'os', event_col='censOS')
llrstat=cph.log_likelihood_ratio_test()
llr=llrstat.test_statistic
df=llrstat.degrees_freedom
p_value=llrstat.p_value
summary=res.summary
print(res.summary)

var='chromatin_lowz_TMB'



coms=samstein.clinical_bigbets_df[var].unique()
commap=dict(zip(coms,range(len(coms))))
clust=list(map(lambda x: commap[x],samstein.clinical_bigbets_df[var]))

plt.close()
f,a=plt.subplots(1,2,figsize=(7.5,10))

nrows=10
ncols=1

ncols1=1
nrows1=6

a=plt.subplot2grid((nrows,ncols),(0,0),rowspan=nrows1,colspan=1)

cols = [red + (1.0,), red + (.5,), blue + (1.0,), blue + (.5,)]
cols=[red+(1.0,),red+(.7,),blue+(1.0,),blue+(.7,)]

kmf = lifelines.KaplanMeierFitter()
df2test=samstein.clinical_bigbets_df
i=0
for name,gdf in df2test.groupby(var):
    if re.search("WT",name):
        ls=':'
    else:
        ls='-'
    kmf.fit(gdf["os"], gdf["censOS"], label=name)
    kmf.plot(ax=a,ci_show=False,c=cols[i],linestyle=ls,
             show_censors=True, censor_styles={'ms': 5, 'marker': '+'})
    i+=1
# lg_lines=lg.get_lines()
# for j,ln in enumerate(a.get_lines()):
#     ln.set_color(cols[j])
#     lg_lines[j].set_color(cols[j])

handles, labels = a.get_legend_handles_labels()
new_labels=['Low-BiG-BETS Chromatin Remod. Mut','Low-BiG-BETS Chromatin Remod. WT','Low-BiG-BETS Chromatin Remod. Mut',
            'Low-BiG-BETS Chromatin Remod. WT']
l=a.legend(loc=1,bbox_to_anchor=(.85,1.0),fontsize=14,
           frameon=False,handles=handles,labels=new_labels)
for i,text in enumerate(l.get_texts()):
    plt.setp(text, color = cols[i])
    
a.annotate(s='TMB-H',fontsize=14,xy=(.83,.925),xytext=(.86,.925),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.annotate(s='TMB-L',fontsize=14,xy=(.83,.825),xytext=(.86,.825),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

a.set_xlabel("months",fontsize=20)
a.set_ylabel("overall survival",fontsize=20)

# a.set_title("Kaplan-Meier Curve by TMB + low TMB Assoc.DDR Genes",fontsize=18,fontweight='bold')
pval_df=bigbets.bipartite_helper_functions.get_os_stats(clust=clust,samp_df=samstein.clinical_bigbets_df)
pval=pval_df['llr_pval'].values[0]
a.text(x=.85,y=.015,s="CPH pval={:.1e}".format(pval),horizontalalignment='center',
       fontsize=14,transform=a.transAxes)



a=plt.subplot2grid((nrows,ncols),(nrows1,0),rowspan=nrows-nrows1,colspan=1)
# a=plt.subplot(1,2,2)
# a.text(s='B)',fontsize=18,fontweight='bold',x=0.0,y=.95,transform=a.transAxes)
# a.text(s='B)',fontsize=18,fontweight='bold',x=-.07,y=1.0,transform=a.transAxes)

xlim_min=np.min(summary['coef']-1.96*summary['se(coef)'])
xlim_max=np.max(summary['coef']+1.96*summary['se(coef)'])

for i,ind in enumerate(summary.index):
    expcoef=summary.loc[ind,'exp(coef)']
    up=summary.loc[ind,'exp(coef) upper 95%']-expcoef
    low=expcoef-summary.loc[ind,'exp(coef) lower 95%']
    ebars=np.array([[low,up]]).T
    a.errorbar(x=[expcoef],alpha=.7,
               y=[summary.shape[0]-1-i],marker='s',color='k',uplims=True, lolims=True,
               xerr=ebars
#                xerr=[1.96*summary.loc[ind,'se(coef)'],
                    )

    
a.vlines(x=1.0,linestyle='--',alpha=.6,linewidth=1,
         ymin=0,ymax=summary.shape[0]-.9)

a.set_xscale('log')
a.set_xlim([.0000025,30])
a.spines['bottom'].set_position(('data', -.4))
a.spines['bottom'].set_bounds( 0.1,5)

a.spines['left'].set_visible(False)
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)
a.set_yticks([])
a.set_xticks([.1,1,5])
a.xaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
plt.minorticks_off()
a.set_ylim([-2,3])


# a.text(s="LLR pval={:.2e}".format(p_value),fontsize=18,
#        x=.2,y=.8,transform=a.transAxes)



axis_to_data = a.transAxes + a.transData.inverted()
data_to_axis = axis_to_data.inverted()

y=data_to_axis.transform((.1,summary.shape[0]-.55))[1]

print('y',y)
a.text(s="Covariate".format(p_value),fontsize=16,
       x=.01,y=y,transform=a.transAxes)

a.text(s="HR (95% CI)".format(p_value),fontsize=16,
       x=.375,y=y,transform=a.transAxes)

a.text(s="P-value".format(p_value),fontsize=16,
       x=.85,y=y,transform=a.transAxes)

a.hlines(y=y-.02,xmin=-2,xmax=50,transform=a.transAxes,linewidth=3,linestyle='-',color='k')
# a.hlines(y=y-.03,xmin=-1,xmax=2,transform=a.transAxes,linewidth=1,linestyle='-')

for i,ind in enumerate(summary.index):
    y=data_to_axis.transform((.1,summary.shape[0]-i-1.2))[1]
    print('y',y)
    if summary.loc[ind,'p']<.05:
        a.text(s="{}*".format(ind),fontsize=16,
       x=-.1,y=y,transform=a.transAxes)
    else:
        a.text(s=ind,fontsize=16,
           x=-.1,y=y,
           transform=a.transAxes)
    hrtext="{:.2f}  ({:.2f}-{:.2f})".format(*summary.loc[ind,['exp(coef)',
                                                         'exp(coef) lower 95%','exp(coef) upper 95%']])
    pvaltext="{:.2e}".format(*summary.loc[ind,['p']])
    a.text(s=hrtext,fontsize=16,
       x=.35,y=y,
           transform=a.transAxes)
    a.text(s=pvaltext,fontsize=16,
       x=.85,y=y,
           transform=a.transAxes)
    
    x1,y1=data_to_axis.transform((.01,summary.shape[0]-i*.9-1.5))
    x2,y2=data_to_axis.transform((.01,summary.shape[0]-i*.9-.8))
    

    if i%2==0:
        crect=patches.Rectangle((-.1,y1),width=1.2,height=y2-y1,transform=a.transAxes,fill=True,
                               alpha=.05,color='k',clip_on=False)
#         crect2=patches.Rectangle((x2,y1),width=1.1-x2,height=y2-y1,transform=a.transAxes,fill=True,
#                                alpha=.05,color='k')
        a.add_patch(crect)
#         a.add_patch(crect2)
        
    
    

# a.set_title("CPH Model Survival",fontsize=18,fontweight='bold')
# cph.plot(ax=a)
a.text(s="Hazard Ratio",fontsize=18,x=1.25,
       y=-1.1,
       horizontalalignment='center')

f.suptitle('Samstein',fontsize=22,x=.5,y=.97,transform=f.transFigure)

f.subplots_adjust(top=.93,bottom=-.05,right=.95,left=.12,wspace=.0,hspace=1.5)
f.savefig(outfile,dpi=200)
plt.show()
# Out:
#                            coef  exp(coef)  se(coef)  coef lower 95%  \
# chromatin_lowz_MUT    -0.099936   0.904895  0.091526       -0.279323
# log(TMB)              -0.113389   0.892804  0.060295       -0.231565
# chromatinlowz:highTMB -0.210792   0.809942  0.152541       -0.509767
#
#                        coef upper 95%  exp(coef) lower 95%  \
# chromatin_lowz_MUT           0.079451             0.756296
# log(TMB)                     0.004788             0.793291
# chromatinlowz:highTMB        0.088182             0.600636
#
#                        exp(coef) upper 95%         z         p  -log2(p)
# chromatin_lowz_MUT                1.082693 -1.091890  0.274882  1.863117
# log(TMB)                          1.004800 -1.880551  0.060033  4.058102
# chromatinlowz:highTMB             1.092187 -1.381877  0.167010  2.581997
# ...

# %% [markdown]
# # IMVigor210

# %%
imvigor=bigbets.IMVigorData()
# Out:
# 2021-12-21 19:43:22,559:root:INFO:Loading IMVIigor clinical data
# 2021-12-21 19:43:22,586:root:INFO:Loading IMVIigor genomic data
# querying 1-160...done.
# Finished.
# 5 input query terms found no hit:
# 	['MLL2', 'GPR124', 'MLL3', 'FAM123B', 'PARK2']
# querying 1-5...done.
# 2021-12-21 19:43:25,892:root:INFO:Loading IMVigor RNAseqdata
# Finished.
# 3 input query terms found dup hits:
# 	[('MLL2', 2), ('MLL3', 2), ('PARK2', 4)]
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# ../bigbets/load_clinical_datasets.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# ## Surival Analysis

# %% [markdown]
# ### Survival by TMB

# %%
#by TMB genes survival analysis
outfile=os.path.join(supplements_dir,'R1_Figure_S4A_imvigor_survival_low_zscore.pdf')

cph = lifelines.CoxPHFitter()
# vars2keep=['high_TMB','DDR','DDR:highTMB']
vars2keep=['DDR']

dummy_df=imvigor.clinical_bigbets_df.loc[:,['os','censOS']]

for var in vars2keep:
    cdf=pd.get_dummies(imvigor.clinical_bigbets_df.loc[:,var])
    cdf.columns=map(lambda x: var+"_"+str(x),cdf.columns.values)
    dummy_df=pd.concat([dummy_df,cdf.iloc[:,:-1]],axis=1)

dummy_df['log(TMB)']=np.log1p(imvigor.clinical_bigbets_df.loc[:,'TMB'])
# dummy_df['TMB']=imvigor.clinical_bigbets_df.loc[:,'high_TMB']


res=cph.fit(dummy_df, 'os', event_col='censOS')
llrstat=cph.log_likelihood_ratio_test()
llr=llrstat.test_statistic
df=llrstat.degrees_freedom
p_value=llrstat.p_value
summary=res.summary
print(res.summary)

var='high_TMB'



coms=imvigor.clinical_bigbets_df[var].unique()
commap=dict(zip(coms,range(len(coms))))
clust=list(map(lambda x: commap[x],imvigor.clinical_bigbets_df[var]))

plt.close()
f,a=plt.subplots(1,2,figsize=(7.5,10))

nrows=10
ncols=1

ncols1=1
nrows1=6

a=plt.subplot2grid((nrows,ncols),(0,0),rowspan=nrows1,colspan=1)

cols = [red + (1.0,), blue + (1.0,)]

kmf = lifelines.KaplanMeierFitter()
df2test=imvigor.clinical_bigbets_df
i=0
for name,gdf in df2test.groupby(var):
    if re.search("WT",name):
        ls=':'
    else:
        ls='-'
    kmf.fit(gdf["os"], gdf["censOS"], label=name)
    kmf.plot(ax=a,ci_show=False,c=cols[i],linestyle=ls,
             show_censors=True, censor_styles={'ms': 5, 'marker': '+'})
    i+=1
# lg_lines=lg.get_lines()
# for j,ln in enumerate(a.get_lines()):
#     ln.set_color(cols[j])
#     lg_lines[j].set_color(cols[j])

handles, labels = a.get_legend_handles_labels()
new_labels=['TMB-H','TMB-L']
l=a.legend(loc=1,bbox_to_anchor=(.85,1.0),fontsize=14,
           frameon=False,handles=handles,labels=new_labels)
for i,text in enumerate(l.get_texts()):
    plt.setp(text, color = cols[i])
    
# a.annotate(s='TMB-H',fontsize=14,xy=(.83,.925),xytext=(.86,.925),
#        arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
#        xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

# a.annotate(s='TMB-L',fontsize=14,xy=(.83,.825),xytext=(.86,.825),
#        arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
#        xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

a.set_xlabel("months",fontsize=20)
a.set_ylabel("overall survival",fontsize=20)

# a.set_title("Kaplan-Meier Curve by TMB + low TMB Assoc.DDR Genes",fontsize=18,fontweight='bold')
pval_df=bigbets.bipartite_helper_functions.get_os_stats(clust=clust,samp_df=imvigor.clinical_bigbets_df)
pval=pval_df['llr_pval'].values[0]
a.text(x=.85,y=.75,s="CPH pval={:.1e}".format(pval),horizontalalignment='center',
       fontsize=14,transform=a.transAxes)



a=plt.subplot2grid((nrows,ncols),(nrows1,0),rowspan=nrows-nrows1,colspan=1)
# a=plt.subplot(1,2,2)
# a.text(s='B)',fontsize=18,fontweight='bold',x=0.0,y=.95,transform=a.transAxes)
# a.text(s='B)',fontsize=18,fontweight='bold',x=-.07,y=1.0,transform=a.transAxes)

xlim_min=np.min(summary['coef']-1.96*summary['se(coef)'])
xlim_max=np.max(summary['coef']+1.96*summary['se(coef)'])

for i,ind in enumerate(summary.index):
    expcoef=summary.loc[ind,'exp(coef)']
    up=summary.loc[ind,'exp(coef) upper 95%']-expcoef
    low=expcoef-summary.loc[ind,'exp(coef) lower 95%']
    ebars=np.array([[low,up]]).T
    a.errorbar(x=[expcoef],alpha=.7,
               y=[summary.shape[0]-1-i],marker='s',color='k',uplims=True, lolims=True,
               xerr=ebars
#                xerr=[1.96*summary.loc[ind,'se(coef)'],
                    )

    
a.vlines(x=1.0,linestyle='--',alpha=.6,linewidth=1,color='k',
         ymin=0,ymax=summary.shape[0]-.9)

a.set_xscale('log')
a.set_xlim([.0000025,30])
a.spines['bottom'].set_position(('data', -.4))
a.spines['bottom'].set_bounds( 0.1,5)

a.spines['left'].set_visible(False)
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)
a.set_yticks([])
a.set_xticks([.1,1,5])
a.xaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
plt.minorticks_off()
a.set_ylim([-2,3])


# a.text(s="LLR pval={:.2e}".format(p_value),fontsize=18,
#        x=.2,y=.8,transform=a.transAxes)



axis_to_data = a.transAxes + a.transData.inverted()
data_to_axis = axis_to_data.inverted()

y=data_to_axis.transform((.1,summary.shape[0]-.55))[1]

print('y',y)
a.text(s="Covariate".format(p_value),fontsize=20,
       x=.01,y=y,transform=a.transAxes)

a.text(s="HR (95% CI)".format(p_value),fontsize=20,
       x=.375,y=y,transform=a.transAxes)

a.text(s="P-value".format(p_value),fontsize=20,
       x=.85,y=y,transform=a.transAxes)

a.hlines(y=y-.02,xmin=-2,color='k',xmax=50,transform=a.transAxes,linewidth=3,linestyle='-')
# a.hlines(y=y-.03,xmin=-1,xmax=2,transform=a.transAxes,linewidth=1,linestyle='-')

for i,ind in enumerate(summary.index):
    y=data_to_axis.transform((.1,summary.shape[0]-i-1.2))[1]
    print('y',y)
    if summary.loc[ind,'p']<.05:
        a.text(s="{}*".format(ind),fontsize=20,
       x=-.1,y=y,transform=a.transAxes)
    else:
        a.text(s=ind,fontsize=20,
           x=-.1,y=y,
           transform=a.transAxes)
    hrtext="{:.2f}  ({:.2f}-{:.2f})".format(*summary.loc[ind,['exp(coef)',
                                                         'exp(coef) lower 95%','exp(coef) upper 95%']])
    pvaltext="{:.2e}".format(*summary.loc[ind,['p']])
    a.text(s=hrtext,fontsize=20,
       x=.35,y=y,
           transform=a.transAxes)
    a.text(s=pvaltext,fontsize=20,
       x=.85,y=y,
           transform=a.transAxes)
    
    x1,y1=data_to_axis.transform((.01,summary.shape[0]-i*.9-1.5))
    x2,y2=data_to_axis.transform((.01,summary.shape[0]-i*.9-.8))
    

    if i%2==0:
        crect=patches.Rectangle((-.1,y1),width=1.2,height=y2-y1,transform=a.transAxes,fill=True,
                               alpha=.05,color='k',clip_on=False)
#         crect2=patches.Rectangle((x2,y1),width=1.1-x2,height=y2-y1,transform=a.transAxes,fill=True,
#                                alpha=.05,color='k')
        a.add_patch(crect)
#         a.add_patch(crect2)
        
    
    

# a.set_title("CPH Model Survival",fontsize=18,fontweight='bold')
# cph.plot(ax=a)
a.text(s="Hazard Ratio",fontsize=18,x=1.25,
       y=-1.1,
       horizontalalignment='center')

f.suptitle('Survival by TMB (IMVigor210)',fontsize=22,x=.5,y=.97,transform=f.transFigure)

f.subplots_adjust(top=.93,bottom=-.05,right=.95,left=.12,wspace=.0,hspace=1.5)
f.savefig(outfile,dpi=200)
plt.show()
# Out:
#               coef  exp(coef)  se(coef)  coef lower 95%  coef upper 95%  \
# DDR_MUT   0.161568   1.175352  0.218622       -0.266923        0.590058
# log(TMB) -0.400662   0.669876  0.106991       -0.610361       -0.190963
#
#           exp(coef) lower 95%  exp(coef) upper 95%         z         p  \
# DDR_MUT              0.765732             1.804094  0.739028  0.459890
# log(TMB)             0.543155             0.826163 -3.744808  0.000181
#
#            -log2(p)
# DDR_MUT    1.120639
# log(TMB)  12.435461
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/lifelines/fitters/kaplan_meier_fitter.py:268: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   self.confidence_interval_ = self._bounds(cumulative_sq_[:, None], alpha, ci_labels)
# ...

# %% [markdown]
# ### Low Big_BETS DDR Mutations

# %%
#low bigbets DDR genes survival analysis
outfile=os.path.join(graphics_dir,'R1_Figure_3A_imvigor_survival_low_zscore.pdf')

cph = lifelines.CoxPHFitter()
# vars2keep=['high_TMB','DDR','DDR:highTMB']
vars2keep=['DDR_low_z']

dummy_df=imvigor.clinical_bigbets_df.loc[:,['os','censOS']]

for var in vars2keep:
    cdf=pd.get_dummies(imvigor.clinical_bigbets_df.loc[:,var])
    cdf.columns=map(lambda x: var+"_"+str(x),cdf.columns.values)
    dummy_df=pd.concat([dummy_df,cdf.iloc[:,:-1]],axis=1)

dummy_df['log(TMB)']=np.log1p(imvigor.clinical_bigbets_df.loc[:,'TMB'])
# dummy_df['TMB']=imvigor.clinical_bigbets_df.loc[:,'high_TMB']

dummy_df['DDRlow:highTMB']=imvigor.clinical_bigbets_df.loc[:,'DDRlowz:highTMB']

res=cph.fit(dummy_df, 'os', event_col='censOS')
llrstat=cph.log_likelihood_ratio_test()
llr=llrstat.test_statistic
df=llrstat.degrees_freedom
p_value=llrstat.p_value
summary=res.summary
print(res.summary)

var='DDR_low_z_TMB'



coms=imvigor.clinical_bigbets_df[var].unique()
commap=dict(zip(coms,range(len(coms))))
clust=list(map(lambda x: commap[x],imvigor.clinical_bigbets_df[var]))

plt.close()
f,a=plt.subplots(1,2,figsize=(7.5,10))

nrows=10
ncols=1

ncols1=1
nrows1=6

a=plt.subplot2grid((nrows,ncols),(0,0),rowspan=nrows1,colspan=1)

cols = [red + (1.0,), red + (.5,), blue + (1.0,), blue + (.5,)]
cols=[red+(1.0,),red+(.7,),blue+(1.0,),blue+(.7,)]

kmf = lifelines.KaplanMeierFitter()
df2test=imvigor.clinical_bigbets_df
i=0
for name,gdf in df2test.groupby(var):
    if re.search("WT",name):
        ls=':'
    else:
        ls='-'
    kmf.fit(gdf["os"], gdf["censOS"], label=name)
    kmf.plot(ax=a,ci_show=False,c=cols[i],linestyle=ls,
             show_censors=True, censor_styles={'ms': 5, 'marker': '+'})
    i+=1
# lg_lines=lg.get_lines()
# for j,ln in enumerate(a.get_lines()):
#     ln.set_color(cols[j])
#     lg_lines[j].set_color(cols[j])

handles, labels = a.get_legend_handles_labels()
new_labels=['Low-BiG-BETS DDR Mut','Low-BiG-BETS DDR WT','Low-BiG-BETS DDR Mut','Low-BiG-BETS DDR WT']
l=a.legend(loc=1,bbox_to_anchor=(.85,1.0),fontsize=14,
           frameon=False,handles=handles,labels=new_labels)
for i,text in enumerate(l.get_texts()):
    plt.setp(text, color = cols[i])
    
a.annotate(s='TMB-H',fontsize=14,xy=(.83,.925),xytext=(.86,.925),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.annotate(s='TMB-L',fontsize=14,xy=(.83,.825),xytext=(.86,.825),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

a.set_xlabel("months",fontsize=20)
a.set_ylabel("overall survival",fontsize=20)

# a.set_title("Kaplan-Meier Curve by TMB + low TMB Assoc.DDR Genes",fontsize=18,fontweight='bold')
pval_df=bigbets.bipartite_helper_functions.get_os_stats(clust=clust,samp_df=imvigor.clinical_bigbets_df)
pval=pval_df['llr_pval'].values[0]
a.text(x=.85,y=.05,s="CPH pval={:.1e}".format(pval),horizontalalignment='center',
       fontsize=14,transform=a.transAxes)



a=plt.subplot2grid((nrows,ncols),(nrows1,0),rowspan=nrows-nrows1,colspan=1)
# a=plt.subplot(1,2,2)
# a.text(s='B)',fontsize=18,fontweight='bold',x=0.0,y=.95,transform=a.transAxes)
# a.text(s='B)',fontsize=18,fontweight='bold',x=-.07,y=1.0,transform=a.transAxes)

xlim_min=np.min(summary['coef']-1.96*summary['se(coef)'])
xlim_max=np.max(summary['coef']+1.96*summary['se(coef)'])

for i,ind in enumerate(summary.index):
    expcoef=summary.loc[ind,'exp(coef)']
    up=summary.loc[ind,'exp(coef) upper 95%']-expcoef
    low=expcoef-summary.loc[ind,'exp(coef) lower 95%']
    ebars=np.array([[low,up]]).T
    a.errorbar(x=[expcoef],alpha=.7,
               y=[summary.shape[0]-1-i],marker='s',color='k',uplims=True, lolims=True,
               xerr=ebars
#                xerr=[1.96*summary.loc[ind,'se(coef)'],
                    )

    
a.vlines(x=1.0,linestyle='--',alpha=.6,linewidth=1,color='k',
         ymin=0,ymax=summary.shape[0]-.9)

a.set_xscale('log')
a.set_xlim([.0000025,30])
a.spines['bottom'].set_position(('data', -.4))
a.spines['bottom'].set_bounds( 0.1,5)

a.spines['left'].set_visible(False)
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)
a.set_yticks([])
a.set_xticks([.1,1,5])
a.xaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
plt.minorticks_off()
a.set_ylim([-2,3])


# a.text(s="LLR pval={:.2e}".format(p_value),fontsize=18,
#        x=.2,y=.8,transform=a.transAxes)



axis_to_data = a.transAxes + a.transData.inverted()
data_to_axis = axis_to_data.inverted()

y=data_to_axis.transform((.1,summary.shape[0]-.55))[1]

print('y',y)
a.text(s="Covariate".format(p_value),fontsize=20,
       x=.01,y=y,transform=a.transAxes)

a.text(s="HR (95% CI)".format(p_value),fontsize=20,
       x=.375,y=y,transform=a.transAxes)

a.text(s="P-value".format(p_value),fontsize=20,
       x=.85,y=y,transform=a.transAxes)

a.hlines(y=y-.02,xmin=-2,color='k',xmax=50,transform=a.transAxes,linewidth=3,linestyle='-')
# a.hlines(y=y-.03,xmin=-1,xmax=2,transform=a.transAxes,linewidth=1,linestyle='-')

for i,ind in enumerate(summary.index):
    y=data_to_axis.transform((.1,summary.shape[0]-i-1.2))[1]
    print('y',y)
    if summary.loc[ind,'p']<.05:
        a.text(s="{}*".format(ind),fontsize=20,
       x=-.1,y=y,transform=a.transAxes)
    else:
        a.text(s=ind,fontsize=20,
           x=-.1,y=y,
           transform=a.transAxes)
    hrtext="{:.2f}  ({:.2f}-{:.2f})".format(*summary.loc[ind,['exp(coef)',
                                                         'exp(coef) lower 95%','exp(coef) upper 95%']])
    pvaltext="{:.2e}".format(*summary.loc[ind,['p']])
    a.text(s=hrtext,fontsize=20,
       x=.35,y=y,
           transform=a.transAxes)
    a.text(s=pvaltext,fontsize=20,
       x=.85,y=y,
           transform=a.transAxes)
    
    x1,y1=data_to_axis.transform((.01,summary.shape[0]-i*.9-1.5))
    x2,y2=data_to_axis.transform((.01,summary.shape[0]-i*.9-.8))
    

    if i%2==0:
        crect=patches.Rectangle((-.1,y1),width=1.2,height=y2-y1,transform=a.transAxes,fill=True,
                               alpha=.05,color='k',clip_on=False)
#         crect2=patches.Rectangle((x2,y1),width=1.1-x2,height=y2-y1,transform=a.transAxes,fill=True,
#                                alpha=.05,color='k')
        a.add_patch(crect)
#         a.add_patch(crect2)
        
    
    

# a.set_title("CPH Model Survival",fontsize=18,fontweight='bold')
# cph.plot(ax=a)
a.text(s="Hazard Ratio",fontsize=18,x=1.25,
       y=-1.1,
       horizontalalignment='center')

f.suptitle('IMVigor210',fontsize=22,x=.5,y=.97,transform=f.transFigure)

f.subplots_adjust(top=.93,bottom=-.05,right=.95,left=.12,wspace=.0,hspace=1.5)
f.savefig(outfile,dpi=200)
plt.show()
# Out:
#                     coef  exp(coef)  se(coef)  coef lower 95%  coef upper 95%  \
# DDR_low_z_MUT   1.020980   2.775914  0.305662        0.421894        1.620066
# log(TMB)       -0.303131   0.738502  0.108425       -0.515640       -0.090623
# DDRlow:highTMB -1.695224   0.183558  0.522180       -2.718679       -0.671770
#
#                 exp(coef) lower 95%  exp(coef) upper 95%         z         p  \
# DDR_low_z_MUT              1.524847             5.053425  3.340227  0.000837
# log(TMB)                   0.597118             0.913362 -2.795779  0.005177
# DDRlow:highTMB             0.065962             0.510804 -3.246434  0.001169
#
#                  -log2(p)
# DDR_low_z_MUT   10.222314
# log(TMB)         7.593536
# DDRlow:highTMB   9.740998
# ...

# %%
imvigor.clinical_bigbets_df['DDR_low_z_TMB'].value_counts()
# Out:
# TMB-L_WT     159
# TMB-H_WT      84
# TMB-H_MUT     19
# TMB-L_MUT     12
# Name: DDR_low_z_TMB, dtype: int64

# %%
samstein.clinical_bigbets_df['DDR_low_z_TMB'].value_counts()
# Out:
# TMB-L_WT     861
# TMB-H_WT     307
# TMB-L_MUT     72
# TMB-H_MUT     67
# Name: DDR_low_z_TMB, dtype: int64

# %%
#low bigbets DDR genes survival analysis
outfile=os.path.join(graphics_dir,'imvigor_survival_TMB-L_only_low_zscore.pdf')

cph = lifelines.CoxPHFitter()
# vars2keep=['high_TMB','DDR','DDR:highTMB']
vars2keep=['DDR_low_z']

imvigor_clinical_bigbets_low_tmb=imvigor.clinical_bigbets_df.loc[imvigor.clinical_bigbets_df['high_TMB']=='TMB-L',:]

dummy_df=imvigor_clinical_bigbets_low_tmb.loc[:,['os','censOS']]

for var in vars2keep:
    cdf=pd.get_dummies(imvigor_clinical_bigbets_low_tmb.loc[:,var])
    cdf.columns=map(lambda x: var+"_"+str(x),cdf.columns.values)
    dummy_df=pd.concat([dummy_df,cdf.iloc[:,:-1]],axis=1)

dummy_df['log(TMB)']=np.log1p(imvigor_clinical_bigbets_low_tmb.loc[:,'TMB'])

res=cph.fit(dummy_df, 'os', event_col='censOS')
llrstat=cph.log_likelihood_ratio_test()
llr=llrstat.test_statistic
df=llrstat.degrees_freedom
p_value=llrstat.p_value
summary=res.summary
print(res.summary)

var='DDR_low_z_TMB'



coms=imvigor_clinical_bigbets_low_tmb[var].unique()
commap=dict(zip(coms,range(len(coms))))
clust=list(map(lambda x: commap[x],imvigor_clinical_bigbets_low_tmb[var]))

plt.close()
f,a=plt.subplots(1,2,figsize=(7.5,10))

nrows=10
ncols=1

ncols1=1
nrows1=6

a=plt.subplot2grid((nrows,ncols),(0,0),rowspan=nrows1,colspan=1)

cols = [red + (1.0,), red + (.5,), blue + (1.0,), blue + (.5,)]
cols=[blue+(1.0,),blue+(.7,)]

kmf = lifelines.KaplanMeierFitter()
df2test=imvigor_clinical_bigbets_low_tmb
i=0
for name,gdf in df2test.groupby(var):
    if re.search("WT",name):
        ls=':'
    else:
        ls='-'
    kmf.fit(gdf["os"], gdf["censOS"], label=name)
    kmf.plot(ax=a,ci_show=False,c=cols[i],linestyle=ls,
             show_censors=True, censor_styles={'ms': 5, 'marker': '+'})
    i+=1
# lg_lines=lg.get_lines()
# for j,ln in enumerate(a.get_lines()):
#     ln.set_color(cols[j])
#     lg_lines[j].set_color(cols[j])

handles, labels = a.get_legend_handles_labels()
new_labels=['Low-BiG-BETS DDR Mut','Low-BiG-BETS DDR WT','Low-BiG-BETS DDR Mut','Low-BiG-BETS DDR WT']

l=a.legend(loc=1,bbox_to_anchor=(.85,1.0),fontsize=14,
           frameon=False,handles=handles,labels=new_labels)
for i,text in enumerate(l.get_texts()):
    plt.setp(text, color = cols[i])
    
a.annotate(s='TMB-L',fontsize=14,xy=(.83,.925),xytext=(.86,.925),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)


a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

a.set_xlabel("months",fontsize=20)
a.set_ylabel("overall survival",fontsize=20)

# a.set_title("Kaplan-Meier Curve by TMB + low TMB Assoc.DDR Genes",fontsize=18,fontweight='bold')
pval_df=bigbets.bipartite_helper_functions.get_os_stats(clust=clust,samp_df=imvigor_clinical_bigbets_low_tmb)
pval=pval_df['llr_pval'].values[0]
a.text(x=.85,y=.05,s="CPH pval={:.1e}".format(pval),horizontalalignment='center',
       fontsize=14,transform=a.transAxes)



a=plt.subplot2grid((nrows,ncols),(nrows1,0),rowspan=nrows-nrows1,colspan=1)
# a=plt.subplot(1,2,2)
# a.text(s='B)',fontsize=18,fontweight='bold',x=0.0,y=.95,transform=a.transAxes)
# a.text(s='B)',fontsize=18,fontweight='bold',x=-.07,y=1.0,transform=a.transAxes)

xlim_min=np.min(summary['coef']-1.96*summary['se(coef)'])
xlim_max=np.max(summary['coef']+1.96*summary['se(coef)'])

for i,ind in enumerate(summary.index):
    expcoef=summary.loc[ind,'exp(coef)']
    up=summary.loc[ind,'exp(coef) upper 95%']-expcoef
    low=expcoef-summary.loc[ind,'exp(coef) lower 95%']
    ebars=np.array([[low,up]]).T
    a.errorbar(x=[expcoef],alpha=.7,
               y=[summary.shape[0]-1-i],marker='s',color='k',uplims=True, lolims=True,
               xerr=ebars
#                xerr=[1.96*summary.loc[ind,'se(coef)'],
                    )

    
a.vlines(x=1.0,linestyle='--',alpha=.6,linewidth=1,
         ymin=0,ymax=summary.shape[0]-.9)

a.set_xscale('log')
a.set_xlim([.0000025,30])
a.spines['bottom'].set_position(('data', -.4))
a.spines['bottom'].set_bounds( 0.1,5)

a.spines['left'].set_visible(False)
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)
a.set_yticks([])
a.set_xticks([.1,1,5])
a.xaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
plt.minorticks_off()
a.set_ylim([-2,3])


# a.text(s="LLR pval={:.2e}".format(p_value),fontsize=18,
#        x=.2,y=.8,transform=a.transAxes)



axis_to_data = a.transAxes + a.transData.inverted()
data_to_axis = axis_to_data.inverted()

y=data_to_axis.transform((.1,summary.shape[0]-.55))[1]

print('y',y)
a.text(s="Covariate".format(p_value),fontsize=20,
       x=.01,y=y,transform=a.transAxes)

a.text(s="HR (95% CI)".format(p_value),fontsize=20,
       x=.375,y=y,transform=a.transAxes)

a.text(s="P-value".format(p_value),fontsize=20,
       x=.85,y=y,transform=a.transAxes)

a.hlines(y=y-.02,xmin=-2,xmax=50,transform=a.transAxes,linewidth=3,linestyle='-',color='k')
# a.hlines(y=y-.03,xmin=-1,xmax=2,transform=a.transAxes,linewidth=1,linestyle='-')

for i,ind in enumerate(summary.index):
    y=data_to_axis.transform((.1,summary.shape[0]-i-1.2))[1]
    print('y',y)
    if summary.loc[ind,'p']<.05:
        a.text(s="{}*".format(ind),fontsize=20,
       x=-.1,y=y,transform=a.transAxes)
    else:
        a.text(s=ind,fontsize=20,
           x=-.1,y=y,
           transform=a.transAxes)
    hrtext="{:.2f}  ({:.2f}-{:.2f})".format(*summary.loc[ind,['exp(coef)',
                                                         'exp(coef) lower 95%','exp(coef) upper 95%']])
    pvaltext="{:.2e}".format(*summary.loc[ind,['p']])
    a.text(s=hrtext,fontsize=20,
       x=.35,y=y,
           transform=a.transAxes)
    a.text(s=pvaltext,fontsize=20,
       x=.85,y=y,
           transform=a.transAxes)
    
    x1,y1=data_to_axis.transform((.01,summary.shape[0]-i*.9-1.5))
    x2,y2=data_to_axis.transform((.01,summary.shape[0]-i*.9-.8))
    

    if i%2==0:
        crect=patches.Rectangle((-.1,y1),width=1.2,height=y2-y1,transform=a.transAxes,fill=True,
                               alpha=.05,color='k',clip_on=False)
#         crect2=patches.Rectangle((x2,y1),width=1.1-x2,height=y2-y1,transform=a.transAxes,fill=True,
#                                alpha=.05,color='k')
        a.add_patch(crect)
#         a.add_patch(crect2)
        
    
    

# a.set_title("CPH Model Survival",fontsize=18,fontweight='bold')
# cph.plot(ax=a)
a.text(s="Hazard Ratio",fontsize=18,x=1.25,
       y=-1.1,
       horizontalalignment='center')

f.suptitle('IMVigor210',fontsize=22,x=.5,y=.97,transform=f.transFigure)

f.subplots_adjust(top=.93,bottom=-.05,right=.95,left=.12,wspace=.0,hspace=1.5)
f.savefig(outfile,dpi=200)
plt.show()
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/lifelines/utils/__init__.py:1053: ConvergenceWarning: Column DDR_low_z_MUT have very low variance when conditioned on death event present or not. This may harm convergence. This could be a form of 'complete separation'. For example, try the following code:
#
# >>> events = df['censOS'].astype(bool)
# >>> print(df.loc[events, 'DDR_low_z_MUT'].var())
# >>> print(df.loc[~events, 'DDR_low_z_MUT'].var())
#
# A very low variance means that the column DDR_low_z_MUT completely determines whether a subject dies or not. See https://stats.stackexchange.com/questions/11109/how-to-deal-with-perfect-separation-in-logistic-regression
#   warnings.warn(dedent(warning_text), ConvergenceWarning)
# ...

# %% [markdown]
# ### High Big_BETS DDR Mutations

# %%
#high bigbets DDR genes survival analysis
outfile=os.path.join(supplements_dir,'R1_Figure_S4C_imvigor_survival_high_zscore.pdf')

cph = lifelines.CoxPHFitter()
# vars2keep=['high_TMB','DDR','DDR:highTMB']
vars2keep=['DDR_high_z']

dummy_df=imvigor.clinical_bigbets_df.loc[:,['os','censOS']]

for var in vars2keep:
    cdf=pd.get_dummies(imvigor.clinical_bigbets_df.loc[:,var])
    cdf.columns=map(lambda x: var+"_"+str(x),cdf.columns.values)
    dummy_df=pd.concat([dummy_df,cdf.iloc[:,:-1]],axis=1)

dummy_df['log(TMB)']=np.log1p(imvigor.clinical_bigbets_df.loc[:,'TMB'])
# dummy_df['TMB']=imvigor.clinical_bigbets_df.loc[:,'high_TMB']

dummy_df['DDRhigh:highTMB']=imvigor.clinical_bigbets_df.loc[:,'DDRhighz:highTMB']

res=cph.fit(dummy_df, 'os', event_col='censOS')
llrstat=cph.log_likelihood_ratio_test()
llr=llrstat.test_statistic
df=llrstat.degrees_freedom
p_value=llrstat.p_value
summary=res.summary
print(res.summary)

var='DDR_high_z_TMB'



coms=imvigor.clinical_bigbets_df[var].unique()
commap=dict(zip(coms,range(len(coms))))
clust=list(map(lambda x: commap[x],imvigor.clinical_bigbets_df[var]))

plt.close()
f,a=plt.subplots(1,2,figsize=(7.5,10))

nrows=10
ncols=1

ncols1=1
nrows1=6

a=plt.subplot2grid((nrows,ncols),(0,0),rowspan=nrows1,colspan=1)

cols = [red + (1.0,), red + (.5,), blue + (1.0,), blue + (.5,)]
cols=[red+(1.0,),red+(.7,),blue+(1.0,),blue+(.7,)]

kmf = lifelines.KaplanMeierFitter()
df2test=imvigor.clinical_bigbets_df
i=0
for name,gdf in df2test.groupby(var):
    if re.search("WT",name):
        ls=':'
    else:
        ls='-'
    kmf.fit(gdf["os"], gdf["censOS"], label=name)
    kmf.plot(ax=a,ci_show=False,c=cols[i],linestyle=ls,
             show_censors=True, censor_styles={'ms': 5, 'marker': '+'})
    i+=1
# lg_lines=lg.get_lines()
# for j,ln in enumerate(a.get_lines()):
#     ln.set_color(cols[j])
#     lg_lines[j].set_color(cols[j])

handles, labels = a.get_legend_handles_labels()
new_labels=['High-BiG-BETS DDR Mut','High-BiG-BETS DDR WT','High-BiG-BETS DDR Mut','High-BiG-BETS DDR WT']
l=a.legend(loc=1,bbox_to_anchor=(.85,1.0),fontsize=14,
           frameon=False,handles=handles,labels=new_labels)
for i,text in enumerate(l.get_texts()):
    plt.setp(text, color = cols[i])
    
a.annotate(s='TMB-H',fontsize=14,xy=(.83,.925),xytext=(.86,.925),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.annotate(s='TMB-L',fontsize=14,xy=(.83,.825),xytext=(.86,.825),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

a.set_xlabel("months",fontsize=20)
a.set_ylabel("overall survival",fontsize=20)

# a.set_title("Kaplan-Meier Curve by TMB + low TMB Assoc.DDR Genes",fontsize=18,fontweight='bold')
pval_df=bigbets.bipartite_helper_functions.get_os_stats(clust=clust,samp_df=imvigor.clinical_bigbets_df)
pval=pval_df['llr_pval'].values[0]
a.text(x=.85,y=.05,s="CPH pval={:.1e}".format(pval),horizontalalignment='center',
       fontsize=14,transform=a.transAxes)



a=plt.subplot2grid((nrows,ncols),(nrows1,0),rowspan=nrows-nrows1,colspan=1)
# a=plt.subplot(1,2,2)
# a.text(s='B)',fontsize=18,fontweight='bold',x=0.0,y=.95,transform=a.transAxes)
# a.text(s='B)',fontsize=18,fontweight='bold',x=-.07,y=1.0,transform=a.transAxes)

xlim_min=np.min(summary['coef']-1.96*summary['se(coef)'])
xlim_max=np.max(summary['coef']+1.96*summary['se(coef)'])

for i,ind in enumerate(summary.index):
    expcoef=summary.loc[ind,'exp(coef)']
    up=summary.loc[ind,'exp(coef) upper 95%']-expcoef
    low=expcoef-summary.loc[ind,'exp(coef) lower 95%']
    ebars=np.array([[low,up]]).T
    a.errorbar(x=[expcoef],alpha=.7,
               y=[summary.shape[0]-1-i],marker='s',color='k',uplims=True, lolims=True,
               xerr=ebars
#                xerr=[1.96*summary.loc[ind,'se(coef)'],
                    )

    
a.vlines(x=1.0,linestyle='--',alpha=.6,linewidth=1,color='k',
         ymin=0,ymax=summary.shape[0]-.9)

a.set_xscale('log')
a.set_xlim([.0000025,30])
a.spines['bottom'].set_position(('data', -.4))
a.spines['bottom'].set_bounds( 0.1,5)

a.spines['left'].set_visible(False)
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)
a.set_yticks([])
a.set_xticks([.1,1,5])
a.xaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
plt.minorticks_off()
a.set_ylim([-2,3])


# a.text(s="LLR pval={:.2e}".format(p_value),fontsize=18,
#        x=.2,y=.8,transform=a.transAxes)



axis_to_data = a.transAxes + a.transData.inverted()
data_to_axis = axis_to_data.inverted()

y=data_to_axis.transform((.1,summary.shape[0]-.55))[1]

print('y',y)
a.text(s="Covariate".format(p_value),fontsize=20,
       x=.01,y=y,transform=a.transAxes)

a.text(s="HR (95% CI)".format(p_value),fontsize=20,
       x=.375,y=y,transform=a.transAxes)

a.text(s="P-value".format(p_value),fontsize=20,
       x=.85,y=y,transform=a.transAxes)

a.hlines(y=y-.02,xmin=-2,xmax=50,color='k',transform=a.transAxes,linewidth=3,linestyle='-')
# a.hlines(y=y-.03,xmin=-1,xmax=2,transform=a.transAxes,linewidth=1,linestyle='-')

for i,ind in enumerate(summary.index):
    y=data_to_axis.transform((.1,summary.shape[0]-i-1.2))[1]
    print('y',y)
    if summary.loc[ind,'p']<.05:
        a.text(s="{}*".format(ind),fontsize=20,
       x=-.1,y=y,transform=a.transAxes)
    else:
        a.text(s=ind,fontsize=20,
           x=-.1,y=y,
           transform=a.transAxes)
    hrtext="{:.2f}  ({:.2f}-{:.2f})".format(*summary.loc[ind,['exp(coef)',
                                                         'exp(coef) lower 95%','exp(coef) upper 95%']])
    pvaltext="{:.2e}".format(*summary.loc[ind,['p']])
    a.text(s=hrtext,fontsize=20,
       x=.35,y=y,
           transform=a.transAxes)
    a.text(s=pvaltext,fontsize=20,
       x=.85,y=y,
           transform=a.transAxes)
    
    x1,y1=data_to_axis.transform((.01,summary.shape[0]-i*.9-1.5))
    x2,y2=data_to_axis.transform((.01,summary.shape[0]-i*.9-.8))
    

    if i%2==0:
        crect=patches.Rectangle((-.1,y1),width=1.2,height=y2-y1,transform=a.transAxes,fill=True,
                               alpha=.05,color='k',clip_on=False)
#         crect2=patches.Rectangle((x2,y1),width=1.1-x2,height=y2-y1,transform=a.transAxes,fill=True,
#                                alpha=.05,color='k')
        a.add_patch(crect)
#         a.add_patch(crect2)
        
    
    

# a.set_title("CPH Model Survival",fontsize=18,fontweight='bold')
# cph.plot(ax=a)
a.text(s="Hazard Ratio",fontsize=18,x=1.25,
       y=-1.1,
       horizontalalignment='center')

f.suptitle('IMVigor210',fontsize=22,x=.5,y=.97,transform=f.transFigure)

f.subplots_adjust(top=.93,bottom=-.05,right=.95,left=.12,wspace=.0,hspace=1.5)
f.savefig(outfile,dpi=200)
plt.show()
# Out:
#                      coef  exp(coef)  se(coef)  coef lower 95%  \
# DDR_high_z_MUT   0.382878   1.466499  0.416311       -0.433077
# log(TMB)        -0.353975   0.701893  0.106034       -0.561798
# DDRhigh:highTMB -0.597772   0.550036  0.624196       -1.821173
#
#                  coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%  \
# DDR_high_z_MUT         1.198832             0.648511             3.316242
# log(TMB)              -0.146152             0.570183             0.864027
# DDRhigh:highTMB        0.625629             0.161836             1.869422
#
#                         z         p   -log2(p)
# DDR_high_z_MUT   0.919692  0.357734   1.483041
# log(TMB)        -3.338309  0.000843  10.212350
# DDRhigh:highTMB -0.957667  0.338231   1.563921
# ...

# %% [markdown]
# ### Chromatin Remodelling genes

# %%
#low bigbets DDR genes survival analysis
outfile=os.path.join(supplements_dir,'R1_Figure_S5B_imvigor_survival_low_chromatin.pdf')

cph = lifelines.CoxPHFitter()
# vars2keep=['high_TMB','DDR','DDR:highTMB']
vars2keep=['chromatin_lowz']

dummy_df=imvigor.clinical_bigbets_df.loc[:,['os','censOS']]

for var in vars2keep:
    cdf=pd.get_dummies(imvigor.clinical_bigbets_df.loc[:,var])
    cdf.columns=map(lambda x: var+"_"+str(x),cdf.columns.values)
    dummy_df=pd.concat([dummy_df,cdf.iloc[:,:-1]],axis=1)

dummy_df['log(TMB)']=np.log1p(imvigor.clinical_bigbets_df.loc[:,'TMB'])
# dummy_df['TMB']=imvigor.clinical_bigbets_df.loc[:,'high_TMB']

dummy_df['chromatinlowz:highTMB']=imvigor.clinical_bigbets_df.loc[:,'chromatinlowz:highTMB']

res=cph.fit(dummy_df, 'os', event_col='censOS')
llrstat=cph.log_likelihood_ratio_test()
llr=llrstat.test_statistic
df=llrstat.degrees_freedom
p_value=llrstat.p_value
summary=res.summary
print(res.summary)

var='chromatin_lowz_TMB'



coms=imvigor.clinical_bigbets_df[var].unique()
commap=dict(zip(coms,range(len(coms))))
clust=list(map(lambda x: commap[x],imvigor.clinical_bigbets_df[var]))

plt.close()
f,a=plt.subplots(1,2,figsize=(7.5,10))

nrows=10
ncols=1

ncols1=1
nrows1=6

a=plt.subplot2grid((nrows,ncols),(0,0),rowspan=nrows1,colspan=1)

cols = [red + (1.0,), red + (.5,), blue + (1.0,), blue + (.5,)]
cols=[red+(1.0,),red+(.7,),blue+(1.0,),blue+(.7,)]

kmf = lifelines.KaplanMeierFitter()
df2test=imvigor.clinical_bigbets_df
i=0
for name,gdf in df2test.groupby(var):
    if re.search("WT",name):
        ls=':'
    else:
        ls='-'
    kmf.fit(gdf["os"], gdf["censOS"], label=name)
    kmf.plot(ax=a,ci_show=False,c=cols[i],linestyle=ls,
             show_censors=True, censor_styles={'ms': 5, 'marker': '+'})
    i+=1
# lg_lines=lg.get_lines()
# for j,ln in enumerate(a.get_lines()):
#     ln.set_color(cols[j])
#     lg_lines[j].set_color(cols[j])

handles, labels = a.get_legend_handles_labels()
new_labels=['Low-BiG-BETS Chromatin Remod. Mut','Low-BiG-BETS Chromatin Remod. WT','Low-BiG-BETS Chromatin Remod. Mut',
            'Low-BiG-BETS Chromatin Remod. WT']
l=a.legend(loc=1,bbox_to_anchor=(.85,1.0),fontsize=14,
           frameon=False,handles=handles,labels=new_labels)
for i,text in enumerate(l.get_texts()):
    plt.setp(text, color = cols[i])
    
a.annotate(s='TMB-H',fontsize=14,xy=(.83,.925),xytext=(.86,.925),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.annotate(s='TMB-L',fontsize=14,xy=(.83,.825),xytext=(.86,.825),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

a.set_xlabel("months",fontsize=20)
a.set_ylabel("overall survival",fontsize=20)

# a.set_title("Kaplan-Meier Curve by TMB + low TMB Assoc.DDR Genes",fontsize=18,fontweight='bold')
pval_df=bigbets.bipartite_helper_functions.get_os_stats(clust=clust,samp_df=imvigor.clinical_bigbets_df)
pval=pval_df['llr_pval'].values[0]
a.text(x=.85,y=.015,s="CPH pval={:.1e}".format(pval),horizontalalignment='center',
       fontsize=14,transform=a.transAxes)



a=plt.subplot2grid((nrows,ncols),(nrows1,0),rowspan=nrows-nrows1,colspan=1)
# a=plt.subplot(1,2,2)
# a.text(s='B)',fontsize=18,fontweight='bold',x=0.0,y=.95,transform=a.transAxes)
# a.text(s='B)',fontsize=18,fontweight='bold',x=-.07,y=1.0,transform=a.transAxes)

xlim_min=np.min(summary['coef']-1.96*summary['se(coef)'])
xlim_max=np.max(summary['coef']+1.96*summary['se(coef)'])

for i,ind in enumerate(summary.index):
    expcoef=summary.loc[ind,'exp(coef)']
    up=summary.loc[ind,'exp(coef) upper 95%']-expcoef
    low=expcoef-summary.loc[ind,'exp(coef) lower 95%']
    ebars=np.array([[low,up]]).T
    a.errorbar(x=[expcoef],alpha=.7,
               y=[summary.shape[0]-1-i],marker='s',color='k',uplims=True, lolims=True,
               xerr=ebars
#                xerr=[1.96*summary.loc[ind,'se(coef)'],
                    )

    
a.vlines(x=1.0,linestyle='--',alpha=.6,linewidth=1,color='k',
         ymin=0,ymax=summary.shape[0]-.9)

a.set_xscale('log')
a.set_xlim([.0000025,30])
a.spines['bottom'].set_position(('data', -.4))
a.spines['bottom'].set_bounds( 0.1,5)

a.spines['left'].set_visible(False)
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)
a.set_yticks([])
a.set_xticks([.1,1,5])
a.xaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
plt.minorticks_off()
a.set_ylim([-2,3])


# a.text(s="LLR pval={:.2e}".format(p_value),fontsize=18,
#        x=.2,y=.8,transform=a.transAxes)



axis_to_data = a.transAxes + a.transData.inverted()
data_to_axis = axis_to_data.inverted()

y=data_to_axis.transform((.1,summary.shape[0]-.55))[1]

print('y',y)
a.text(s="Covariate".format(p_value),fontsize=20,
       x=-.05,y=y,transform=a.transAxes)

a.text(s="HR (95% CI)".format(p_value),fontsize=20,
       x=.375,y=y,transform=a.transAxes)

a.text(s="P-value".format(p_value),fontsize=20,
       x=.85,y=y,transform=a.transAxes)

a.hlines(y=y-.02,xmin=-2,xmax=50,color='k',transform=a.transAxes,linewidth=3,linestyle='-')
# a.hlines(y=y-.03,xmin=-1,xmax=2,transform=a.transAxes,linewidth=1,linestyle='-')

for i,ind in enumerate(summary.index):
    y=data_to_axis.transform((.1,summary.shape[0]-i-1.2))[1]
    print('y',y)
    if summary.loc[ind,'p']<.05:
        a.text(s="{}*".format(ind),fontsize=16,
       x=-.1,y=y,transform=a.transAxes)
    else:
        a.text(s=ind,fontsize=16,
           x=-.1,y=y,
           transform=a.transAxes)
    hrtext="{:.2f}  ({:.2f}-{:.2f})".format(*summary.loc[ind,['exp(coef)',
                                                         'exp(coef) lower 95%','exp(coef) upper 95%']])
    pvaltext="{:.2e}".format(*summary.loc[ind,['p']])
    a.text(s=hrtext,fontsize=16,
       x=.35,y=y,
           transform=a.transAxes)
    a.text(s=pvaltext,fontsize=16,
       x=.85,y=y,
           transform=a.transAxes)
    
    x1,y1=data_to_axis.transform((.01,summary.shape[0]-i*.9-1.5))
    x2,y2=data_to_axis.transform((.01,summary.shape[0]-i*.9-.8))
    

    if i%2==0:
        crect=patches.Rectangle((-.1,y1),width=1.2,height=y2-y1,transform=a.transAxes,fill=True,
                               alpha=.05,color='k',clip_on=False)
#         crect2=patches.Rectangle((x2,y1),width=1.1-x2,height=y2-y1,transform=a.transAxes,fill=True,
#                                alpha=.05,color='k')
        a.add_patch(crect)
#         a.add_patch(crect2)
        
    
    

# a.set_title("CPH Model Survival",fontsize=18,fontweight='bold')
# cph.plot(ax=a)
a.text(s="Hazard Ratio",fontsize=18,x=1.25,
       y=-1.1,
       horizontalalignment='center')

f.suptitle('IMVigor 210',fontsize=22,x=.5,y=.97,transform=f.transFigure)

f.subplots_adjust(top=.93,bottom=-.05,right=.95,left=.12,wspace=.0,hspace=1.5)
f.savefig(outfile,dpi=200)
plt.show()
# Out:
#                            coef  exp(coef)  se(coef)  coef lower 95%  \
# chromatin_lowz_MUT    -0.280719   0.755241  0.186127       -0.645522
# log(TMB)              -0.350000   0.704688  0.131039       -0.606833
# chromatinlowz:highTMB  0.069528   1.072002  0.285160       -0.489376
#
#                        coef upper 95%  exp(coef) lower 95%  \
# chromatin_lowz_MUT           0.084084             0.524389
# log(TMB)                    -0.093168             0.545075
# chromatinlowz:highTMB        0.628432             0.613009
#
#                        exp(coef) upper 95%         z         p  -log2(p)
# chromatin_lowz_MUT                1.087720 -1.508210  0.131501  2.926855
# log(TMB)                          0.911040 -2.670958  0.007564  7.046727
# chromatinlowz:highTMB             1.874669  0.243822  0.807369  0.308700
# ...

# %% [markdown]
# ## ICB Response Analyses

# %% [markdown]
# ### Response TMB only

# %%
#Response by low BIGBETS DDR genes
df_low=bigbets.bipartite_helper_functions.get_percents_bar_by_group(imvigor.clinical_bigbets_df,['high_TMB'],'binaryResponse')
outfile=os.path.join(supplements_dir,"R1_Figure_S4B_imvigor_response_by_low_zscore_mut_tmb.pdf")


plt.close()
f,a=plt.subplots(1,1,figsize=(4,5))

pivot=df_low.loc[:,['Response','group','percent']].pivot(index='group',columns='Response',values='percent')
pivot=pivot.loc[['TMB-L','TMB-H'],:]
stat,pval,_,_=stats.chi2_contingency(df_low.groupby(['group','Response'])['count'].max().unstack(fill_value=0))

ctab_true=df_low.groupby(['group','Response'])['count'].max().unstack().loc[['TMB-H','TMB-L'],:]
s2,pval2=stats.fisher_exact(ctab_true,'two-sided')

a.bar(x=range(pivot.shape[0]),height=pivot['CR/PR'],color=blue)
a.set_ylim([0,.8])
a.set_title("Response by TMB\n(IMvigor210)",fontsize=18)


# a.text(x=.025,y=.85,s=r"p={:.2e}".format(pval1),
#        fontsize=16,transform=a.transAxes)

if pval2>.05:
    a.annotate(s='n.s',fontsize=18,xy=(.5,.62),xytext=(.5,.65),
           arrowprops=dict(arrowstyle='-[, widthB=1.5, lengthB=0', lw=1.0),
           xycoords='axes fraction',horizontalalignment='center',transform=a.transAxes)
else:
    a.annotate(s=r"p={:.2e}".format(pval2),fontsize=18,xy=(.5,.62),xytext=(.5,.65),
               arrowprops=dict(arrowstyle='-[, widthB=1.8, lengthB=0', lw=1.0),
               xycoords='axes fraction',horizontalalignment='center',transform=a.transAxes)

# a.text(x=.57,y=.85,s=r"p={:.2e}".format(pval2),
#        fontsize=16,transform=a.transAxes)

a.set_xlabel("")
a.set_ylabel("% response (CR/PR)",fontsize=18)

    
a.get_xaxis().set_visible(False)
scale=.8

a.text(s="TMB-L",x=0,y=-.1875*scale,fontsize=20,horizontalalignment='center')     
a.text(s="TMB-H",x=1,y=-.1875*scale,fontsize=20,horizontalalignment='center') 


#tick marks 

# for i in range(4):
#     line = lines.Line2D(xdata=[i,i], ydata=[0*scale,-.03*scale],color='k', lw=2,
#                         linestyle='-', alpha=.8,clip_on=False)
#     a.add_line(line)
    
# for i in range(4):
#     line = lines.Line2D(xdata=[i,i], ydata=[-.067*scale,-.12*scale],color='k', lw=2,
#                         linestyle='-', alpha=.8,clip_on=False)
#     a.add_line(line)
    
# for i in range(1):
#     line = lines.Line2D(xdata=[i*2-.2,i*2+1.2], ydata=[-.1*scale,-.1*scale],color='k', lw=2,
#                         linestyle='-', alpha=.8,clip_on=False)
#     a.add_line(line)
# for i in range(2):
#     line = lines.Line2D(xdata=[i*2+.5,i*2+.5], ydata=[-.12*scale,-.15*scale],color='k', lw=2,
#                         linestyle='-', alpha=.8,clip_on=False)
#     a.add_line(line)
    
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

# l=a.legend(fontsize=18,bbox_to_anchor=(.6,.95),ncol=2,loc=10,
#           handletextpad=.4,columnspacing=.7,framealpha=1)
# l.set_visible(True)

f.subplots_adjust(top=.88,bottom=.16,right=.93,left=.22)
f.savefig(outfile,dpi=200)

plt.show()
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:31: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.

# %% [markdown]
# ### by low BiGBETS DDR

# %%
#Response by low BIGBETS DDR genes
df_low=bigbets.bipartite_helper_functions.get_percents_bar_by_group(imvigor.clinical_bigbets_df,['high_TMB','DDR_low_z'],'binaryResponse')
outfile=os.path.join(graphics_dir,"R1_Figure_3C_imvigor_response_by_low_zscore_mut_tmb.pdf")


plt.close()
f,a=plt.subplots(1,1,figsize=(4,5))

pivot=df_low.loc[:,['Response','group','percent']].pivot(index='group',columns='Response',values='percent')
pivot=pivot.loc[['TMB-L_WT','TMB-L_MUT','TMB-H_WT','TMB-H_MUT'],:]
stat,pval,_,_=stats.chi2_contingency(df_low.groupby(['group','Response'])['count'].max().unstack(fill_value=0))

ctab_false=df_low.groupby(['group','Response'])['count'].max().unstack().loc[['TMB-L_WT','TMB-L_MUT'],:]
ctab_true=df_low.groupby(['group','Response'])['count'].max().unstack().loc[['TMB-H_WT','TMB-H_MUT'],:]
s1,pval1=stats.fisher_exact(ctab_false,'less')
s2,pval2=stats.fisher_exact(ctab_true,'less')

a.bar(x=range(pivot.shape[0]),height=pivot['CR/PR'],color=blue)
a.set_ylim([0,1.2])
a.set_ylim([0,.8])
a.set_title("Low BiG-BETS DDR Pts\n(IMvigor210)",fontsize=18)


# a.text(x=.025,y=.85,s=r"p={:.2e}".format(pval1),
#        fontsize=16,transform=a.transAxes)
a.annotate(s='n.s',fontsize=18,xy=(.25,.32),xytext=(.25,.35),
           arrowprops=dict(arrowstyle='-[, widthB=1.5, lengthB=0', lw=1.0),
           xycoords='axes fraction',horizontalalignment='center',transform=a.transAxes)

a.annotate(s=r"p={:.3f}".format(pval2),fontsize=18,xy=(.75,.86),xytext=(.75,.895),
           arrowprops=dict(arrowstyle='-[, widthB=1.5, lengthB=0', lw=1.0),
           xycoords='axes fraction',horizontalalignment='center',transform=a.transAxes)

# a.text(x=.57,y=.85,s=r"p={:.2e}".format(pval2),
#        fontsize=16,transform=a.transAxes)

a.set_xlabel("")
a.set_ylabel("% response (CR/PR)",fontsize=18)

    
a.get_xaxis().set_visible(False)
scale=.8

a.text(s="TMB-L",x=.5,y=-.19*scale,fontsize=20,horizontalalignment='center')     
a.text(s="TMB-H",x=2.5,y=-.19*scale,fontsize=20,horizontalalignment='center') 

a.text(s="WT",x=0,y=-.07*scale,fontsize=20,horizontalalignment='center')     
a.text(s="MUT",x=1,y=-.07*scale,fontsize=20,horizontalalignment='center')
a.text(s="WT",x=2,y=-.07*scale,fontsize=20,horizontalalignment='center')     
a.text(s="MUT",x=3,y=-.07*scale,fontsize=20,horizontalalignment='center')

#tick marks 

# for i in range(4):
#     line = lines.Line2D(xdata=[i,i], ydata=[0*scale,-.03*scale],color='k', lw=2,
#                         linestyle='-', alpha=.8,clip_on=False)
#     a.add_line(line)
    
# for i in range(4):
#     line = lines.Line2D(xdata=[i,i], ydata=[-.067*scale,-.12*scale],color='k', lw=2,
#                         linestyle='-', alpha=.8,clip_on=False)
#     a.add_line(line)
    
for i in range(2):
    line = lines.Line2D(xdata=[i*2-.2,i*2+1.2], ydata=[-.1*scale,-.1*scale],color='k', lw=2,
                        linestyle='-', alpha=.8,clip_on=False)
    a.add_line(line)
# for i in range(2):
#     line = lines.Line2D(xdata=[i*2+.5,i*2+.5], ydata=[-.12*scale,-.15*scale],color='k', lw=2,
#                         linestyle='-', alpha=.8,clip_on=False)
#     a.add_line(line)
    
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

# l=a.legend(fontsize=18,bbox_to_anchor=(.6,.95),ncol=2,loc=10,
#           handletextpad=.4,columnspacing=.7,framealpha=1)
# l.set_visible(True)

f.subplots_adjust(top=.88,bottom=.16,right=.93,left=.22)
f.savefig(outfile,dpi=200)

plt.show()
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:28: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:32: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.

# %%
df_low[df_low['Response']=='CR/PR'].set_index('group').loc[['TMB-L_WT','TMB-L_MUT',"TMB-H_WT","TMB-H_MUT"],'count']
# Out:
# group
# TMB-L_WT     21
# TMB-L_MUT     1
# TMB-H_WT     28
# TMB-H_MUT    10
# Name: count, dtype: object

# %%
#Response by high BiGbets DDR 
df_high=bigbets.bipartite_helper_functions.get_percents_bar_by_group(imvigor.clinical_bigbets_df,['high_TMB','DDR_high_z'],'binaryResponse')
outfile=os.path.join(supplements_dir,"R1_Figure_S4D_imvigor_response_by_high_zscore_mut_tmb.pdf")


plt.close()
f,a=plt.subplots(1,1,figsize=(4,5))

pivot=df_high.loc[:,['Response','group','percent']].pivot(index='group',columns='Response',values='percent')
pivot=pivot.loc[['TMB-L_WT','TMB-L_MUT','TMB-H_WT','TMB-H_MUT'],:]
stat,pval,_,_=stats.chi2_contingency(df_high.groupby(['group','Response'])['count'].max().unstack(fill_value=0))

ctab_false=df_high.groupby(['group','Response'])['count'].max().unstack().loc[['TMB-L_WT','TMB-L_MUT'],:]
ctab_true=df_high.groupby(['group','Response'])['count'].max().unstack().loc[['TMB-H_WT','TMB-H_MUT'],:]
s1,pval1=stats.fisher_exact(ctab_false,'less')
s2,pval2=stats.fisher_exact(ctab_true,'less')

a.bar(x=range(pivot.shape[0]),height=pivot['CR/PR'],color=blue)
a.set_ylim([0,1.2])
a.set_ylim([0,.8])
a.set_title("High BiG-BETS DDR Pts\n(IMvigor210)",fontsize=18)


# a.text(x=.025,y=.85,s=r"p={:.2e}".format(pval1),
#        fontsize=16,transform=a.transAxes)
a.annotate(s='n.s',fontsize=18,xy=(.25,.32),xytext=(.25,.35),
           arrowprops=dict(arrowstyle='-[, widthB=1.5, lengthB=0', lw=1.0),
           xycoords='axes fraction',horizontalalignment='center',transform=a.transAxes)

if pval2<.05:
    a.annotate(s=r"p={:.3f}".format(pval2),fontsize=18,xy=(.75,.86),xytext=(.75,.895),
           arrowprops=dict(arrowstyle='-[, widthB=1.5, lengthB=0', lw=1.0),
           xycoords='axes fraction',horizontalalignment='center',transform=a.transAxes)
else:
    a.annotate(s=r"n.s.".format(pval2),fontsize=18,xy=(.75,.86),xytext=(.75,.895),
           arrowprops=dict(arrowstyle='-[, widthB=1.5, lengthB=0', lw=1.0),
           xycoords='axes fraction',horizontalalignment='center',transform=a.transAxes)

# a.text(x=.57,y=.85,s=r"p={:.2e}".format(pval2),
#        fontsize=16,transform=a.transAxes)

a.set_xlabel("")
a.set_ylabel("% response (CR/PR)",fontsize=18)

    
a.get_xaxis().set_visible(False)
scale=.8

a.text(s="TMB-L",x=.5,y=-.19*scale,fontsize=20,horizontalalignment='center')     
a.text(s="TMB-H",x=2.5,y=-.19*scale,fontsize=20,horizontalalignment='center') 

a.text(s="WT",x=0,y=-.07*scale,fontsize=20,horizontalalignment='center')     
a.text(s="MUT",x=1,y=-.07*scale,fontsize=20,horizontalalignment='center')
a.text(s="WT",x=2,y=-.07*scale,fontsize=20,horizontalalignment='center')     
a.text(s="MUT",x=3,y=-.07*scale,fontsize=20,horizontalalignment='center')

#tick marks 

# for i in range(4):
#     line = lines.Line2D(xdata=[i,i], ydata=[0*scale,-.03*scale],color='k', lw=2,
#                         linestyle='-', alpha=.8,clip_on=False)
#     a.add_line(line)
    
# for i in range(4):
#     line = lines.Line2D(xdata=[i,i], ydata=[-.067*scale,-.12*scale],color='k', lw=2,
#                         linestyle='-', alpha=.8,clip_on=False)
#     a.add_line(line)
    
for i in range(2):
    line = lines.Line2D(xdata=[i*2-.2,i*2+1.2], ydata=[-.1*scale,-.1*scale],color='k', lw=2,
                        linestyle='-', alpha=.8,clip_on=False)
    a.add_line(line)
# for i in range(2):
#     line = lines.Line2D(xdata=[i*2+.5,i*2+.5], ydata=[-.12*scale,-.15*scale],color='k', lw=2,
#                         linestyle='-', alpha=.8,clip_on=False)
#     a.add_line(line)
    
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

# l=a.legend(fontsize=18,bbox_to_anchor=(.6,.95),ncol=2,loc=10,
#           handletextpad=.4,columnspacing=.7,framealpha=1)
# l.set_visible(True)

f.subplots_adjust(top=.88,bottom=.16,right=.93,left=.22)
f.savefig(outfile,dpi=200)

plt.show()
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:28: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:37: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.

# %% [markdown]
# #### ICB response by low chromatin genes IMVIGOR

# %%
#Response by low BIGBETS DDR genes
df_low=bigbets.bipartite_helper_functions.get_percents_bar_by_group(imvigor.clinical_bigbets_df,['high_TMB','chromatin_lowz'],'binaryResponse')
outfile=os.path.join(supplements_dir,"R1_Figure_S5B_imvigor_response_by_low_zscore_chromatin_mut_tmb.pdf")


plt.close()
f,a=plt.subplots(1,1,figsize=(4,5))

pivot=df_low.loc[:,['Response','group','percent']].pivot(index='group',columns='Response',values='percent')
pivot=pivot.loc[['TMB-L_WT','TMB-L_MUT','TMB-H_WT','TMB-H_MUT'],:]
stat,pval,_,_=stats.chi2_contingency(df_low.groupby(['group','Response'])['count'].max().unstack(fill_value=0))

ctab_false=df_low.groupby(['group','Response'])['count'].max().unstack().loc[['TMB-L_WT','TMB-L_MUT'],:]
ctab_true=df_low.groupby(['group','Response'])['count'].max().unstack().loc[['TMB-H_WT','TMB-H_MUT'],:]
s1,pval1=stats.fisher_exact(ctab_false,'less')
s2,pval2=stats.fisher_exact(ctab_true,'less')

a.bar(x=range(pivot.shape[0]),height=pivot['CR/PR'],color=blue)
a.set_ylim([0,1.2])
a.set_ylim([0,.8])
a.set_title("Low BiG-BETS\n Chromatin Remodel. Pts\n(IMvigor210)",fontsize=18)


# a.text(x=.025,y=.85,s=r"p={:.2e}".format(pval1),
#        fontsize=16,transform=a.transAxes)
a.annotate(s='n.s',fontsize=18,xy=(.25,.32),xytext=(.25,.35),
           arrowprops=dict(arrowstyle='-[, widthB=1.5, lengthB=0', lw=1.0),
           xycoords='axes fraction',horizontalalignment='center',transform=a.transAxes)

if pval2<.05:
    a.annotate(s=r"p={:.3f}".format(pval2),fontsize=18,xy=(.75,.86),xytext=(.75,.895),
           arrowprops=dict(arrowstyle='-[, widthB=1.5, lengthB=0', lw=1.0),
           xycoords='axes fraction',horizontalalignment='center',transform=a.transAxes)
else:
    a.annotate(s=r"n.s.".format(pval2),fontsize=18,xy=(.75,.86),xytext=(.75,.895),
           arrowprops=dict(arrowstyle='-[, widthB=1.5, lengthB=0', lw=1.0),
           xycoords='axes fraction',horizontalalignment='center',transform=a.transAxes)

# a.text(x=.57,y=.85,s=r"p={:.2e}".format(pval2),
#        fontsize=16,transform=a.transAxes)

a.set_xlabel("")
a.set_ylabel("% response (CR/PR)",fontsize=18)

    
a.get_xaxis().set_visible(False)
scale=.93

a.text(s="TMB-L",x=.5,y=-.19*scale,fontsize=20,horizontalalignment='center')     
a.text(s="TMB-H",x=2.5,y=-.19*scale,fontsize=20,horizontalalignment='center') 

a.text(s="WT",x=0,y=-.07*scale,fontsize=20,horizontalalignment='center')     
a.text(s="MUT",x=1,y=-.07*scale,fontsize=20,horizontalalignment='center')
a.text(s="WT",x=2,y=-.07*scale,fontsize=20,horizontalalignment='center')     
a.text(s="MUT",x=3,y=-.07*scale,fontsize=20,horizontalalignment='center')

#tick marks 

# for i in range(4):
#     line = lines.Line2D(xdata=[i,i], ydata=[0*scale,-.03*scale],color='k', lw=2,
#                         linestyle='-', alpha=.8,clip_on=False)
#     a.add_line(line)
    
# for i in range(4):
#     line = lines.Line2D(xdata=[i,i], ydata=[-.067*scale,-.12*scale],color='k', lw=2,
#                         linestyle='-', alpha=.8,clip_on=False)
#     a.add_line(line)
    
for i in range(2):
    line = lines.Line2D(xdata=[i*2-.2,i*2+1.2], ydata=[-.1*scale,-.1*scale],color='k', lw=2,
                        linestyle='-', alpha=.8,clip_on=False)
    a.add_line(line)
# for i in range(2):
#     line = lines.Line2D(xdata=[i*2+.5,i*2+.5], ydata=[-.12*scale,-.15*scale],color='k', lw=2,
#                         linestyle='-', alpha=.8,clip_on=False)
#     a.add_line(line)
    
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

# l=a.legend(fontsize=18,bbox_to_anchor=(.6,.95),ncol=2,loc=10,
#           handletextpad=.4,columnspacing=.7,framealpha=1)
# l.set_visible(True)

f.subplots_adjust(top=.8,bottom=.16,right=.92,left=.22)
f.savefig(outfile,dpi=200)

plt.show()
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:28: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:37: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.

# %% [markdown]
# ## Gene signatures analysis

# %%
def get_gene_signature(df,sig_genes):
    sig_means=np.mean(df.loc[:,sig_genes],axis=1)
    sig_means=(sig_means-np.median(sig_means))/np.std(sig_means)
    return sig_means


imvigor_ig_signatures=pd.DataFrame(index=imvigor.rnaseq_log_robust_filtered.index)

for sig,genes in imvigor.gene_sigs.items():
    cgenes=np.array(genes)[np.where(np.isin(genes,imvigor.rnaseq_log_robust_filtered.columns))[0]]
    imvigor_ig_signatures.loc[:,sig]=get_gene_signature(imvigor.rnaseq_log_robust_filtered,cgenes)
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/numpy/lib/function_base.py:3405: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %% [markdown]
# ### Gene signatures for Low BIG-BETS DDR genes

# %%
# TMB H low BIG bets DDR
outfile=os.path.join(graphics_dir,'R1_Figure_4A-D_IMVigor210_signatures_by_low_z-ddrmut.pdf')


high_TMB_samps=imvigor.clinical_bigbets_df.loc[imvigor.clinical_bigbets_df['high_TMB']=='TMB-H',:]
design_mat=(high_TMB_samps.loc[:,'DDR_low_z']=='MUT').to_frame(name='DDRlowmutated')
design_mat=design_mat.loc[design_mat.index.isin(imvigor_ig_signatures.index),:]


signatures_2_show={"ISHIKAWA STING Signaling":['ISHIKAWA_STING_SIGNALING'],
                   "Grandvaux IRF3 Targets UP":['GRANDVAUX_IRF3_TARGETS_UP'],
                  'T-cell':['13_T_Cell_EntrezID','18_Iglesia_CD8_cluster_EntrezID','25_Bindea_CD8_T_cells_EntrezID'],
                   'Immune Microenvironment':['EMT_stroma_core_18','FTBRS'],
                    'INFG':['50_HALLMARK_INFN_GAMMA_RESPONSE','Ayers_IFNG',"Higgs_IFNG"]}

sigs2names={'ISHIKAWA_STING_SIGNALING':"ISHIKAWA STING\nSIGNALING",
                  'GRANDVAUX_IRF3_TARGETS_UP':"GRANDVAUX IRF3\nTargets UP",
                  '13_T_Cell_EntrezID':'T_Cell',
                  '18_Iglesia_CD8_cluster_EntrezID':'Iglesia CD8\nCluster',
                  '25_Bindea_CD8_T_cells_EntrezID':"Bindea CD8\nT_cells",
                  'EMT_stroma_core_18':'EMT_stroma\nCore_18',
                  'FTBRS':'FTBRS',
                  '50_HALLMARK_INFN_GAMMA_RESPONSE':"Hallmark_IFN\nGamma_Response",
                  'Ayers_IFNG':'Ayers_IFNG','Higgs_IFNG':'Higgs_IFNG'}

letters=['D',"",'E','F','G']

all_sigs2show = [val for vals in signatures_2_show.values() for val in vals ]


plt.close()

pvals_df=pd.DataFrame(columns=['mwu_stat','mwu_pval'])
cols=sbn.color_palette('Set1',n_colors=2)
cols.reverse()
# cols=[blue,red]

ncols=len(all_sigs2show)*3

f=plt.gcf()
f.set_size_inches(23,6)

ii=0
cnt=0

colwidths={0:4,1:4,2:8,3:6,4:8}


for name,sig_set in signatures_2_show.items():
    print(ii,name)
    a=plt.subplot2grid((1,ncols),(0,cnt),colspan=colwidths[ii])
    combined_df=pd.DataFrame()
    for i,sig in enumerate(sig_set):
        cdf=imvigor_ig_signatures.loc[:,[sig]]
        cdf.columns=['score']
        cdf.loc[:,'sample']=cdf.index.values
        cdf.loc[:,'IG_signature']=sig
        cdf.loc[design_mat.index,'lowzDDR_mut']=design_mat['DDRlowmutated'].apply(lambda x:  'MUT' if x else 'WT')
        
        mwu,pval=stats.mannwhitneyu(cdf[cdf['lowzDDR_mut']=='WT']['score'],
                                   cdf[cdf['lowzDDR_mut']=='MUT']['score'])
        pvals_df.loc[sig,['mwu_stat','mwu_pval']]=mwu,pval
        combined_df=pd.concat([combined_df,cdf])
    
    
    bp=sbn.boxplot(data=combined_df,x='IG_signature',palette=cols,
               y='score',hue='lowzDDR_mut',ax=a,fliersize=0)
    
#     adjust_box_widths(f, 0.9)
    
    a.set_ylim([-3,6])
    a.spines['right'].set_visible(False)
    a.spines['top'].set_visible(False)
    
    for i,sig in enumerate(combined_df['IG_signature'].unique()):
        ymax=combined_df[combined_df['IG_signature']==sig]['score'].max()
        pval=pvals_df.loc[sig,'mwu_pval']
        print(sig,pval)
        if pval<.05:
            a.text(s="p={:.1e}*".format(pval),horizontalalignment='center',fontsize=18,
              x=i,y=4)
        else:
#             a.text(s="{:.1e}".format(pval),horizontalalignment='center',fontsize=18,
#               x=i,y=4)
            a.text(s="n.s.".format(pval),horizontalalignment='center',fontsize=18,
              x=i,y=4)
    
        a.text(s="{:}".format(sigs2names[sig]),horizontalalignment='center',fontsize=16,
          x=i,y=6)
        

    a.set_ylabel('z-score',fontsize=18)
    
    a.get_legend().set_visible(False)
        
    a.text(s=letters[ii],x=0,y=1.02,horizontalalignment='center',transform=a.transAxes,
           fontsize=14,fontweight='bold')
    new_labs=['WT','MUT']*len(sig_set)
    new_ticks=[j for jj in [[j-.24,j+.24] for j in range(len(sig_set))] for j in jj]
    a.set_xticks(new_ticks)        
    a.set_xticklabels(new_labs,fontsize=14)
    a.set_xlabel("")
    
    for j in range(1,len(sig_set)+1):
        xcoord=j/len(sig_set)-.5/len(sig_set)
        a.annotate(s='Low BiG-BET DDR',fontsize=12,xy=(xcoord,-.07),xytext=(xcoord,-.11),
           arrowprops=dict(arrowstyle='-[, widthB=4, lengthB=0', lw=1.0),
           xycoords='axes fraction',verticalalignment='center',horizontalalignment='center',transform=a.transAxes)
    cnt+=colwidths[ii]
    ii+=1

f.subplots_adjust(left=0.035,right=.98,bottom=.12,top=.9,wspace=3)
# f.suptitle("IMVigor210 Expression Data (TMB-H)",x=.5,y=1.05,fontsize=18,fontweight='bold')
f.savefig(outfile,dpi=200)

plt.show()
# Out:
# 0 ISHIKAWA STING Signaling
# ISHIKAWA_STING_SIGNALING 0.008343930123629254
# 1 Grandvaux IRF3 Targets UP
# GRANDVAUX_IRF3_TARGETS_UP 0.04572591888288001
# 2 T-cell
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:108: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:108: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# ...

# %%
#WRITE OUT SIGNATURES USED TO EXCEL SHEET 
out_df=pd.DataFrame()
sigs=[]
for k,val in signatures_2_show.items():
    for v in val:
        sigs.append(v)
        genes=imvigor.gene_sigs[v]
        out_df.loc[out_df.shape[0],range(len(genes))]=genes
out_df.index=sigs

outfile=os.path.join(dropdir,"gene_expression_signatures.csv")
out_df.to_csv(outfile)

# %%
#TMB - L LOw BiGBETS
outfile=os.path.join(graphics_dir,'IMVigor210_signatures_by_TMB-L_low_z-ddrmut.pdf')


low_TMB_samps=imvigor.clinical_bigbets_df.loc[imvigor.clinical_bigbets_df['high_TMB']=='TMB-L',:]
design_mat=(low_TMB_samps.loc[:,'DDR_low_z']=='MUT').to_frame(name='DDRlowmutated')
design_mat=design_mat.loc[design_mat.index.isin(imvigor_ig_signatures.index),:]


signatures_2_show={"ISHIKAWA STING Signaling":['ISHIKAWA_STING_SIGNALING'],
                   "Grandvaux IRF3 Targets UP":['GRANDVAUX_IRF3_TARGETS_UP'],
                  'T-cell':['13_T_Cell_EntrezID','18_Iglesia_CD8_cluster_EntrezID','25_Bindea_CD8_T_cells_EntrezID'],
                   'Immune Microenvironment':['EMT_stroma_core_18','FTBRS'],
                    'INFG':['50_HALLMARK_INFN_GAMMA_RESPONSE','Ayers_IFNG',"Higgs_IFNG"]}

sigs2names={'ISHIKAWA_STING_SIGNALING':"ISHIKAWA STING\nSIGNALING",
                  'GRANDVAUX_IRF3_TARGETS_UP':"GRANDVAUX IRF3\nTargets UP",
                  '13_T_Cell_EntrezID':'T_Cell',
                  '18_Iglesia_CD8_cluster_EntrezID':'Iglesia CD8\nCluster',
                  '25_Bindea_CD8_T_cells_EntrezID':"Bindea CD8\nT_cells",
                  'EMT_stroma_core_18':'EMT_stroma\nCore_18',
                  'FTBRS':'FTBRS',
                  '50_HALLMARK_INFN_GAMMA_RESPONSE':"Hallmark_IFN\nGamma_Response",
                  'Ayers_IFNG':'Ayers_IFNG','Higgs_IFNG':'Higgs_IFNG'}

letters=['D',"",'E','F','G']

all_sigs2show = [val for vals in signatures_2_show.values() for val in vals ]


plt.close()

pvals_df=pd.DataFrame(columns=['mwu_stat','mwu_pval'])
cols=sbn.color_palette('Set1',n_colors=2)
cols.reverse()
# cols=[blue,red]

ncols=len(all_sigs2show)*3

f=plt.gcf()
f.set_size_inches(23,6)

ii=0
cnt=0

colwidths={0:4,1:4,2:8,3:6,4:8}


for name,sig_set in signatures_2_show.items():
    print(ii,name)
    a=plt.subplot2grid((1,ncols),(0,cnt),colspan=colwidths[ii])
    combined_df=pd.DataFrame()
    for i,sig in enumerate(sig_set):
        cdf=imvigor_ig_signatures.loc[:,[sig]]
        cdf.columns=['score']
        cdf.loc[:,'sample']=cdf.index.values
        cdf.loc[:,'IG_signature']=sig
        cdf.loc[design_mat.index,'lowzDDR_mut']=design_mat['DDRlowmutated'].apply(lambda x:  'MUT' if x else 'WT')
        
        mwu,pval=stats.mannwhitneyu(cdf[cdf['lowzDDR_mut']=='WT']['score'],
                                   cdf[cdf['lowzDDR_mut']=='MUT']['score'])
        pvals_df.loc[sig,['mwu_stat','mwu_pval']]=mwu,pval
        combined_df=pd.concat([combined_df,cdf])
    
    
    bp=sbn.boxplot(data=combined_df,x='IG_signature',palette=cols,
               y='score',hue='lowzDDR_mut',ax=a,fliersize=0)
    
#     adjust_box_widths(f, 0.9)
    
    a.set_ylim([-3,6])
    a.spines['right'].set_visible(False)
    a.spines['top'].set_visible(False)
    
    for i,sig in enumerate(combined_df['IG_signature'].unique()):
        ymax=combined_df[combined_df['IG_signature']==sig]['score'].max()
        pval=pvals_df.loc[sig,'mwu_pval']
        print(sig,pval)
        if pval<.05:
            a.text(s="p={:.1e}*".format(pval),horizontalalignment='center',fontsize=18,
              x=i,y=4)
        else:
#             a.text(s="{:.1e}".format(pval),horizontalalignment='center',fontsize=18,
#               x=i,y=4)
            a.text(s="n.s.".format(pval),horizontalalignment='center',fontsize=18,
              x=i,y=4)
    
        a.text(s="{:}".format(sigs2names[sig]),horizontalalignment='center',fontsize=16,
          x=i,y=6)
        

    a.set_ylabel('z-score',fontsize=18)
    
    a.get_legend().set_visible(False)
        
    a.text(s=letters[ii],x=0,y=1.02,horizontalalignment='center',transform=a.transAxes,
           fontsize=14,fontweight='bold')
    new_labs=['WT','MUT']*len(sig_set)
    new_ticks=[j for jj in [[j-.24,j+.24] for j in range(len(sig_set))] for j in jj]
    a.set_xticks(new_ticks)        
    a.set_xticklabels(new_labs,fontsize=14)
    a.set_xlabel("")
    
    for j in range(1,len(sig_set)+1):
        xcoord=j/len(sig_set)-.5/len(sig_set)
        a.annotate(s='Low BiG-BET DDR',fontsize=12,xy=(xcoord,-.07),xytext=(xcoord,-.11),
           arrowprops=dict(arrowstyle='-[, widthB=4, lengthB=0', lw=1.0),
           xycoords='axes fraction',verticalalignment='center',horizontalalignment='center',transform=a.transAxes)
    cnt+=colwidths[ii]
    ii+=1

f.subplots_adjust(left=0.035,right=.98,bottom=.12,top=.9,wspace=3)
# f.suptitle("IMVigor210 Expression Data (TMB-H)",x=.5,y=1.05,fontsize=18,fontweight='bold')
f.savefig(outfile,dpi=200)

plt.show()
# Out:
# 0 ISHIKAWA STING Signaling
# ISHIKAWA_STING_SIGNALING 0.1527275450146386
# 1 Grandvaux IRF3 Targets UP
# GRANDVAUX_IRF3_TARGETS_UP 0.4108352037594583
# 2 T-cell
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:108: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:108: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# ...

# %%
#TMB -H High BIG-BETS
outfile=os.path.join(supplements_dir,'IMVigor210_signatures_by_high_z-ddrmut.pdf')


high_TMB_samps=imvigor.clinical_bigbets_df.loc[imvigor.clinical_bigbets_df['high_TMB']=='TMB-H',:]
design_mat=(high_TMB_samps.loc[:,'DDR_high_z']=='MUT').to_frame(name='DDRhighmutated')
design_mat=design_mat.loc[design_mat.index.isin(imvigor_ig_signatures.index),:]


signatures_2_show={"ISHIKAWA STING Signaling":['ISHIKAWA_STING_SIGNALING'],
                   "Grandvaux IRF3 Targets UP":['GRANDVAUX_IRF3_TARGETS_UP'],
                  'T-cell':['13_T_Cell_EntrezID','18_Iglesia_CD8_cluster_EntrezID','25_Bindea_CD8_T_cells_EntrezID'],
                   'Immune Microenvironment':['EMT_stroma_core_18','FTBRS'],
                    'INFG':['50_HALLMARK_INFN_GAMMA_RESPONSE','Ayers_IFNG',"Higgs_IFNG"]}

sigs2names={'ISHIKAWA_STING_SIGNALING':"ISHIKAWA STING\nSIGNALING",
                  'GRANDVAUX_IRF3_TARGETS_UP':"GRANDVAUX IRF3\nTargets UP",
                  '13_T_Cell_EntrezID':'T_Cell',
                  '18_Iglesia_CD8_cluster_EntrezID':'Iglesia CD8\nCluster',
                  '25_Bindea_CD8_T_cells_EntrezID':"Bindea CD8\nT_cells",
                  'EMT_stroma_core_18':'EMT_stroma\nCore_18',
                  'FTBRS':'FTBRS',
                  '50_HALLMARK_INFN_GAMMA_RESPONSE':"Hallmark_IFN\nGamma_Response",
                  'Ayers_IFNG':'Ayers_IFNG','Higgs_IFNG':'Higgs_IFNG'}

letters=['D',"",'E','F','G']

all_sigs2show = [val for vals in signatures_2_show.values() for val in vals ]


plt.close()

pvals_df=pd.DataFrame(columns=['mwu_stat','mwu_pval'])
cols=sbn.color_palette('Set1',n_colors=2)
cols.reverse()
# cols=[blue,red]

ncols=len(all_sigs2show)*3

f=plt.gcf()
f.set_size_inches(23,6)

ii=0
cnt=0

colwidths={0:4,1:4,2:8,3:6,4:8}


for name,sig_set in signatures_2_show.items():
    print(ii,name)
    a=plt.subplot2grid((1,ncols),(0,cnt),colspan=colwidths[ii])
    combined_df=pd.DataFrame()
    for i,sig in enumerate(sig_set):
        cdf=imvigor_ig_signatures.loc[:,[sig]]
        cdf.columns=['score']
        cdf.loc[:,'sample']=cdf.index.values
        cdf.loc[:,'IG_signature']=sig
        cdf.loc[design_mat.index,'highzDDR_mut']=design_mat['DDRhighmutated'].apply(lambda x:  'MUT' if x else 'WT')
        
        mwu,pval=stats.mannwhitneyu(cdf[cdf['highzDDR_mut']=='WT']['score'],
                                   cdf[cdf['highzDDR_mut']=='MUT']['score'])
        pvals_df.loc[sig,['mwu_stat','mwu_pval']]=mwu,pval
        combined_df=pd.concat([combined_df,cdf])
    
    
    bp=sbn.boxplot(data=combined_df,x='IG_signature',palette=cols,
               y='score',hue='highzDDR_mut',ax=a,fliersize=0)
    
#     adjust_box_widths(f, 0.9)
    
    a.set_ylim([-3,6])
    a.spines['right'].set_visible(False)
    a.spines['top'].set_visible(False)
    
    for i,sig in enumerate(combined_df['IG_signature'].unique()):
        ymax=combined_df[combined_df['IG_signature']==sig]['score'].max()
        pval=pvals_df.loc[sig,'mwu_pval']
        print(sig,pval)
        if pval<.05:
            a.text(s="p={:.1e}*".format(pval),horizontalalignment='center',fontsize=18,
              x=i,y=4)
        else:
#             a.text(s="{:.1e}".format(pval),horizontalalignment='center',fontsize=18,
#               x=i,y=4)
            a.text(s="n.s.".format(pval),horizontalalignment='center',fontsize=18,
              x=i,y=4)
    
        a.text(s="{:}".format(sigs2names[sig]),horizontalalignment='center',fontsize=16,
          x=i,y=6)
        

    a.set_ylabel('z-score',fontsize=18)
    
    a.get_legend().set_visible(False)
        
    a.text(s=letters[ii],x=0,y=1.02,horizontalalignment='center',transform=a.transAxes,
           fontsize=14,fontweight='bold')
    new_labs=['WT','MUT']*len(sig_set)
    new_ticks=[j for jj in [[j-.24,j+.24] for j in range(len(sig_set))] for j in jj]
    a.set_xticks(new_ticks)        
    a.set_xticklabels(new_labs,fontsize=14)
    a.set_xlabel("")
    
    for j in range(1,len(sig_set)+1):
        xcoord=j/len(sig_set)-.5/len(sig_set)
        a.annotate(s='High BiG-BET DDR',fontsize=12,xy=(xcoord,-.07),xytext=(xcoord,-.11),
           arrowprops=dict(arrowstyle='-[, widthB=4, lengthB=0', lw=1.0),
           xycoords='axes fraction',verticalalignment='center',horizontalalignment='center',transform=a.transAxes)
    cnt+=colwidths[ii]
    ii+=1

f.subplots_adjust(left=0.035,right=.98,bottom=.12,top=.9,wspace=3)
# f.suptitle("IMVigor210 Expression Data (TMB-H)",x=.5,y=1.05,fontsize=18,fontweight='bold')
f.savefig(outfile,dpi=200)

plt.show()
# Out:
# 0 ISHIKAWA STING Signaling
# ISHIKAWA_STING_SIGNALING 0.2536609650276992
# 1 Grandvaux IRF3 Targets UP
# GRANDVAUX_IRF3_TARGETS_UP 0.48565015988580446
# 2 T-cell
# 13_T_Cell_EntrezID 0.3847765778362082
# 18_Iglesia_CD8_cluster_EntrezID 0.4651871702993259
# 25_Bindea_CD8_T_cells_EntrezID 0.420565920113114
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:108: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:108: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# ...

# %%
#TMB - L high BIG-BETS
outfile=os.path.join(supplements_dir,'IMVigor210_signatures_TMB-L_by_high_z-ddrmut.pdf')


high_TMB_samps=imvigor.clinical_bigbets_df.loc[imvigor.clinical_bigbets_df['high_TMB']=='TMB-L',:]
design_mat=(high_TMB_samps.loc[:,'DDR_high_z']=='MUT').to_frame(name='DDRhighmutated')
design_mat=design_mat.loc[design_mat.index.isin(imvigor_ig_signatures.index),:]


signatures_2_show={"ISHIKAWA STING Signaling":['ISHIKAWA_STING_SIGNALING'],
                   "Grandvaux IRF3 Targets UP":['GRANDVAUX_IRF3_TARGETS_UP'],
                  'T-cell':['13_T_Cell_EntrezID','18_Iglesia_CD8_cluster_EntrezID','25_Bindea_CD8_T_cells_EntrezID'],
                   'Immune Microenvironment':['EMT_stroma_core_18','FTBRS'],
                    'INFG':['50_HALLMARK_INFN_GAMMA_RESPONSE','Ayers_IFNG',"Higgs_IFNG"]}

sigs2names={'ISHIKAWA_STING_SIGNALING':"ISHIKAWA STING\nSIGNALING",
                  'GRANDVAUX_IRF3_TARGETS_UP':"GRANDVAUX IRF3\nTargets UP",
                  '13_T_Cell_EntrezID':'T_Cell',
                  '18_Iglesia_CD8_cluster_EntrezID':'Iglesia CD8\nCluster',
                  '25_Bindea_CD8_T_cells_EntrezID':"Bindea CD8\nT_cells",
                  'EMT_stroma_core_18':'EMT_stroma\nCore_18',
                  'FTBRS':'FTBRS',
                  '50_HALLMARK_INFN_GAMMA_RESPONSE':"Hallmark_IFN\nGamma_Response",
                  'Ayers_IFNG':'Ayers_IFNG','Higgs_IFNG':'Higgs_IFNG'}

letters=['D',"",'E','F','G']

all_sigs2show = [val for vals in signatures_2_show.values() for val in vals ]


plt.close()

pvals_df=pd.DataFrame(columns=['mwu_stat','mwu_pval'])
cols=sbn.color_palette('Set1',n_colors=2)
cols.reverse()
# cols=[blue,red]

ncols=len(all_sigs2show)*3

f=plt.gcf()
f.set_size_inches(23,6)

ii=0
cnt=0

colwidths={0:4,1:4,2:8,3:6,4:8}


for name,sig_set in signatures_2_show.items():
    print(ii,name)
    a=plt.subplot2grid((1,ncols),(0,cnt),colspan=colwidths[ii])
    combined_df=pd.DataFrame()
    for i,sig in enumerate(sig_set):
        cdf=imvigor_ig_signatures.loc[:,[sig]]
        cdf.columns=['score']
        cdf.loc[:,'sample']=cdf.index.values
        cdf.loc[:,'IG_signature']=sig
        cdf.loc[design_mat.index,'highzDDR_mut']=design_mat['DDRhighmutated'].apply(lambda x:  'MUT' if x else 'WT')
        
        mwu,pval=stats.mannwhitneyu(cdf[cdf['highzDDR_mut']=='WT']['score'],
                                   cdf[cdf['highzDDR_mut']=='MUT']['score'])
        pvals_df.loc[sig,['mwu_stat','mwu_pval']]=mwu,pval
        combined_df=pd.concat([combined_df,cdf])
    
    
    bp=sbn.boxplot(data=combined_df,x='IG_signature',palette=cols,
               y='score',hue='highzDDR_mut',ax=a,fliersize=0)
    
#     adjust_box_widths(f, 0.9)
    
    a.set_ylim([-3,6])
    a.spines['right'].set_visible(False)
    a.spines['top'].set_visible(False)
    
    for i,sig in enumerate(combined_df['IG_signature'].unique()):
        ymax=combined_df[combined_df['IG_signature']==sig]['score'].max()
        pval=pvals_df.loc[sig,'mwu_pval']
        print(sig,pval)
        if pval<.05:
            a.text(s="p={:.1e}*".format(pval),horizontalalignment='center',fontsize=18,
              x=i,y=4)
        else:
#             a.text(s="{:.1e}".format(pval),horizontalalignment='center',fontsize=18,
#               x=i,y=4)
            a.text(s="n.s.".format(pval),horizontalalignment='center',fontsize=18,
              x=i,y=4)
    
        a.text(s="{:}".format(sigs2names[sig]),horizontalalignment='center',fontsize=16,
          x=i,y=6)
        

    a.set_ylabel('z-score',fontsize=18)
    
    a.get_legend().set_visible(False)
        
    a.text(s=letters[ii],x=0,y=1.02,horizontalalignment='center',transform=a.transAxes,
           fontsize=14,fontweight='bold')
    new_labs=['WT','MUT']*len(sig_set)
    new_ticks=[j for jj in [[j-.24,j+.24] for j in range(len(sig_set))] for j in jj]
    a.set_xticks(new_ticks)        
    a.set_xticklabels(new_labs,fontsize=14)
    a.set_xlabel("")
    
    for j in range(1,len(sig_set)+1):
        xcoord=j/len(sig_set)-.5/len(sig_set)
        a.annotate(s='High BiG-BET DDR',fontsize=12,xy=(xcoord,-.07),xytext=(xcoord,-.11),
           arrowprops=dict(arrowstyle='-[, widthB=4, lengthB=0', lw=1.0),
           xycoords='axes fraction',verticalalignment='center',horizontalalignment='center',transform=a.transAxes)
    cnt+=colwidths[ii]
    ii+=1

f.subplots_adjust(left=0.035,right=.98,bottom=.12,top=.9,wspace=3)
# f.suptitle("IMVigor210 Expression Data (TMB-H)",x=.5,y=1.05,fontsize=18,fontweight='bold')
f.savefig(outfile,dpi=200)

plt.show()
# Out:
# 0 ISHIKAWA STING Signaling
# ISHIKAWA_STING_SIGNALING 0.4814569389850556
# 1 Grandvaux IRF3 Targets UP
# GRANDVAUX_IRF3_TARGETS_UP 0.4691146787758295
# 2 T-cell
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:108: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:108: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# ...

# %% [markdown]
# ### Genes signatures for low chromatin remodeling genes

# %%
#chromatin remodeling genes
outfile=os.path.join(supplements_dir,'IMVigor210_signatures_by_low_z-chromatin_remodmut.pdf')


high_TMB_samps=imvigor.clinical_bigbets_df.loc[imvigor.clinical_bigbets_df['high_TMB']=='TMB-H',:]
design_mat=(high_TMB_samps.loc[:,'chromatin_lowz']=='MUT').to_frame(name='ChromatinRemodlowmutated')
design_mat=design_mat.loc[design_mat.index.isin(imvigor_ig_signatures.index),:]


signatures_2_show={"ISHIKAWA STING Signaling":['ISHIKAWA_STING_SIGNALING'],
                   "Grandvaux IRF3 Targets UP":['GRANDVAUX_IRF3_TARGETS_UP'],
                  'T-cell':['13_T_Cell_EntrezID','18_Iglesia_CD8_cluster_EntrezID','25_Bindea_CD8_T_cells_EntrezID'],
                   'Immune Microenvironment':['EMT_stroma_core_18','FTBRS'],
                    'INFG':['50_HALLMARK_INFN_GAMMA_RESPONSE','Ayers_IFNG',"Higgs_IFNG"]}

sigs2names={'ISHIKAWA_STING_SIGNALING':"ISHIKAWA STING\nSIGNALING",
                  'GRANDVAUX_IRF3_TARGETS_UP':"GRANDVAUX IRF3\nTargets UP",
                  '13_T_Cell_EntrezID':'T_Cell',
                  '18_Iglesia_CD8_cluster_EntrezID':'Iglesia CD8\nCluster',
                  '25_Bindea_CD8_T_cells_EntrezID':"Bindea CD8\nT_cells",
                  'EMT_stroma_core_18':'EMT_stroma\nCore_18',
                  'FTBRS':'FTBRS',
                  '50_HALLMARK_INFN_GAMMA_RESPONSE':"Hallmark_IFN\nGamma_Response",
                  'Ayers_IFNG':'Ayers_IFNG','Higgs_IFNG':'Higgs_IFNG'}

letters=['D',"",'E','F','G']

all_sigs2show = [val for vals in signatures_2_show.values() for val in vals ]


plt.close()

pvals_df=pd.DataFrame(columns=['mwu_stat','mwu_pval'])
cols=sbn.color_palette('Set1',n_colors=2)
cols.reverse()
# cols=[blue,red]

ncols=len(all_sigs2show)*3

f=plt.gcf()
f.set_size_inches(23,6)

ii=0
cnt=0

colwidths={0:4,1:4,2:8,3:6,4:8}


for name,sig_set in signatures_2_show.items():
    print(ii,name)
    a=plt.subplot2grid((1,ncols),(0,cnt),colspan=colwidths[ii])
    combined_df=pd.DataFrame()
    for i,sig in enumerate(sig_set):
        cdf=imvigor_ig_signatures.loc[:,[sig]]
        cdf.columns=['score']
        cdf.loc[:,'sample']=cdf.index.values
        cdf.loc[:,'IG_signature']=sig
        cdf.loc[design_mat.index,'lowzDDR_mut']=design_mat['ChromatinRemodlowmutated'].apply(lambda x:  'MUT' if x else 'WT')
        
        mwu,pval=stats.mannwhitneyu(cdf[cdf['lowzDDR_mut']=='WT']['score'],
                                   cdf[cdf['lowzDDR_mut']=='MUT']['score'])
        pvals_df.loc[sig,['mwu_stat','mwu_pval']]=mwu,pval
        combined_df=pd.concat([combined_df,cdf])
    
    
    bp=sbn.boxplot(data=combined_df,x='IG_signature',palette=cols,
               y='score',hue='lowzDDR_mut',ax=a,fliersize=0)
    
#     adjust_box_widths(f, 0.9)
    
    a.set_ylim([-3,6])
    a.spines['right'].set_visible(False)
    a.spines['top'].set_visible(False)
    
    for i,sig in enumerate(combined_df['IG_signature'].unique()):
        ymax=combined_df[combined_df['IG_signature']==sig]['score'].max()
        pval=pvals_df.loc[sig,'mwu_pval']
        print(sig,pval)
        if pval<.05:
            a.text(s="p={:.1e}*".format(pval),horizontalalignment='center',fontsize=18,
              x=i,y=4)
        else:
#             a.text(s="{:.1e}".format(pval),horizontalalignment='center',fontsize=18,
#               x=i,y=4)
            a.text(s="n.s.".format(pval),horizontalalignment='center',fontsize=18,
              x=i,y=4)
    
        a.text(s="{:}".format(sigs2names[sig]),horizontalalignment='center',fontsize=16,
          x=i,y=6)
        

    a.set_ylabel('z-score',fontsize=18)
    
    a.get_legend().set_visible(False)
        
    a.text(s=letters[ii],x=0,y=1.02,horizontalalignment='center',transform=a.transAxes,
           fontsize=14,fontweight='bold')
    new_labs=['WT','MUT']*len(sig_set)
    new_ticks=[j for jj in [[j-.24,j+.24] for j in range(len(sig_set))] for j in jj]
    a.set_xticks(new_ticks)        
    a.set_xticklabels(new_labs,fontsize=14)
    a.set_xlabel("")
    
    for j in range(1,len(sig_set)+1):
        xcoord=j/len(sig_set)-.5/len(sig_set)
        ycoord=-.15 if j%2 == 0 else -.11
        a.annotate(s='Low BiG-BET Chromatin Remod.',fontsize=12,xy=(xcoord,-.07),xytext=(xcoord,ycoord),
           arrowprops=dict(arrowstyle='-[, widthB=4, lengthB=0', lw=1.0),
           xycoords='axes fraction',verticalalignment='center',horizontalalignment='center',transform=a.transAxes)
    cnt+=colwidths[ii]
    ii+=1

f.subplots_adjust(left=0.035,right=.98,bottom=.15,top=.9,wspace=3)
# f.suptitle("IMVigor210 Expression Data (TMB-H)",x=.5,y=1.05,fontsize=18,fontweight='bold')
f.savefig(outfile,dpi=200)

plt.show()
# Out:
# 0 ISHIKAWA STING Signaling
# ISHIKAWA_STING_SIGNALING 0.4588494604409649
# 1 Grandvaux IRF3 Targets UP
# GRANDVAUX_IRF3_TARGETS_UP 0.21969796626589133
# 2 T-cell
# 13_T_Cell_EntrezID 0.1566349175191145
# 18_Iglesia_CD8_cluster_EntrezID 0.13699911703257123
# 25_Bindea_CD8_T_cells_EntrezID 0.0532498224951016
# 3 Immune Microenvironment
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:109: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:109: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# ...

# %% [markdown]
# ## Overlap of DDR genes Samstein and IMVigor

# %%
#overlap of DDR genes
outfile=os.path.join(supplements_dir,"R1_Figure_S3C_overlap_ddr_genes_imvigor_samstein.pdf")
ddr_genes=bigbets.ddr_data_object.myddr_obj.ddr_gene_df.index
ddr_genes_present_samstein=ddr_genes.intersection(samstein.spec_by_genes.columns)
ddr_genes_present_imvigor=ddr_genes.intersection(imvigor.spec_by_genes.columns)

cols=sbn.color_palette('cubehelix',n_colors=3)

# cols=[(.4,0,0,1),(0,1,0,.5),(0,0,1,.5)]
# cols=sbn.cubehelix_palette(n_colors=3)

plt.close()
f,a=plt.subplots(1,1,figsize=(8,6))
a.set_title("Overlap of DDR genes",fontsize=18)
ven=venn.venn3([set(ddr_genes),set(ddr_genes_present_samstein),
                set(ddr_genes_present_imvigor)],
               set_colors=cols,
           ax=a,set_labels=["DDR Core","Samstein et al.","IMVigor210"])
for lab in ven.set_labels:
    lab.set_fontsize(18)
    
for text in ven.subset_labels:
    if text:
        text.set_fontsize(18)
    
alpha=.7
for i,t in enumerate(ven.patches):
    if t:
        t.set_alpha(alpha)

f.tight_layout()
f.savefig(outfile)
plt.show()

# %% [markdown]
# ### Samstein Surival with Overlap DDR Genes

# %%
overlap_genes=list(set(ddr_genes_present_samstein).intersection(ddr_genes_present_imvigor))
scores=bigbets.ClinicalDataSet.bigbet_scores_df.loc[overlap_genes,'bigbets']
low_bigbets_overlap=list(scores.index[scores<0])
mut_samps=samstein.add_big_bets_category(genes=low_bigbets_overlap,label="DDR_low_z_imvigor")

# %%
#low bigbets DDR genes samstein survival analysis
outfile=os.path.join(supplements_dir,'R1_Figure_S5A_samstein_ddr_samstein_overlap_survival_low_zscore.pdf')

cph = lifelines.CoxPHFitter()
# vars2keep=['high_TMB','DDR','DDR:highTMB']
vars2keep=['DDR_low_z_imvigor']

dummy_df=samstein.clinical_bigbets_df.loc[:,['os','censOS']]

for var in vars2keep:
    cdf=pd.get_dummies(samstein.clinical_bigbets_df.loc[:,var])
    cdf.columns=map(lambda x: var+"_"+str(x),cdf.columns.values)
    dummy_df=pd.concat([dummy_df,cdf.iloc[:,:-1]],axis=1)

dummy_df['log(TMB)']=np.log1p(samstein.clinical_bigbets_df.loc[:,'TMB'])
# dummy_df['TMB']=samstein.clinical_bigbets_df.loc[:,'high_TMB']

dummy_df['DDRlowzimvigor:highTMB']=samstein.clinical_bigbets_df.loc[:,'DDRlowzimvigor:highTMB']

res=cph.fit(dummy_df, 'os', event_col='censOS')
llrstat=cph.log_likelihood_ratio_test()
llr=llrstat.test_statistic
df=llrstat.degrees_freedom
p_value=llrstat.p_value
summary=res.summary
print(res.summary)

var='DDR_low_z_TMB'



coms=samstein.clinical_bigbets_df[var].unique()
commap=dict(zip(coms,range(len(coms))))
clust=list(map(lambda x: commap[x],samstein.clinical_bigbets_df[var]))

plt.close()
f,a=plt.subplots(1,2,figsize=(7.5,10))

nrows=10
ncols=1

ncols1=1
nrows1=6

a=plt.subplot2grid((nrows,ncols),(0,0),rowspan=nrows1,colspan=1)

cols = [red + (1.0,), red + (.5,), blue + (1.0,), blue + (.5,)]
cols=[red+(1.0,),red+(.7,),blue+(1.0,),blue+(.7,)]

kmf = lifelines.KaplanMeierFitter()
df2test=samstein.clinical_bigbets_df
i=0
for name,gdf in df2test.groupby(var):
    if re.search("WT",name):
        ls=':'
    else:
        ls='-'
    kmf.fit(gdf["os"], gdf["censOS"], label=name)
    kmf.plot(ax=a,ci_show=False,c=cols[i],linestyle=ls,
             show_censors=True, censor_styles={'ms': 5, 'marker': '+'})
    i+=1
# lg_lines=lg.get_lines()
# for j,ln in enumerate(a.get_lines()):
#     ln.set_color(cols[j])
#     lg_lines[j].set_color(cols[j])

handles, labels = a.get_legend_handles_labels()
new_labels=['Low-BiG-BETS DDR Mut','Low-BiG-BETS DDR WT','Low-BiG-BETS DDR Mut','Low-BiG-BETS DDR WT']
l=a.legend(loc=1,bbox_to_anchor=(.85,1.0),fontsize=14,
           frameon=False,handles=handles,labels=new_labels)
for i,text in enumerate(l.get_texts()):
    plt.setp(text, color = cols[i])
    
a.annotate(s='TMB-H',fontsize=14,xy=(.83,.925),xytext=(.86,.925),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.annotate(s='TMB-L',fontsize=14,xy=(.83,.825),xytext=(.86,.825),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

a.set_xlabel("months",fontsize=20)
a.set_ylabel("overall survival",fontsize=20)

# a.set_title("Kaplan-Meier Curve by TMB + low TMB Assoc.DDR Genes",fontsize=18,fontweight='bold')
pval_df=bigbets.bipartite_helper_functions.get_os_stats(clust=clust,samp_df=samstein.clinical_bigbets_df)
pval=pval_df['llr_pval'].values[0]
a.text(x=.85,y=.05,s="CPH pval={:.1e}".format(pval),horizontalalignment='center',
       fontsize=14,transform=a.transAxes)



a=plt.subplot2grid((nrows,ncols),(nrows1,0),rowspan=nrows-nrows1,colspan=1)
# a=plt.subplot(1,2,2)
# a.text(s='B)',fontsize=18,fontweight='bold',x=0.0,y=.95,transform=a.transAxes)
# a.text(s='B)',fontsize=18,fontweight='bold',x=-.07,y=1.0,transform=a.transAxes)

xlim_min=np.min(summary['coef']-1.96*summary['se(coef)'])
xlim_max=np.max(summary['coef']+1.96*summary['se(coef)'])

for i,ind in enumerate(summary.index):
    expcoef=summary.loc[ind,'exp(coef)']
    up=summary.loc[ind,'exp(coef) upper 95%']-expcoef
    low=expcoef-summary.loc[ind,'exp(coef) lower 95%']
    ebars=np.array([[low,up]]).T
    a.errorbar(x=[expcoef],alpha=.7,
               y=[summary.shape[0]-1-i],marker='s',color='k',uplims=True, lolims=True,
               xerr=ebars
#                xerr=[1.96*summary.loc[ind,'se(coef)'],
                    )

    
a.vlines(x=1.0,linestyle='--',alpha=.6,linewidth=1,color='k',
         ymin=0,ymax=summary.shape[0]-.9)

a.set_xscale('log')
a.set_xlim([.0000025,30])
a.spines['bottom'].set_position(('data', -.4))
a.spines['bottom'].set_bounds( 0.1,5)

a.spines['left'].set_visible(False)
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)
a.set_yticks([])
a.set_xticks([.1,1,5])
a.xaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
plt.minorticks_off()
a.set_ylim([-2,3])


# a.text(s="LLR pval={:.2e}".format(p_value),fontsize=18,
#        x=.2,y=.8,transform=a.transAxes)



axis_to_data = a.transAxes + a.transData.inverted()
data_to_axis = axis_to_data.inverted()

y=data_to_axis.transform((.1,summary.shape[0]-.55))[1]

print('y',y)
a.text(s="Covariate".format(p_value),fontsize=16,
       x=.01,y=y,transform=a.transAxes)

a.text(s="HR (95% CI)".format(p_value),fontsize=16,
       x=.375,y=y,transform=a.transAxes)

a.text(s="P-value".format(p_value),fontsize=16,
       x=.85,y=y,transform=a.transAxes)

a.hlines(y=y-.02,xmin=-2,xmax=50,color='k',transform=a.transAxes,linewidth=3,linestyle='-')
# a.hlines(y=y-.03,xmin=-1,xmax=2,transform=a.transAxes,linewidth=1,linestyle='-')

for i,ind in enumerate(summary.index):
    y=data_to_axis.transform((.1,summary.shape[0]-i-1.2))[1]
    print('y',y)
    if summary.loc[ind,'p']<.05:
        a.text(s="{}*".format(ind),fontsize=14,
       x=-.1,y=y,transform=a.transAxes)
    else:
        a.text(s=ind,fontsize=14,
           x=-.1,y=y,
           transform=a.transAxes)
    hrtext="{:.2f}  ({:.2f}-{:.2f})".format(*summary.loc[ind,['exp(coef)',
                                                         'exp(coef) lower 95%','exp(coef) upper 95%']])
    pvaltext="{:.2e}".format(*summary.loc[ind,['p']])
    a.text(s=hrtext,fontsize=16,
       x=.35,y=y,
           transform=a.transAxes)
    a.text(s=pvaltext,fontsize=16,
       x=.85,y=y,
           transform=a.transAxes)
    
    x1,y1=data_to_axis.transform((.01,summary.shape[0]-i*.9-1.5))
    x2,y2=data_to_axis.transform((.01,summary.shape[0]-i*.9-.8))
    

    if i%2==0:
        crect=patches.Rectangle((-.1,y1),width=1.2,height=y2-y1,transform=a.transAxes,fill=True,
                               alpha=.05,color='k',clip_on=False)
#         crect2=patches.Rectangle((x2,y1),width=1.1-x2,height=y2-y1,transform=a.transAxes,fill=True,
#                                alpha=.05,color='k')
        a.add_patch(crect)
#         a.add_patch(crect2)
        
    
    

# a.set_title("CPH Model Survival",fontsize=18,fontweight='bold')
# cph.plot(ax=a)
a.text(s="Hazard Ratio",fontsize=18,x=1.25,
       y=-1.1,
       horizontalalignment='center')

f.suptitle('Samstein (IMVigor DDR overlap)',fontsize=22,x=.5,y=.97,transform=f.transFigure)

f.subplots_adjust(top=.93,bottom=-.05,right=.95,left=.12,wspace=.0,hspace=1.5)
f.savefig(outfile,dpi=200)
plt.show()
# Out:
#                             coef  exp(coef)  se(coef)  coef lower 95%  \
# DDR_low_z_imvigor_MUT   0.129661   1.138442  0.156599       -0.177268
# log(TMB)               -0.117479   0.889159  0.050196       -0.215861
# DDRlowzimvigor:highTMB -0.606426   0.545296  0.216660       -1.031072
#
#                         coef upper 95%  exp(coef) lower 95%  \
# DDR_low_z_imvigor_MUT         0.436589             0.837555
# log(TMB)                     -0.019097             0.805847
# DDRlowzimvigor:highTMB       -0.181780             0.356625
#
#                         exp(coef) upper 95%         z         p  -log2(p)
# DDR_low_z_imvigor_MUT              1.547420  0.827978  0.407683  1.294481
# log(TMB)                           0.981084 -2.340418  0.019262  5.698087
# DDRlowzimvigor:highTMB             0.833785 -2.798972  0.005127  7.607795
# ...

# %% [markdown]
# # Weir et al Meta-dataset

# %%
weirmeta=bigbets.WeirMetaDataSet()
# Out:
# 2021-12-21 19:43:55,291:root:INFO:loading skcm_dfci_2015 data_mutations_extended.txt
# 2021-12-21 19:43:55,685:root:INFO:loading skcm_dfci_2015 data_mutations_mskcc.txt
# 2021-12-21 19:43:56,231:root:INFO:loading skcm_mskcc_2014 data_mutations_extended.txt
# 2021-12-21 19:43:56,879:root:INFO:loading skcm_mskcc_2014 data_mutations_mskcc.txt
# 2021-12-21 19:43:57,539:root:INFO:loading ccrcc_dfci_2019 data_mutations_extended.txt
# 2021-12-21 19:43:57,925:root:INFO:loading ccrcc_dfci_2019 data_mutations_mskcc.txt
# 2021-12-21 19:43:58,366:root:INFO:loading nsclc_mskcc_2015 data_mutations_extended.txt
# 2021-12-21 19:43:58,819:root:INFO:loading nsclc_mskcc_2015 data_mutations_mskcc.txt
# 2021-12-21 19:43:59,234:root:INFO:loading mel_ucla_2016 data_mutations_extended.txt
# 2021-12-21 19:43:59,884:root:INFO:loading mel_ucla_2016 data_mutations_mskcc.txt
# 2021-12-21 19:44:00,573:root:INFO:loading nsclc_mskcc_2018 data_mutations_extended.txt
# ...

# %% [markdown]
# ## Surival Analysis

# %% [markdown]
# ### Low Big_BETS DDR Mutations

# %%
#low bigbets DDR genes survival analysis
outfile=os.path.join(graphics_dir,'R1_Figure_3D_weirmeta_survival_low_zscore.pdf')

cph = lifelines.CoxPHFitter()
# vars2keep=['high_TMB','DDR','DDR:highTMB']
vars2keep=['DDR_low_z']

dummy_df=weirmeta.clinical_bigbets_df.loc[:,['os','censOS']]

for var in vars2keep:
    cdf=pd.get_dummies(weirmeta.clinical_bigbets_df.loc[:,var])
    cdf.columns=map(lambda x: var+"_"+str(x),cdf.columns.values)
    dummy_df=pd.concat([dummy_df,cdf.iloc[:,:-1]],axis=1)

dummy_df['log(TMB)']=np.log1p(weirmeta.clinical_bigbets_df.loc[:,'TMB'])
# dummy_df['TMB']=weirmeta.clinical_bigbets_df.loc[:,'high_TMB']

dummy_df['DDRlow:highTMB']=weirmeta.clinical_bigbets_df.loc[:,'DDRlowz:highTMB']

res=cph.fit(dummy_df, 'os', event_col='censOS')
llrstat=cph.log_likelihood_ratio_test()
llr=llrstat.test_statistic
df=llrstat.degrees_freedom
p_value=llrstat.p_value
summary=res.summary
print(res.summary)

var='DDR_low_z_TMB'



coms=weirmeta.clinical_bigbets_df[var].unique()
commap=dict(zip(coms,range(len(coms))))
clust=list(map(lambda x: commap[x],weirmeta.clinical_bigbets_df[var]))

plt.close()
f,a=plt.subplots(1,2,figsize=(7.5,10))

nrows=10
ncols=1

ncols1=1
nrows1=6

a=plt.subplot2grid((nrows,ncols),(0,0),rowspan=nrows1,colspan=1)

cols = [red + (1.0,), red + (.5,), blue + (1.0,), blue + (.5,)]
cols=[red+(1.0,),red+(.7,),blue+(1.0,),blue+(.7,)]

kmf = lifelines.KaplanMeierFitter()
df2test=weirmeta.clinical_bigbets_df
i=0
for name,gdf in df2test.groupby(var):
    if re.search("WT",name):
        ls=':'
    else:
        ls='-'
    kmf.fit(gdf["os"], gdf["censOS"], label=name)
    kmf.plot(ax=a,ci_show=False,c=cols[i],linestyle=ls,
             show_censors=True, censor_styles={'ms': 5, 'marker': '+'})
    i+=1
a.set_ylim([0,1])
# lg_lines=lg.get_lines()
# for j,ln in enumerate(a.get_lines()):
#     ln.set_color(cols[j])
#     lg_lines[j].set_color(cols[j])

handles, labels = a.get_legend_handles_labels()
new_labels=['Low-BiG-BETS DDR Mut','Low-BiG-BETS DDR WT','Low-BiG-BETS DDR Mut','Low-BiG-BETS DDR WT']
l=a.legend(loc=1,bbox_to_anchor=(.85,1.0),fontsize=14,
           frameon=False,handles=handles,labels=new_labels)
for i,text in enumerate(l.get_texts()):
    plt.setp(text, color = cols[i])
    
a.annotate(s='TMB-H',fontsize=14,xy=(.83,.925),xytext=(.86,.925),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.annotate(s='TMB-L',fontsize=14,xy=(.83,.825),xytext=(.86,.825),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

a.set_xlabel("months",fontsize=20)
a.set_ylabel("overall survival",fontsize=20)

# a.set_title("Kaplan-Meier Curve by TMB + low TMB Assoc.DDR Genes",fontsize=18,fontweight='bold')
pval_df=bigbets.bipartite_helper_functions.get_os_stats(clust=clust,samp_df=weirmeta.clinical_bigbets_df)
pval=pval_df['llr_pval'].values[0]
a.text(x=.85,y=.05,s="CPH pval={:.1e}".format(pval),horizontalalignment='center',
       fontsize=14,transform=a.transAxes)



a=plt.subplot2grid((nrows,ncols),(nrows1,0),rowspan=nrows-nrows1,colspan=1)
# a=plt.subplot(1,2,2)
# a.text(s='B)',fontsize=18,fontweight='bold',x=0.0,y=.95,transform=a.transAxes)
# a.text(s='B)',fontsize=18,fontweight='bold',x=-.07,y=1.0,transform=a.transAxes)

xlim_min=np.min(summary['coef']-1.96*summary['se(coef)'])
xlim_max=np.max(summary['coef']+1.96*summary['se(coef)'])

for i,ind in enumerate(summary.index):
    expcoef=summary.loc[ind,'exp(coef)']
    up=summary.loc[ind,'exp(coef) upper 95%']-expcoef
    low=expcoef-summary.loc[ind,'exp(coef) lower 95%']
    ebars=np.array([[low,up]]).T
    a.errorbar(x=[expcoef],alpha=.7,
               y=[summary.shape[0]-1-i],marker='s',color='k',uplims=True, lolims=True,
               xerr=ebars
#                xerr=[1.96*summary.loc[ind,'se(coef)'],
                    )

    
a.vlines(x=1.0,linestyle='--',alpha=.6,linewidth=1,color='k',
         ymin=0,ymax=summary.shape[0]-.9)

a.set_xscale('log')
a.set_xlim([.0000025,30])
a.spines['bottom'].set_position(('data', -.4))
a.spines['bottom'].set_bounds( 0.1,5)

a.spines['left'].set_visible(False)
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)
a.set_yticks([])
a.set_xticks([.1,1,5])
a.xaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
plt.minorticks_off()
a.set_ylim([-2,3])


# a.text(s="LLR pval={:.2e}".format(p_value),fontsize=18,
#        x=.2,y=.8,transform=a.transAxes)



axis_to_data = a.transAxes + a.transData.inverted()
data_to_axis = axis_to_data.inverted()

y=data_to_axis.transform((.1,summary.shape[0]-.55))[1]

print('y',y)
a.text(s="Covariate".format(p_value),fontsize=20,
       x=.01,y=y,transform=a.transAxes)

a.text(s="HR (95% CI)".format(p_value),fontsize=20,
       x=.375,y=y,transform=a.transAxes)

a.text(s="P-value".format(p_value),fontsize=20,
       x=.85,y=y,transform=a.transAxes)

a.hlines(y=y-.02,xmin=-2,xmax=50,color='k',transform=a.transAxes,linewidth=3,linestyle='-')
# a.hlines(y=y-.03,xmin=-1,xmax=2,transform=a.transAxes,linewidth=1,linestyle='-')

for i,ind in enumerate(summary.index):
    y=data_to_axis.transform((.1,summary.shape[0]-i-1.2))[1]
    print('y',y)
    if summary.loc[ind,'p']<.05:
        a.text(s="{}*".format(ind),fontsize=20,
       x=-.1,y=y,transform=a.transAxes)
    else:
        a.text(s=ind,fontsize=20,
           x=-.1,y=y,
           transform=a.transAxes)
    hrtext="{:.2f}  ({:.2f}-{:.2f})".format(*summary.loc[ind,['exp(coef)',
                                                         'exp(coef) lower 95%','exp(coef) upper 95%']])
    pvaltext="{:.2e}".format(*summary.loc[ind,['p']])
    a.text(s=hrtext,fontsize=20,
       x=.35,y=y,
           transform=a.transAxes)
    a.text(s=pvaltext,fontsize=20,
       x=.85,y=y,
           transform=a.transAxes)
    
    x1,y1=data_to_axis.transform((.01,summary.shape[0]-i*.9-1.5))
    x2,y2=data_to_axis.transform((.01,summary.shape[0]-i*.9-.8))
    

    if i%2==0:
        crect=patches.Rectangle((-.1,y1),width=1.2,height=y2-y1,transform=a.transAxes,fill=True,
                               alpha=.05,color='k',clip_on=False)
#         crect2=patches.Rectangle((x2,y1),width=1.1-x2,height=y2-y1,transform=a.transAxes,fill=True,
#                                alpha=.05,color='k')
        a.add_patch(crect)
#         a.add_patch(crect2)
        
    
    

# a.set_title("CPH Model Survival",fontsize=18,fontweight='bold')
# cph.plot(ax=a)
a.text(s="Hazard Ratio",fontsize=18,x=1.25,
       y=-1.1,
       horizontalalignment='center')

f.suptitle('Weir Meta-dataset',fontsize=22,x=.5,y=.97,transform=f.transFigure)

f.subplots_adjust(top=.93,bottom=-.05,right=.95,left=.12,wspace=.0,hspace=1.5)
f.savefig(outfile,dpi=200)
plt.show()
# Out:
#                     coef  exp(coef)  se(coef)  coef lower 95%  coef upper 95%  \
# DDR_low_z_MUT   0.143095   1.153840  0.229567       -0.306848        0.593038
# log(TMB)       -0.132923   0.875533  0.031313       -0.194295       -0.071550
# DDRlow:highTMB -0.607895   0.544496  0.305999       -1.207642       -0.008148
#
#                 exp(coef) lower 95%  exp(coef) upper 95%         z         p  \
# DDR_low_z_MUT              0.735762             1.809478  0.623326  0.533070
# log(TMB)                   0.823415             0.930950 -4.244948  0.000022
# DDRlow:highTMB             0.298901             0.991885 -1.986590  0.046968
#
#                  -log2(p)
# DDR_low_z_MUT    0.907602
# log(TMB)        15.481056
# DDRlow:highTMB   4.412184
# ...

# %%
#low bigbets DDR genes survival analysis
outfile=os.path.join(graphics_dir,'weirmeta_survival_TMB-L_only_low_zscore.pdf')

cph = lifelines.CoxPHFitter()
# vars2keep=['high_TMB','DDR','DDR:highTMB']
vars2keep=['DDR_low_z']

weirmeta_clinical_bigbets_low_tmb=weirmeta.clinical_bigbets_df.loc[weirmeta.clinical_bigbets_df['high_TMB']=='TMB-L',:]

dummy_df=weirmeta_clinical_bigbets_low_tmb.loc[:,['os','censOS']]

for var in vars2keep:
    cdf=pd.get_dummies(weirmeta_clinical_bigbets_low_tmb.loc[:,var])
    cdf.columns=map(lambda x: var+"_"+str(x),cdf.columns.values)
    dummy_df=pd.concat([dummy_df,cdf.iloc[:,:-1]],axis=1)

dummy_df['log(TMB)']=np.log1p(weirmeta_clinical_bigbets_low_tmb.loc[:,'TMB'])

res=cph.fit(dummy_df, 'os', event_col='censOS')
llrstat=cph.log_likelihood_ratio_test()
llr=llrstat.test_statistic
df=llrstat.degrees_freedom
p_value=llrstat.p_value
summary=res.summary
print(res.summary)

var='DDR_low_z_TMB'



coms=weirmeta_clinical_bigbets_low_tmb[var].unique()
commap=dict(zip(coms,range(len(coms))))
clust=list(map(lambda x: commap[x],weirmeta_clinical_bigbets_low_tmb[var]))

plt.close()
f,a=plt.subplots(1,2,figsize=(7.5,10))

nrows=10
ncols=1

ncols1=1
nrows1=6

a=plt.subplot2grid((nrows,ncols),(0,0),rowspan=nrows1,colspan=1)

cols = [red + (1.0,), red + (.5,), blue + (1.0,), blue + (.5,)]
cols=[blue+(1.0,),blue+(.7,)]

kmf = lifelines.KaplanMeierFitter()
df2test=weirmeta_clinical_bigbets_low_tmb
i=0
for name,gdf in df2test.groupby(var):
    if re.search("WT",name):
        ls=':'
    else:
        ls='-'
    kmf.fit(gdf["os"], gdf["censOS"], label=name)
    kmf.plot(ax=a,ci_show=False,c=cols[i],linestyle=ls,
             show_censors=True, censor_styles={'ms': 5, 'marker': '+'})
    i+=1
# lg_lines=lg.get_lines()
# for j,ln in enumerate(a.get_lines()):
#     ln.set_color(cols[j])
#     lg_lines[j].set_color(cols[j])

handles, labels = a.get_legend_handles_labels()
new_labels=['Low-BiG-BETS DDR Mut','Low-BiG-BETS DDR WT','Low-BiG-BETS DDR Mut','Low-BiG-BETS DDR WT']

l=a.legend(loc=1,bbox_to_anchor=(.85,1.0),fontsize=14,
           frameon=False,handles=handles,labels=new_labels)
for i,text in enumerate(l.get_texts()):
    plt.setp(text, color = cols[i])
    
a.annotate(s='TMB-L',fontsize=14,xy=(.83,.925),xytext=(.86,.925),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)


a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

a.set_xlabel("months",fontsize=20)
a.set_ylabel("overall survival",fontsize=20)

# a.set_title("Kaplan-Meier Curve by TMB + low TMB Assoc.DDR Genes",fontsize=18,fontweight='bold')
pval_df=bigbets.bipartite_helper_functions.get_os_stats(clust=clust,samp_df=weirmeta_clinical_bigbets_low_tmb)
pval=pval_df['llr_pval'].values[0]
a.text(x=.85,y=.05,s="CPH pval={:.1e}".format(pval),horizontalalignment='center',
       fontsize=14,transform=a.transAxes)



a=plt.subplot2grid((nrows,ncols),(nrows1,0),rowspan=nrows-nrows1,colspan=1)
# a=plt.subplot(1,2,2)
# a.text(s='B)',fontsize=18,fontweight='bold',x=0.0,y=.95,transform=a.transAxes)
# a.text(s='B)',fontsize=18,fontweight='bold',x=-.07,y=1.0,transform=a.transAxes)

xlim_min=np.min(summary['coef']-1.96*summary['se(coef)'])
xlim_max=np.max(summary['coef']+1.96*summary['se(coef)'])

for i,ind in enumerate(summary.index):
    expcoef=summary.loc[ind,'exp(coef)']
    up=summary.loc[ind,'exp(coef) upper 95%']-expcoef
    low=expcoef-summary.loc[ind,'exp(coef) lower 95%']
    ebars=np.array([[low,up]]).T
    a.errorbar(x=[expcoef],alpha=.7,
               y=[summary.shape[0]-1-i],marker='s',color='k',uplims=True, lolims=True,
               xerr=ebars
#                xerr=[1.96*summary.loc[ind,'se(coef)'],
                    )

    
a.vlines(x=1.0,linestyle='--',alpha=.6,linewidth=1,
         ymin=0,ymax=summary.shape[0]-.9)

a.set_xscale('log')
a.set_xlim([.0000025,30])
a.spines['bottom'].set_position(('data', -.4))
a.spines['bottom'].set_bounds( 0.1,5)

a.spines['left'].set_visible(False)
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)
a.set_yticks([])
a.set_xticks([.1,1,5])
a.xaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
plt.minorticks_off()
a.set_ylim([-2,3])


# a.text(s="LLR pval={:.2e}".format(p_value),fontsize=18,
#        x=.2,y=.8,transform=a.transAxes)



axis_to_data = a.transAxes + a.transData.inverted()
data_to_axis = axis_to_data.inverted()

y=data_to_axis.transform((.1,summary.shape[0]-.55))[1]

print('y',y)
a.text(s="Covariate".format(p_value),fontsize=20,
       x=.01,y=y,transform=a.transAxes)

a.text(s="HR (95% CI)".format(p_value),fontsize=20,
       x=.375,y=y,transform=a.transAxes)

a.text(s="P-value".format(p_value),fontsize=20,
       x=.85,y=y,transform=a.transAxes)

a.hlines(y=y-.02,xmin=-2,xmax=50,transform=a.transAxes,linewidth=3,linestyle='-',color='k')
# a.hlines(y=y-.03,xmin=-1,xmax=2,transform=a.transAxes,linewidth=1,linestyle='-')

for i,ind in enumerate(summary.index):
    y=data_to_axis.transform((.1,summary.shape[0]-i-1.2))[1]
    print('y',y)
    if summary.loc[ind,'p']<.05:
        a.text(s="{}*".format(ind),fontsize=20,
       x=-.1,y=y,transform=a.transAxes)
    else:
        a.text(s=ind,fontsize=20,
           x=-.1,y=y,
           transform=a.transAxes)
    hrtext="{:.2f}  ({:.2f}-{:.2f})".format(*summary.loc[ind,['exp(coef)',
                                                         'exp(coef) lower 95%','exp(coef) upper 95%']])
    pvaltext="{:.2e}".format(*summary.loc[ind,['p']])
    a.text(s=hrtext,fontsize=20,
       x=.35,y=y,
           transform=a.transAxes)
    a.text(s=pvaltext,fontsize=20,
       x=.85,y=y,
           transform=a.transAxes)
    
    x1,y1=data_to_axis.transform((.01,summary.shape[0]-i*.9-1.5))
    x2,y2=data_to_axis.transform((.01,summary.shape[0]-i*.9-.8))
    

    if i%2==0:
        crect=patches.Rectangle((-.1,y1),width=1.2,height=y2-y1,transform=a.transAxes,fill=True,
                               alpha=.05,color='k',clip_on=False)
#         crect2=patches.Rectangle((x2,y1),width=1.1-x2,height=y2-y1,transform=a.transAxes,fill=True,
#                                alpha=.05,color='k')
        a.add_patch(crect)
#         a.add_patch(crect2)
        
    
    

# a.set_title("CPH Model Survival",fontsize=18,fontweight='bold')
# cph.plot(ax=a)
a.text(s="Hazard Ratio",fontsize=18,x=1.25,
       y=-1.1,
       horizontalalignment='center')

f.suptitle('Weir Metadatset',fontsize=22,x=.5,y=.97,transform=f.transFigure)

f.subplots_adjust(top=.93,bottom=-.05,right=.95,left=.12,wspace=.0,hspace=1.5)
f.savefig(outfile,dpi=200)
plt.show()
# Out:
#                    coef  exp(coef)  se(coef)  coef lower 95%  coef upper 95%  \
# DDR_low_z_MUT  0.070304   1.072834  0.232703       -0.385786        0.526393
# log(TMB)      -0.130644   0.877530  0.041294       -0.211578       -0.049710
#
#                exp(coef) lower 95%  exp(coef) upper 95%         z         p  \
# DDR_low_z_MUT             0.679916             1.692816  0.302118  0.762562
# log(TMB)                  0.809306             0.951505 -3.163792  0.001557
#
#                -log2(p)
# DDR_low_z_MUT  0.391073
# log(TMB)       9.326756
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/lifelines/fitters/kaplan_meier_fitter.py:268: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   self.confidence_interval_ = self._bounds(cumulative_sq_[:, None], alpha, ci_labels)
# ...

# %% [markdown]
# ### High Big_BETS DDR Mutations

# %%
#high bigbets DDR genes survival analysis
outfile=os.path.join(graphics_dir,'weirmeta_survival_high_zscore.pdf')

cph = lifelines.CoxPHFitter()
# vars2keep=['high_TMB','DDR','DDR:highTMB']
vars2keep=['DDR_high_z']

dummy_df=weirmeta.clinical_bigbets_df.loc[:,['os','censOS']]

for var in vars2keep:
    cdf=pd.get_dummies(weirmeta.clinical_bigbets_df.loc[:,var])
    cdf.columns=map(lambda x: var+"_"+str(x),cdf.columns.values)
    dummy_df=pd.concat([dummy_df,cdf.iloc[:,:-1]],axis=1)

dummy_df['log(TMB)']=np.log1p(weirmeta.clinical_bigbets_df.loc[:,'TMB'])
# dummy_df['TMB']=weirmeta.clinical_bigbets_df.loc[:,'high_TMB']

dummy_df['DDRhigh:highTMB']=weirmeta.clinical_bigbets_df.loc[:,'DDRhighz:highTMB']

res=cph.fit(dummy_df, 'os', event_col='censOS')
llrstat=cph.log_likelihood_ratio_test()
llr=llrstat.test_statistic
df=llrstat.degrees_freedom
p_value=llrstat.p_value
summary=res.summary
print(res.summary)

var='DDR_high_z_TMB'



coms=weirmeta.clinical_bigbets_df[var].unique()
commap=dict(zip(coms,range(len(coms))))
clust=list(map(lambda x: commap[x],weirmeta.clinical_bigbets_df[var]))

plt.close()
f,a=plt.subplots(1,2,figsize=(7.5,10))

nrows=10
ncols=1

ncols1=1
nrows1=6

a=plt.subplot2grid((nrows,ncols),(0,0),rowspan=nrows1,colspan=1)

cols = [red + (1.0,), red + (.5,), blue + (1.0,), blue + (.5,)]
cols=[red+(1.0,),red+(.7,),blue+(1.0,),blue+(.7,)]

kmf = lifelines.KaplanMeierFitter()
df2test=weirmeta.clinical_bigbets_df
i=0
for name,gdf in df2test.groupby(var):
    if re.search("WT",name):
        ls=':'
    else:
        ls='-'
    kmf.fit(gdf["os"], gdf["censOS"], label=name)
    kmf.plot(ax=a,ci_show=False,c=cols[i],linestyle=ls,
             show_censors=True, censor_styles={'ms': 5, 'marker': '+'})
    i+=1
# lg_lines=lg.get_lines()
# for j,ln in enumerate(a.get_lines()):
#     ln.set_color(cols[j])
#     lg_lines[j].set_color(cols[j])

handles, labels = a.get_legend_handles_labels()
new_labels=['High-BiG-BETS DDR Mut','High-BiG-BETS DDR WT','High-BiG-BETS DDR Mut','High-BiG-BETS DDR WT']
l=a.legend(loc=1,bbox_to_anchor=(.85,1.0),fontsize=14,
           frameon=False,handles=handles,labels=new_labels)
for i,text in enumerate(l.get_texts()):
    plt.setp(text, color = cols[i])
    
a.annotate(s='TMB-H',fontsize=14,xy=(.83,.925),xytext=(.86,.925),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.annotate(s='TMB-L',fontsize=14,xy=(.83,.825),xytext=(.86,.825),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

a.set_xlabel("months",fontsize=20)
a.set_ylabel("overall survival",fontsize=20)

# a.set_title("Kaplan-Meier Curve by TMB + low TMB Assoc.DDR Genes",fontsize=18,fontweight='bold')
pval_df=bigbets.bipartite_helper_functions.get_os_stats(clust=clust,samp_df=weirmeta.clinical_bigbets_df)
pval=pval_df['llr_pval'].values[0]
a.text(x=.85,y=.05,s="CPH pval={:.1e}".format(pval),horizontalalignment='center',
       fontsize=14,transform=a.transAxes)



a=plt.subplot2grid((nrows,ncols),(nrows1,0),rowspan=nrows-nrows1,colspan=1)
# a=plt.subplot(1,2,2)
# a.text(s='B)',fontsize=18,fontweight='bold',x=0.0,y=.95,transform=a.transAxes)
# a.text(s='B)',fontsize=18,fontweight='bold',x=-.07,y=1.0,transform=a.transAxes)

xlim_min=np.min(summary['coef']-1.96*summary['se(coef)'])
xlim_max=np.max(summary['coef']+1.96*summary['se(coef)'])

for i,ind in enumerate(summary.index):
    expcoef=summary.loc[ind,'exp(coef)']
    up=summary.loc[ind,'exp(coef) upper 95%']-expcoef
    low=expcoef-summary.loc[ind,'exp(coef) lower 95%']
    ebars=np.array([[low,up]]).T
    a.errorbar(x=[expcoef],alpha=.7,
               y=[summary.shape[0]-1-i],marker='s',color='k',uplims=True, lolims=True,
               xerr=ebars
#                xerr=[1.96*summary.loc[ind,'se(coef)'],
                    )

    
a.vlines(x=1.0,linestyle='--',alpha=.6,linewidth=1,color='k',
         ymin=0,ymax=summary.shape[0]-.9)

a.set_xscale('log')
a.set_xlim([.0000025,30])
a.spines['bottom'].set_position(('data', -.4))
a.spines['bottom'].set_bounds( 0.1,5)

a.spines['left'].set_visible(False)
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)
a.set_yticks([])
a.set_xticks([.1,1,5])
a.xaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
plt.minorticks_off()
a.set_ylim([-2,3])


# a.text(s="LLR pval={:.2e}".format(p_value),fontsize=18,
#        x=.2,y=.8,transform=a.transAxes)



axis_to_data = a.transAxes + a.transData.inverted()
data_to_axis = axis_to_data.inverted()

y=data_to_axis.transform((.1,summary.shape[0]-.55))[1]

print('y',y)
a.text(s="Covariate".format(p_value),fontsize=20,
       x=.01,y=y,transform=a.transAxes)

a.text(s="HR (95% CI)".format(p_value),fontsize=20,
       x=.375,y=y,transform=a.transAxes)

a.text(s="P-value".format(p_value),fontsize=20,
       x=.85,y=y,transform=a.transAxes)

a.hlines(y=y-.02,xmin=-2,xmax=50,color='k',transform=a.transAxes,linewidth=3,linestyle='-')
# a.hlines(y=y-.03,xmin=-1,xmax=2,transform=a.transAxes,linewidth=1,linestyle='-')

for i,ind in enumerate(summary.index):
    y=data_to_axis.transform((.1,summary.shape[0]-i-1.2))[1]
    print('y',y)
    if summary.loc[ind,'p']<.05:
        a.text(s="{}*".format(ind),fontsize=20,
       x=-.1,y=y,transform=a.transAxes)
    else:
        a.text(s=ind,fontsize=20,
           x=-.1,y=y,
           transform=a.transAxes)
    hrtext="{:.2f}  ({:.2f}-{:.2f})".format(*summary.loc[ind,['exp(coef)',
                                                         'exp(coef) lower 95%','exp(coef) upper 95%']])
    pvaltext="{:.2e}".format(*summary.loc[ind,['p']])
    a.text(s=hrtext,fontsize=20,
       x=.35,y=y,
           transform=a.transAxes)
    a.text(s=pvaltext,fontsize=20,
       x=.85,y=y,
           transform=a.transAxes)
    
    x1,y1=data_to_axis.transform((.01,summary.shape[0]-i*.9-1.5))
    x2,y2=data_to_axis.transform((.01,summary.shape[0]-i*.9-.8))
    

    if i%2==0:
        crect=patches.Rectangle((-.1,y1),width=1.2,height=y2-y1,transform=a.transAxes,fill=True,
                               alpha=.05,color='k',clip_on=False)
#         crect2=patches.Rectangle((x2,y1),width=1.1-x2,height=y2-y1,transform=a.transAxes,fill=True,
#                                alpha=.05,color='k')
        a.add_patch(crect)
#         a.add_patch(crect2)
        
    
    

# a.set_title("CPH Model Survival",fontsize=18,fontweight='bold')
# cph.plot(ax=a)
a.text(s="Hazard Ratio",fontsize=18,x=1.25,
       y=-1.1,
       horizontalalignment='center')

f.suptitle('Weir Meta-dataset',fontsize=22,x=.5,y=.97,transform=f.transFigure)

f.subplots_adjust(top=.93,bottom=-.05,right=.95,left=.12,wspace=.0,hspace=1.5)
f.savefig(outfile,dpi=200)
plt.show()
# Out:
#                      coef  exp(coef)  se(coef)  coef lower 95%  \
# DDR_high_z_MUT  -0.339541   0.712097  0.504344       -1.328037
# log(TMB)        -0.141492   0.868062  0.030318       -0.200914
# DDRhigh:highTMB -0.178858   0.836224  0.572512       -1.300962
#
#                  coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%  \
# DDR_high_z_MUT         0.648954             0.264997             1.913539
# log(TMB)              -0.082069             0.817983             0.921208
# DDRhigh:highTMB        0.943245             0.272270             2.568301
#
#                         z         p   -log2(p)
# DDR_high_z_MUT  -0.673234  0.500799   0.997698
# log(TMB)        -4.666888  0.000003  18.318997
# DDRhigh:highTMB -0.312410  0.754729   0.405969
# ...

# %% [markdown]
# ## ICB Response Analyses

# %%
#Response by low BIGBETS DDR genes
df_low=bigbets.bipartite_helper_functions.get_percents_bar_by_group(weirmeta.clinical_bigbets_df,['high_TMB','DDR_low_z'],'binaryResponse')
outfile=os.path.join(graphics_dir,"R1_Figure_3E_weirmeta_response_by_low_zscore_mut_tmb.pdf")


plt.close()
f,a=plt.subplots(1,1,figsize=(4,5))

pivot=df_low.loc[:,['Response','group','percent']].pivot(index='group',columns='Response',values='percent')
pivot=pivot.loc[['TMB-L_WT','TMB-L_MUT','TMB-H_WT','TMB-H_MUT'],:]
stat,pval,_,_=stats.chi2_contingency(df_low.groupby(['group','Response'])['count'].max().unstack(fill_value=0))

ctab_false=df_low.groupby(['group','Response'])['count'].max().unstack().loc[['TMB-L_WT','TMB-L_MUT'],:]
ctab_true=df_low.groupby(['group','Response'])['count'].max().unstack().loc[['TMB-H_WT','TMB-H_MUT'],:]
s1,pval1=stats.fisher_exact(ctab_false,'less')
s2,pval2=stats.fisher_exact(ctab_true,'less')

a.bar(x=range(pivot.shape[0]),height=pivot['CR/PR'],color=blue)
a.set_ylim([0,1.2])
a.set_ylim([0,.8])
a.set_title("Low BiG-BETS DDR Pts\n(Weir Metaset)",fontsize=18)


# a.text(x=.025,y=.85,s=r"p={:.2e}".format(pval1),
#        fontsize=16,transform=a.transAxes)
a.annotate(s='n.s',fontsize=18,xy=(.25,.32),xytext=(.25,.35),
           arrowprops=dict(arrowstyle='-[, widthB=1.5, lengthB=0', lw=1.0),
           xycoords='axes fraction',horizontalalignment='center',transform=a.transAxes)

a.annotate(s=r"p={:.3f}".format(pval2),fontsize=18,xy=(.75,.66),xytext=(.75,.695),
           arrowprops=dict(arrowstyle='-[, widthB=1.5, lengthB=0', lw=1.0),
           xycoords='axes fraction',horizontalalignment='center',transform=a.transAxes)

# a.text(x=.57,y=.85,s=r"p={:.2e}".format(pval2),
#        fontsize=16,transform=a.transAxes)

a.set_xlabel("")
a.set_ylabel("% response (CR/PR)",fontsize=18)

    
a.get_xaxis().set_visible(False)
scale=.8

a.text(s="TMB-L",x=.5,y=-.19*scale,fontsize=20,horizontalalignment='center')     
a.text(s="TMB-H",x=2.5,y=-.19*scale,fontsize=20,horizontalalignment='center') 

a.text(s="WT",x=0,y=-.07*scale,fontsize=20,horizontalalignment='center')     
a.text(s="MUT",x=1,y=-.07*scale,fontsize=20,horizontalalignment='center')
a.text(s="WT",x=2,y=-.07*scale,fontsize=20,horizontalalignment='center')     
a.text(s="MUT",x=3,y=-.07*scale,fontsize=20,horizontalalignment='center')

#tick marks 

# for i in range(4):
#     line = lines.Line2D(xdata=[i,i], ydata=[0*scale,-.03*scale],color='k', lw=2,
#                         linestyle='-', alpha=.8,clip_on=False)
#     a.add_line(line)
    
# for i in range(4):
#     line = lines.Line2D(xdata=[i,i], ydata=[-.067*scale,-.12*scale],color='k', lw=2,
#                         linestyle='-', alpha=.8,clip_on=False)
#     a.add_line(line)
    
for i in range(2):
    line = lines.Line2D(xdata=[i*2-.2,i*2+1.2], ydata=[-.1*scale,-.1*scale],color='k', lw=2,
                        linestyle='-', alpha=.8,clip_on=False)
    a.add_line(line)
# for i in range(2):
#     line = lines.Line2D(xdata=[i*2+.5,i*2+.5], ydata=[-.12*scale,-.15*scale],color='k', lw=2,
#                         linestyle='-', alpha=.8,clip_on=False)
#     a.add_line(line)
    
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

# l=a.legend(fontsize=18,bbox_to_anchor=(.6,.95),ncol=2,loc=10,
#           handletextpad=.4,columnspacing=.7,framealpha=1)
# l.set_visible(True)

f.subplots_adjust(top=.88,bottom=.17,right=.93,left=.24)
f.savefig(outfile,dpi=200)

plt.show()
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:28: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:32: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.

# %%
#Response by low BIGBETS DDR genes
df_high=bigbets.bipartite_helper_functions.get_percents_bar_by_group(weirmeta.clinical_bigbets_df,['high_TMB','DDR_high_z'],'binaryResponse')
outfile=os.path.join(graphics_dir,"weirmeta_response_by_high_zscore_mut_tmb.pdf")


plt.close()
f,a=plt.subplots(1,1,figsize=(4,5))

pivot=df_high.loc[:,['Response','group','percent']].pivot(index='group',columns='Response',values='percent')
pivot=pivot.loc[['TMB-L_WT','TMB-L_MUT','TMB-H_WT','TMB-H_MUT'],:]
stat,pval,_,_=stats.chi2_contingency(df_high.groupby(['group','Response'])['count'].max().unstack(fill_value=0))

ctab_false=df_high.groupby(['group','Response'])['count'].max().unstack().loc[['TMB-L_WT','TMB-L_MUT'],:]
ctab_true=df_high.groupby(['group','Response'])['count'].max().unstack().loc[['TMB-H_WT','TMB-H_MUT'],:]
s1,pval1=stats.fisher_exact(ctab_false,'less')
s2,pval2=stats.fisher_exact(ctab_true,'less')

a.bar(x=range(pivot.shape[0]),height=pivot['CR/PR'],color=blue)
a.set_ylim([0,1.2])
a.set_ylim([0,.8])
a.set_title("High BiG-BETS DDR Pts\n(Weir Metaset)",fontsize=18)


# a.text(x=.025,y=.85,s=r"p={:.2e}".format(pval1),
#        fontsize=16,transform=a.transAxes)

a.annotate(s='p={:.3f}'.format(pval1),fontsize=18,xy=(.25,.74),xytext=(.25,.78),
           arrowprops=dict(arrowstyle='-[, widthB=1.5, lengthB=0', lw=1.0),
           xycoords='axes fraction',horizontalalignment='center',transform=a.transAxes)

a.annotate(s=r"n.s.".format(pval2),fontsize=18,xy=(.75,.66),xytext=(.75,.695),
           arrowprops=dict(arrowstyle='-[, widthB=1.5, lengthB=0', lw=1.0),
           xycoords='axes fraction',horizontalalignment='center',transform=a.transAxes)

# a.text(x=.57,y=.85,s=r"p={:.2e}".format(pval2),
#        fontsize=16,transform=a.transAxes)

a.set_xlabel("")
a.set_ylabel("% response (CR/PR)",fontsize=18)

    
a.get_xaxis().set_visible(False)
scale=.8

a.text(s="TMB-L",x=.5,y=-.1875*scale,fontsize=20,horizontalalignment='center')     
a.text(s="TMB-H",x=2.5,y=-.1875*scale,fontsize=20,horizontalalignment='center') 

a.text(s="WT",x=0,y=-.065*scale,fontsize=20,horizontalalignment='center')     
a.text(s="MUT",x=1,y=-.065*scale,fontsize=20,horizontalalignment='center')
a.text(s="WT",x=2,y=-.065*scale,fontsize=20,horizontalalignment='center')     
a.text(s="MUT",x=3,y=-.065*scale,fontsize=20,horizontalalignment='center')

#tick marks 

# for i in range(4):
#     line = lines.Line2D(xdata=[i,i], ydata=[0*scale,-.03*scale],color='k', lw=2,
#                         linestyle='-', alpha=.8,clip_on=False)
#     a.add_line(line)
    
# for i in range(4):
#     line = lines.Line2D(xdata=[i,i], ydata=[-.067*scale,-.12*scale],color='k', lw=2,
#                         linestyle='-', alpha=.8,clip_on=False)
#     a.add_line(line)
    
for i in range(2):
    line = lines.Line2D(xdata=[i*2-.2,i*2+1.2], ydata=[-.1*scale,-.1*scale],color='k', lw=2,
                        linestyle='-', alpha=.8,clip_on=False)
    a.add_line(line)
# for i in range(2):
#     line = lines.Line2D(xdata=[i*2+.5,i*2+.5], ydata=[-.12*scale,-.15*scale],color='k', lw=2,
#                         linestyle='-', alpha=.8,clip_on=False)
#     a.add_line(line)
    
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

# l=a.legend(fontsize=18,bbox_to_anchor=(.6,.95),ncol=2,loc=10,
#           handletextpad=.4,columnspacing=.7,framealpha=1)
# l.set_visible(True)

f.subplots_adjust(top=.88,bottom=.17,right=.93,left=.24)
f.savefig(outfile,dpi=200)

plt.show()
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:29: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:33: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.

# %% [markdown]
# # Tumor Specific Survival (Combined Weir-meta, Samstein, IMVigor)

# %%
#combine all of the dta
spec_by_genes=pd.concat([weirmeta.spec_by_genes,
                         imvigor.spec_by_genes,
                         samstein.spec_by_genes],join='outer',sort=True)

clinical_bigbets_df=pd.concat([weirmeta.clinical_bigbets_df,
                         imvigor.clinical_bigbets_df,
                         samstein.clinical_bigbets_df],join='outer',sort=True)

combined=bigbets.load_clinical_datasets.ClinicalDataSet()
combined.spec_by_genes=spec_by_genes
combined.clinical_bigbets_df=clinical_bigbets_df

print('spec_by_genes',spec_by_genes.shape)
print('clinical_dataframe',combined.clinical_bigbets_df.shape)
# Out:
# spec_by_genes (2266, 1013)
# clinical_dataframe (1992, 83)

# %%
combined.clinical_bigbets_df.groupby(['CANCER_TYPE']).size()
# Out:
# CANCER_TYPE
# Bladder Cancer                287
# Breast Cancer                  20
# Cancer of Unknown Primary      76
# Colorectal Cancer              99
# Esophagogastric Cancer         93
# Glioma                        114
# Head and Neck Cancer          131
# Melanoma                      327
# Non-Small Cell Lung Cancer    413
# Renal Cell Carcinoma          157
# Skin Cancer, Non-Melanoma       1
# dtype: int64

# %%
# outfile=os.path.join(graphics_dir,"samtstein_survival_low_zscore.png")
cph = lifelines.CoxPHFitter()
# vars2keep=['high_TMB','DDR_mut','DDR:highTMB']
vars2keep=['DDR_low_z']
# vars2keep=['DDR']
# vars2keep=[]

# ctype='Bladder Cancer'
outdir=os.path.join(graphics_dir,'survival_by_tumor_type_combined_set')
if not os.path.exists(outdir):
    os.makedirs(outdir)
    
ctype_counts=combined.clinical_bigbets_df['CANCER_TYPE'].value_counts()
ctypes=[
    ['Bladder Cancer'],['Non-Small Cell Lung Cancer'],['Melanoma'],['Renal Cell Carcinoma'],['Colorectal Cancer'],
]


ii=0

outfiles=[]

for ctype in ctypes:
    title_txt="+".join(ctype)
    combined.clinical_bigbets_df_filt=combined.clinical_bigbets_df.loc[combined.clinical_bigbets_df['CANCER_TYPE'].isin(ctype),:]
    dummy_df=combined.clinical_bigbets_df_filt.loc[:,['os','censOS']]
    for var in vars2keep:
        cdf=pd.get_dummies(combined.clinical_bigbets_df_filt.loc[:,var])
        cdf.columns=map(lambda x: var+"_"+str(x),cdf.columns.values)
        dummy_df=pd.concat([dummy_df,cdf.iloc[:,:-1]],axis=1)

    dummy_df['TMB']=np.log1p(combined.clinical_bigbets_df_filt.loc[:,'TMB'])
    dummy_df['DDRlow:highTMB']=combined.clinical_bigbets_df_filt.loc[:,'DDRlowz:highTMB']
    try:
        res=cph.fit(dummy_df, 'os', event_col='censOS')
    except:
        res=cph.fit(dummy_df, 'os', event_col='censOS')
        print('not enough seperation for {:}'.format(ctype))
        continue
    summary=res.summary
#     print(res.summary)
    llrstat=cph.log_likelihood_ratio_test()
    llr=llrstat.test_statistic
    df=llrstat.degrees_freedom
    p_value=llrstat.p_value
    print(ctype,p_value)


    var='DDR_low_z_TMB'
    


    coms=combined.clinical_bigbets_df_filt[var].unique()
    commap=dict(zip(coms,range(len(coms))))
    clust=list(map(lambda x: commap[x],combined.clinical_bigbets_df_filt[var]))
    
    coutfile=os.path.join(outdir,"{:}_comb_surv.png".format("_".join(ctype)))
    outfiles.append(coutfile)
    plt.close()
    f,a=plt.subplots(1,2,figsize=(7.5,10))

    nrows=10
    ncols=1

    ncols1=1
    nrows1=6

    a=plt.subplot2grid((nrows,ncols),(0,0),rowspan=nrows1,colspan=1)

    cols = [red + (1.0,), red + (.5,), blue + (1.0,), blue + (.5,)]
    cols=[red+(1.0,),red+(.7,),blue+(1.0,),blue+(.7,)]

    kmf = lifelines.KaplanMeierFitter()
    df2test=combined.clinical_bigbets_df_filt
    i=0
    for name,gdf in df2test.groupby(var):
        if re.search("WT",name):
            ls=':'
        else:
            ls='-'
        kmf.fit(gdf["os"], gdf["censOS"], label=name)
        kmf.plot(ax=a,ci_show=False,c=cols[i],linestyle=ls,
                 show_censors=True, censor_styles={'ms': 5, 'marker': '+'})
        i+=1
    a.set_ylim([0,1])
    # lg_lines=lg.get_lines()
    # for j,ln in enumerate(a.get_lines()):
    #     ln.set_color(cols[j])
    #     lg_lines[j].set_color(cols[j])

    handles, labels = a.get_legend_handles_labels()
    new_labels=['Low-BiG-BETS DDR Mut','Low-BiG-BETS DDR WT','Low-BiG-BETS DDR Mut','Low-BiG-BETS DDR WT']
    l=a.legend(loc=1,bbox_to_anchor=(.85,1.0),fontsize=14,
               frameon=False,handles=handles,labels=new_labels)
    for i,text in enumerate(l.get_texts()):
        plt.setp(text, color = cols[i])

    a.annotate(s='TMB-H',fontsize=14,xy=(.83,.925),xytext=(.86,.925),
           arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
           xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

    a.annotate(s='TMB-L',fontsize=14,xy=(.83,.825),xytext=(.86,.825),
           arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
           xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

    a.spines['right'].set_visible(False)
    a.spines['top'].set_visible(False)

    a.set_xlabel("months",fontsize=20)
    a.set_ylabel("overall survival",fontsize=20)

    # a.set_title("Kaplan-Meier Curve by TMB + low TMB Assoc.DDR Genes",fontsize=18,fontweight='bold')
    pval_df=bigbets.bipartite_helper_functions.get_os_stats(clust=clust,samp_df=combined.clinical_bigbets_df_filt)
    pval=pval_df['llr_pval'].values[0]
    a.text(x=.85,y=.05,s="CPH pval={:.1e}".format(pval),horizontalalignment='center',
           fontsize=14,transform=a.transAxes)



    a=plt.subplot2grid((nrows,ncols),(nrows1,0),rowspan=nrows-nrows1,colspan=1)
    # a=plt.subplot(1,2,2)
    # a.text(s='B)',fontsize=18,fontweight='bold',x=0.0,y=.95,transform=a.transAxes)
    # a.text(s='B)',fontsize=18,fontweight='bold',x=-.07,y=1.0,transform=a.transAxes)

    xlim_min=np.min(summary['coef']-1.96*summary['se(coef)'])
    xlim_max=np.max(summary['coef']+1.96*summary['se(coef)'])

    for i,ind in enumerate(summary.index):
        expcoef=summary.loc[ind,'exp(coef)']
        up=summary.loc[ind,'exp(coef) upper 95%']-expcoef
        low=expcoef-summary.loc[ind,'exp(coef) lower 95%']
        ebars=np.array([[low,up]]).T
        a.errorbar(x=[expcoef],alpha=.7,
                   y=[summary.shape[0]-1-i],marker='s',color='k',uplims=True, lolims=True,
                   xerr=ebars
    #                xerr=[1.96*summary.loc[ind,'se(coef)'],
                        )


    a.vlines(x=1.0,linestyle='--',alpha=.6,linewidth=1,color='k',
             ymin=0,ymax=summary.shape[0]-.9)

    a.set_xscale('log')
    a.set_xlim([.0000025,30])
    a.spines['bottom'].set_position(('data', -.4))
    a.spines['bottom'].set_bounds( 0.1,5)

    a.spines['left'].set_visible(False)
    a.spines['right'].set_visible(False)
    a.spines['top'].set_visible(False)
    a.set_yticks([])
    a.set_xticks([.1,1,5])
    a.xaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
    plt.minorticks_off()
    a.set_ylim([-2,3])


    # a.text(s="LLR pval={:.2e}".format(p_value),fontsize=18,
    #        x=.2,y=.8,transform=a.transAxes)



    axis_to_data = a.transAxes + a.transData.inverted()
    data_to_axis = axis_to_data.inverted()

    y=data_to_axis.transform((.1,summary.shape[0]-.55))[1]

    a.text(s="Covariate".format(p_value),fontsize=20,
           x=.01,y=y,transform=a.transAxes)

    a.text(s="HR (95% CI)".format(p_value),fontsize=20,
           x=.375,y=y,transform=a.transAxes)

    a.text(s="P-value".format(p_value),fontsize=20,
           x=.85,y=y,transform=a.transAxes)

    a.hlines(y=y-.02,xmin=-2,xmax=50,color='k',transform=a.transAxes,linewidth=3,linestyle='-')
    # a.hlines(y=y-.03,xmin=-1,xmax=2,transform=a.transAxes,linewidth=1,linestyle='-')

    for i,ind in enumerate(summary.index):
        y=data_to_axis.transform((.1,summary.shape[0]-i-1.2))[1]
        if summary.loc[ind,'p']<.05:
            a.text(s="{}*".format(ind),fontsize=20,
           x=-.1,y=y,transform=a.transAxes)
        else:
            a.text(s=ind,fontsize=20,
               x=-.1,y=y,
               transform=a.transAxes)
        hrtext="{:.2f}  ({:.2f}-{:.2f})".format(*summary.loc[ind,['exp(coef)',
                                                             'exp(coef) lower 95%','exp(coef) upper 95%']])
        pvaltext="{:.2e}".format(*summary.loc[ind,['p']])
        a.text(s=hrtext,fontsize=20,
           x=.35,y=y,
               transform=a.transAxes)
        a.text(s=pvaltext,fontsize=20,
           x=.85,y=y,
               transform=a.transAxes)

        x1,y1=data_to_axis.transform((.01,summary.shape[0]-i*.9-1.5))
        x2,y2=data_to_axis.transform((.01,summary.shape[0]-i*.9-.8))


        if i%2==0:
            crect=patches.Rectangle((-.1,y1),width=1.2,height=y2-y1,transform=a.transAxes,fill=True,
                                   alpha=.05,color='k',clip_on=False)
    #         crect2=patches.Rectangle((x2,y1),width=1.1-x2,height=y2-y1,transform=a.transAxes,fill=True,
    #                                alpha=.05,color='k')
            a.add_patch(crect)
    #         a.add_patch(crect2)




    # a.set_title("CPH Model Survival",fontsize=18,fontweight='bold')
    # cph.plot(ax=a)
    a.text(s="Hazard Ratio",fontsize=18,x=1.25,
           y=-1.1,
           horizontalalignment='center')

    f.suptitle('Weir Combined: {:}\nLow BiG-BETS DDR genes'.format("_".join(ctype)),
               fontsize=22,x=.1,y=.99,transform=f.transFigure,horizontalalignment='left')

    f.subplots_adjust(top=.89,bottom=-.05,right=.95,left=.12,wspace=.0,hspace=1.5)
    f.savefig(coutfile,dpi=200)
    f.savefig(re.sub("\.png",".pdf",coutfile)) #save as pdf as well
    plt.close()
# Out:
# ['Bladder Cancer'] 0.0005684217326317485
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/lifelines/fitters/kaplan_meier_fitter.py:268: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   self.confidence_interval_ = self._bounds(cumulative_sq_[:, None], alpha, ci_labels)
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/lifelines/fitters/kaplan_meier_fitter.py:268: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   self.confidence_interval_ = self._bounds(cumulative_sq_[:, None], alpha, ci_labels)
# ...

# %%
# combined.clinical_bigbets_df.loc[combined.clinical_bigbets_df['CANCER_TYPE'].isin(['Colorectal Cancer']),:].groupby('DDR_low_z_TMB').size()

# %%
#We combine all of these together.  
letters=['A','B','C','D','E']
files=dict(zip(letters,outfiles))

outfile=os.path.join(graphics_dir,'combined_individual_tumor.pdf')
plt.close()
f=plt.gcf()

# f.set_size_inches((8.5,6.75))
f.set_size_inches((7.5*3,10*1))
nrows=1
ncols=3
                  
for i,ofile in enumerate(files):
    if i<3:     
        a=plt.subplot2grid((nrows,ncols),(0,i),colspan=1,rowspan=1)
    else:
        continue
#         a=plt.subplot2grid((nrows,ncols),(1,2),colspan=1,rowspan=2)
        
    im=mpimg.imread(files[letters[i]])
    a.set_axis_off()
    plt.imshow(im)
    a.text(s=letters[i],fontsize=20,fontweight='bold',x=0.01,y=.92,transform=a.transAxes)

# f.suptitle("Low BiG-BETS DDR Mutation by Tumor Types",x=.5,y=.99,fontsize=25,fontweight='bold')
f.subplots_adjust(top=.985,bottom=0,right=1.0,left=.01,hspace=0,wspace=0.05)
f.savefig(outfile,dpi=200)
plt.show()

# %% [markdown]
# # TCGA Survival and Gene Signatures

# %%
tcga_data=bigbets.TCGA_Data()
tcga_data.load_clinical_data(tmbthresh=10)
tcga_data.get_cancer_types_filtered()
# Out:
# 2021-12-30 08:04:57,831:bigbets.load_tcga_dataset:INFO:Loading TCGA dataset
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   """Entry point for launching an IPython kernel.
# 2021-12-30 08:06:20,747:bigbets.load_tcga_dataset:INFO:alteration_data_tcga.shape: (3600963, 25)
# 2021-12-30 08:06:39,502:bigbets.load_tcga_dataset:INFO:Filtering TCGA Dataset
# tcga_alt_filt.shape (208682, 28)
# querying 1-274...done.
# Finished.
# 12 input query terms found no hit:
# 	['C1orf86', 'APITD1', 'TCEB3', 'BRE', 'SHFM1', 'TCEB1', 'H2AFX', 'NDNL2', 'TCEB2', 'C17orf70', 'STRA
# querying 1-12...done.
# Finished.
# 5 input query terms found dup hits:
# 	[('APITD1', 2), ('TCEB3', 2), ('BRE', 3), ('SHFM1', 10), ('STRA13', 2)]
# 2021-12-30 08:07:11,305:bigbets.load_tcga_dataset:INFO:Loading TCGA Clinical data
# ...

# %%
tcga_data.tcga_alt_filt_wmod.shape,tcga_data.tcga_spec_by_all_genes_wmod.shape
# Out:
# ((1000011, 28), (10164, 19255))

# %% [markdown]
# ## Survival analysis by Big-BET mutations TCGA

# %% [markdown]
# ### Low Big-BETS DDR

# %% [markdown]
# #### All cancer types

# %%
#low bigbets DDR genes survival analysis
outfile=os.path.join(supplements_dir,'tcga_data_survival_alltypes_low_zscore.pdf')

cph = lifelines.CoxPHFitter()
# vars2keep=['high_TMB','DDR','DDR:highTMB']
vars2keep=['DDR_low_z']

#filter the types here to match those that are present in Samstein
df_filt=tcga_data.clinical_bigbets_df.dropna(axis=0)

dummy_df=df_filt.loc[:,['os_5yr','censOS_5yr']]

for var in vars2keep:
    cdf=pd.get_dummies(df_filt.loc[:,var])
    cdf.columns=map(lambda x: var+"_"+str(x),cdf.columns.values)
    dummy_df=pd.concat([dummy_df,cdf.iloc[:,:-1]],axis=1)

dummy_df['log(TMB)']=np.log1p(df_filt.loc[:,'TMB'])
# dummy_df['TMB']=df_filt.loc[:,'high_TMB']
dummy_df['DDRlow:highTMB']=df_filt.loc[:,'DDRlowz:highTMB']

res=cph.fit(dummy_df, 'os_5yr', event_col='censOS_5yr')
llrstat=cph.log_likelihood_ratio_test()
llr=llrstat.test_statistic
df=llrstat.degrees_freedom
p_value=llrstat.p_value
summary=res.summary
print(res.summary)

var='DDR_low_z_TMB'



coms=df_filt[var].unique()
commap=dict(zip(coms,range(len(coms))))
clust=list(map(lambda x: commap[x],df_filt[var]))

plt.close()
f,a=plt.subplots(1,2,figsize=(7.5,10))

nrows=10
ncols=1

ncols1=1
nrows1=6

a=plt.subplot2grid((nrows,ncols),(0,0),rowspan=nrows1,colspan=1)

# cols = [red + (1.0,), red + (.5,), blue + (1.0,), blue + (.5,)]
cols=[red+(1.0,),red+(.7,),blue+(1.0,),blue+(.7,)]

kmf = lifelines.KaplanMeierFitter()
df2test=df_filt
i=0
for name,gdf in df2test.groupby(var):
    if re.search("WT",name):
        ls=':'
    else:
        ls='-'
    kmf.fit(gdf["os_5yr"], gdf["censOS_5yr"], label=name)
    kmf.plot(ax=a,ci_show=False,c=cols[i],linestyle=ls,
             show_censors=True, censor_styles={'ms': 3, 'marker': '+'})
    i+=1
# lg_lines=lg.get_lines()
# for j,ln in enumerate(a.get_lines()):
#     ln.set_color(cols[j])
#     lg_lines[j].set_color(cols[j])

handles, labels = a.get_legend_handles_labels()
new_labels=['Low-BiG-BETS DDR Mut','Low-BiG-BETS DDR WT','Low-BiG-BETS DDR Mut','Low-BiG-BETS DDR WT']
l=a.legend(loc=1,bbox_to_anchor=(.85,1.0),fontsize=14,
           frameon=False,handles=handles,labels=new_labels)
for i,text in enumerate(l.get_texts()):
    plt.setp(text, color = cols[i])
    
a.annotate(s='TMB-H',fontsize=14,xy=(.83,.925),xytext=(.86,.925),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.annotate(s='TMB-L',fontsize=14,xy=(.83,.825),xytext=(.86,.825),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

a.set_xlabel("months",fontsize=20)
a.set_ylabel("overall 5yr survival",fontsize=20)

# a.set_title("Kaplan-Meier Curve by TMB + low TMB Assoc.DDR Genes",fontsize=18,fontweight='bold')
pval_df=bigbets.bipartite_helper_functions.get_os_stats(clust=clust,samp_df=df_filt)
pval=pval_df['llr_pval'].values[0]
a.text(x=.85,y=.03,s="CPH pval={:.1e}".format(pval),horizontalalignment='center',
       fontsize=16,transform=a.transAxes)



a=plt.subplot2grid((nrows,ncols),(nrows1,0),rowspan=nrows-nrows1,colspan=1)
# a=plt.subplot(1,2,2)
# a.text(s='B)',fontsize=18,fontweight='bold',x=0.0,y=.95,transform=a.transAxes)
# a.text(s='B)',fontsize=18,fontweight='bold',x=-.07,y=1.0,transform=a.transAxes)

xlim_min=np.min(summary['coef']-1.96*summary['se(coef)'])
xlim_max=np.max(summary['coef']+1.96*summary['se(coef)'])

for i,ind in enumerate(summary.index):
    expcoef=summary.loc[ind,'exp(coef)']
    up=summary.loc[ind,'exp(coef) upper 95%']-expcoef
    low=expcoef-summary.loc[ind,'exp(coef) lower 95%']
    ebars=np.array([[low,up]]).T
    a.errorbar(x=[expcoef],alpha=.7,
               y=[summary.shape[0]-1-i],marker='s',color='k',uplims=True, lolims=True,
               xerr=ebars
#                xerr=[1.96*summary.loc[ind,'se(coef)'],
                    )

    
a.vlines(x=1.0,linestyle='--',alpha=.6,linewidth=1,color='k',
         ymin=0,ymax=summary.shape[0]-.9)

a.set_xscale('log')
a.set_xlim([.0000025,30])
a.spines['bottom'].set_position(('data', -.4))
a.spines['bottom'].set_bounds( 0.1,5)

a.spines['left'].set_visible(False)
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)
a.set_yticks([])
a.set_xticks([.1,1,5])
a.xaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
plt.minorticks_off()
a.set_ylim([-2,3])


# a.text(s="LLR pval={:.2e}".format(p_value),fontsize=18,
#        x=.2,y=.8,transform=a.transAxes)



axis_to_data = a.transAxes + a.transData.inverted()
data_to_axis = axis_to_data.inverted()

y=data_to_axis.transform((.1,summary.shape[0]-.55))[1]

print('y',y)
a.text(s="Covariate".format(p_value),fontsize=20,
       x=.01,y=y,transform=a.transAxes)

a.text(s="HR (95% CI)".format(p_value),fontsize=20,
       x=.375,y=y,transform=a.transAxes)

a.text(s="P-value".format(p_value),fontsize=20,
       x=.85,y=y,transform=a.transAxes)

a.hlines(y=y-.02,xmin=-2,xmax=50,color='k',transform=a.transAxes,linewidth=3,linestyle='-')
# a.hlines(y=y-.03,xmin=-1,xmax=2,transform=a.transAxes,linewidth=1,linestyle='-')

for i,ind in enumerate(summary.index):
    y=data_to_axis.transform((.1,summary.shape[0]-i-1.2))[1]
    print('y',y)
    if summary.loc[ind,'p']<.05:
        a.text(s="{}*".format(ind),fontsize=20,
       x=-.1,y=y,transform=a.transAxes)
    else:
        a.text(s=ind,fontsize=20,
           x=-.1,y=y,
           transform=a.transAxes)
    hrtext="{:.2f}  ({:.2f}-{:.2f})".format(*summary.loc[ind,['exp(coef)',
                                                         'exp(coef) lower 95%','exp(coef) upper 95%']])
    pvaltext="{:.2e}".format(*summary.loc[ind,['p']])
    a.text(s=hrtext,fontsize=20,
       x=.35,y=y,
           transform=a.transAxes)
    a.text(s=pvaltext,fontsize=20,
       x=.85,y=y,
           transform=a.transAxes)
    
    x1,y1=data_to_axis.transform((.01,summary.shape[0]-i*.9-1.5))
    x2,y2=data_to_axis.transform((.01,summary.shape[0]-i*.9-.8))
    

    if i%2==0:
        crect=patches.Rectangle((-.1,y1),width=1.2,height=y2-y1,transform=a.transAxes,fill=True,
                               alpha=.05,color='k',clip_on=False)
#         crect2=patches.Rectangle((x2,y1),width=1.1-x2,height=y2-y1,transform=a.transAxes,fill=True,
#                                alpha=.05,color='k')
        a.add_patch(crect)
#         a.add_patch(crect2)
        
    
    

# a.set_title("CPH Model Survival",fontsize=18,fontweight='bold')
# cph.plot(ax=a)
a.text(s="Hazard Ratio",fontsize=18,x=1.25,
       y=-1.1,
       horizontalalignment='center')

f.suptitle('TCGA Pan-Cancer',fontsize=22,x=.5,y=.97,transform=f.transFigure)

f.subplots_adjust(top=.93,bottom=-.05,right=.95,left=.132,wspace=.0,hspace=1.5)
f.savefig(outfile,dpi=200)
plt.show()
# Out:
#                     coef  exp(coef)  se(coef)  coef lower 95%  coef upper 95%  \
# DDR_low_z_MUT  -0.087676   0.916057  0.113842       -0.310802        0.135450
# log(TMB)        0.211330   1.235319  0.023445        0.165378        0.257281
# DDRlow:highTMB -0.558481   0.572077  0.174064       -0.899640       -0.217322
#
#                 exp(coef) lower 95%  exp(coef) upper 95%         z  \
# DDR_low_z_MUT              0.732859             1.145052 -0.770158
# log(TMB)                   1.179839             1.293409  9.013802
# DDRlow:highTMB             0.406716             0.804671 -3.208483
#
#                            p   -log2(p)
# DDR_low_z_MUT   4.412061e-01   1.180475
# log(TMB)        1.990341e-19  62.123618
# DDRlow:highTMB  1.334373e-03   9.549622
# ...

# %% [markdown]
# #### Types to match samstein

# %%
#low bigbets DDR genes survival analysis
outfile=os.path.join(supplements_dir,'tcga_data_survival_low_zscore.pdf')

cph = lifelines.CoxPHFitter()
# vars2keep=['high_TMB','DDR','DDR:highTMB']
vars2keep=['DDR_low_z']

#filter the types here to match those that are present in Samstein
df_filt=tcga_data.clinical_bigbets_data_type_filt.dropna(axis=0)

dummy_df=df_filt.loc[:,['os_5yr','censOS_5yr']]

for var in vars2keep:
    cdf=pd.get_dummies(df_filt.loc[:,var])
    cdf.columns=map(lambda x: var+"_"+str(x),cdf.columns.values)
    dummy_df=pd.concat([dummy_df,cdf.iloc[:,:-1]],axis=1)

dummy_df['log(TMB)']=np.log1p(df_filt.loc[:,'TMB'])
# dummy_df['TMB']=df_filt.loc[:,'high_TMB']
dummy_df['DDRlow:highTMB']=df_filt.loc[:,'DDRlowz:highTMB']

res=cph.fit(dummy_df, 'os_5yr', event_col='censOS_5yr')
llrstat=cph.log_likelihood_ratio_test()
llr=llrstat.test_statistic
df=llrstat.degrees_freedom
p_value=llrstat.p_value
summary=res.summary
print(res.summary)

var='DDR_low_z_TMB'



coms=df_filt[var].unique()
commap=dict(zip(coms,range(len(coms))))
clust=list(map(lambda x: commap[x],df_filt[var]))

plt.close()
f,a=plt.subplots(1,2,figsize=(7.5,10))

nrows=10
ncols=1

ncols1=1
nrows1=6

a=plt.subplot2grid((nrows,ncols),(0,0),rowspan=nrows1,colspan=1)

# cols = [red + (1.0,), red + (.5,), blue + (1.0,), blue + (.5,)]
cols=[red+(1.0,),red+(.7,),blue+(1.0,),blue+(.7,)]

kmf = lifelines.KaplanMeierFitter()
df2test=df_filt
i=0
for name,gdf in df2test.groupby(var):
    if re.search("WT",name):
        ls=':'
    else:
        ls='-'
    kmf.fit(gdf["os_5yr"], gdf["censOS_5yr"], label=name)
    kmf.plot(ax=a,ci_show=False,c=cols[i],linestyle=ls,
             show_censors=True, censor_styles={'ms': 3, 'marker': '+'})
    i+=1
# lg_lines=lg.get_lines()
# for j,ln in enumerate(a.get_lines()):
#     ln.set_color(cols[j])
#     lg_lines[j].set_color(cols[j])

a.set_ylim([0,1])
handles, labels = a.get_legend_handles_labels()
new_labels=['Low-BiG-BETS DDR Mut','Low-BiG-BETS DDR WT','Low-BiG-BETS DDR Mut','Low-BiG-BETS DDR WT']
l=a.legend(loc=1,bbox_to_anchor=(.85,.4),fontsize=14,
           frameon=False,handles=handles,labels=new_labels)
for i,text in enumerate(l.get_texts()):
    plt.setp(text, color = cols[i])
    
a.annotate(s='TMB-H',fontsize=14,xy=(.83,.325),xytext=(.86,.325),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.annotate(s='TMB-L',fontsize=14,xy=(.83,.225),xytext=(.86,.225),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

a.set_xlabel("months",fontsize=20)
a.set_ylabel("overall 5yr survival",fontsize=20)

# a.set_title("Kaplan-Meier Curve by TMB + low TMB Assoc.DDR Genes",fontsize=18,fontweight='bold')
pval_df=bigbets.bipartite_helper_functions.get_os_stats(clust=clust,samp_df=df_filt)
pval=pval_df['llr_pval'].values[0]
a.text(x=.85,y=.03,s="CPH pval={:.1e}".format(pval),horizontalalignment='center',
       fontsize=16,transform=a.transAxes)



a=plt.subplot2grid((nrows,ncols),(nrows1,0),rowspan=nrows-nrows1,colspan=1)
# a=plt.subplot(1,2,2)
# a.text(s='B)',fontsize=18,fontweight='bold',x=0.0,y=.95,transform=a.transAxes)
# a.text(s='B)',fontsize=18,fontweight='bold',x=-.07,y=1.0,transform=a.transAxes)

xlim_min=np.min(summary['coef']-1.96*summary['se(coef)'])
xlim_max=np.max(summary['coef']+1.96*summary['se(coef)'])

for i,ind in enumerate(summary.index):
    expcoef=summary.loc[ind,'exp(coef)']
    up=summary.loc[ind,'exp(coef) upper 95%']-expcoef
    low=expcoef-summary.loc[ind,'exp(coef) lower 95%']
    ebars=np.array([[low,up]]).T
    a.errorbar(x=[expcoef],alpha=.7,
               y=[summary.shape[0]-1-i],marker='s',color='k',uplims=True, lolims=True,
               xerr=ebars
#                xerr=[1.96*summary.loc[ind,'se(coef)'],
                    )

    
a.vlines(x=1.0,linestyle='--',alpha=.6,linewidth=1,color='k',
         ymin=0,ymax=summary.shape[0]-.9)

a.set_xscale('log')
a.set_xlim([.0000025,30])
a.spines['bottom'].set_position(('data', -.4))
a.spines['bottom'].set_bounds( 0.1,5)

a.spines['left'].set_visible(False)
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)
a.set_yticks([])
a.set_xticks([.1,1,5])
a.xaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
plt.minorticks_off()
a.set_ylim([-2,3])


# a.text(s="LLR pval={:.2e}".format(p_value),fontsize=18,
#        x=.2,y=.8,transform=a.transAxes)



axis_to_data = a.transAxes + a.transData.inverted()
data_to_axis = axis_to_data.inverted()

y=data_to_axis.transform((.1,summary.shape[0]-.55))[1]

print('y',y)
a.text(s="Covariate".format(p_value),fontsize=20,
       x=.01,y=y,transform=a.transAxes)

a.text(s="HR (95% CI)".format(p_value),fontsize=20,
       x=.375,y=y,transform=a.transAxes)

a.text(s="P-value".format(p_value),fontsize=20,
       x=.85,y=y,transform=a.transAxes)

a.hlines(y=y-.02,xmin=-2,xmax=50,color='k',transform=a.transAxes,linewidth=3,linestyle='-')
# a.hlines(y=y-.03,xmin=-1,xmax=2,transform=a.transAxes,linewidth=1,linestyle='-')

for i,ind in enumerate(summary.index):
    y=data_to_axis.transform((.1,summary.shape[0]-i-1.2))[1]
    print('y',y)
    if summary.loc[ind,'p']<.05:
        a.text(s="{}*".format(ind),fontsize=20,
       x=-.1,y=y,transform=a.transAxes)
    else:
        a.text(s=ind,fontsize=20,
           x=-.1,y=y,
           transform=a.transAxes)
    hrtext="{:.2f}  ({:.2f}-{:.2f})".format(*summary.loc[ind,['exp(coef)',
                                                         'exp(coef) lower 95%','exp(coef) upper 95%']])
    pvaltext="{:.2e}".format(*summary.loc[ind,['p']])
    a.text(s=hrtext,fontsize=20,
       x=.35,y=y,
           transform=a.transAxes)
    a.text(s=pvaltext,fontsize=20,
       x=.85,y=y,
           transform=a.transAxes)
    
    x1,y1=data_to_axis.transform((.01,summary.shape[0]-i*.9-1.5))
    x2,y2=data_to_axis.transform((.01,summary.shape[0]-i*.9-.8))
    

    if i%2==0:
        crect=patches.Rectangle((-.1,y1),width=1.2,height=y2-y1,transform=a.transAxes,fill=True,
                               alpha=.05,color='k',clip_on=False)
#         crect2=patches.Rectangle((x2,y1),width=1.1-x2,height=y2-y1,transform=a.transAxes,fill=True,
#                                alpha=.05,color='k')
        a.add_patch(crect)
#         a.add_patch(crect2)
        
    
    

# a.set_title("CPH Model Survival",fontsize=18,fontweight='bold')
# cph.plot(ax=a)
a.text(s="Hazard Ratio",fontsize=18,x=1.25,
       y=-1.1,
       horizontalalignment='center')

f.suptitle('TCGA (Subseted)',fontsize=22,x=.5,y=.97,transform=f.transFigure)

f.subplots_adjust(top=.93,bottom=-.05,right=.95,left=.132,wspace=.0,hspace=1.5)
f.savefig(outfile,dpi=200)
plt.show()
# Out:
#                     coef  exp(coef)  se(coef)  coef lower 95%  coef upper 95%  \
# DDR_low_z_MUT  -0.225082   0.798451  0.172249       -0.562684        0.112521
# log(TMB)        0.174343   1.190464  0.034130        0.107450        0.241236
# DDRlow:highTMB -0.024752   0.975552  0.236337       -0.487964        0.438460
#
#                 exp(coef) lower 95%  exp(coef) upper 95%         z  \
# DDR_low_z_MUT              0.569678             1.119095 -1.306721
# log(TMB)                   1.113436             1.272822  5.108263
# DDRlow:highTMB             0.613875             1.550317 -0.104732
#
#                            p   -log2(p)
# DDR_low_z_MUT   1.913074e-01   2.386035
# log(TMB)        3.251345e-07  21.552460
# DDRlow:highTMB  9.165882e-01   0.125654
# ...

# %% [markdown]
# #### broken out by individual cancer types

# %%
tcga_data.clinical_bigbets_df.groupby(['DDR_low_z_TMB']).groups.keys()
# Out:
# dict_keys(['TMB-H_MUT', 'TMB-H_WT', 'TMB-L_MUT', 'TMB-L_WT'])

# %%
# outfile=os.path.join(graphics_dir,"samtstein_survival_low_zscore.png")
cph = lifelines.CoxPHFitter()
# vars2keep=['high_TMB','DDR_mut','DDR:highTMB']
vars2keep=['DDR_low_z']
# vars2keep=['DDR']
# vars2keep=[]

# ctype='Bladder Cancer'
outdir=os.path.join(graphics_dir,'tcga_survival_by_tumor_type_combined_set')
if not os.path.exists(outdir):
    os.makedirs(outdir)
    
ctype_counts=tcga_data.clinical_bigbets_df['type'].value_counts()
ctypes=[
    ['BLCA'],['LUAD','LUSC'],['SKCM'],['COAD'],['HNSC'],['BRCA'],['ESCA'],['KIRC'] #not enough TMB-H-MUT samples for kirc
]


ii=0

outfiles=[]

for ctype in ctypes:
    title_txt="+".join(ctype)
    tcga_data.clinical_bigbets_df_filt=tcga_data.clinical_bigbets_df.loc[tcga_data.clinical_bigbets_df['type'].isin(ctype),:]
    dummy_df=tcga_data.clinical_bigbets_df_filt.loc[:,['os_5yr','censOS_5yr']]
    for var in vars2keep:
        cdf=pd.get_dummies(tcga_data.clinical_bigbets_df_filt.loc[:,var])
        cdf.columns=map(lambda x: var+"_"+str(x),cdf.columns.values)
        dummy_df=pd.concat([dummy_df,cdf.iloc[:,:-1]],axis=1)

    dummy_df['TMB']=np.log1p(tcga_data.clinical_bigbets_df_filt.loc[:,'TMB'])
    dummy_df['DDRlow:highTMB']=tcga_data.clinical_bigbets_df_filt.loc[:,'DDRlowz:highTMB']
    try:
        res=cph.fit(dummy_df, 'os_5yr', event_col='censOS_5yr')
    except:
        if np.sum(dummy_df['DDRlow:highTMB'])==0:
            res=cph.fit(dummy_df.drop('DDRlow:highTMB',axis=1), 'os_5yr', event_col='censOS_5yr')
            print('not enough seperation for {:}'.format(ctype))
    summary=res.summary
#     print(res.summary)
    llrstat=cph.log_likelihood_ratio_test()
    llr=llrstat.test_statistic
    df=llrstat.degrees_freedom
    p_value=llrstat.p_value
    print(ctype,p_value)


    var='DDR_low_z_TMB'
    


    coms=tcga_data.clinical_bigbets_df_filt[var].unique()
    commap=dict(zip(coms,range(len(coms))))
    clust=list(map(lambda x: commap[x],tcga_data.clinical_bigbets_df_filt[var]))
    
    coutfile=os.path.join(outdir,"{:}_tcga_5yr_surv.png".format("_".join(ctype)))
    outfiles.append(coutfile)
    plt.close()
    f,a=plt.subplots(1,2,figsize=(7.5,10))

    nrows=10
    ncols=1

    ncols1=1
    nrows1=6

    a=plt.subplot2grid((nrows,ncols),(0,0),rowspan=nrows1,colspan=1)

    cols=[red+(1.0,),red+(.7,),blue+(1.0,),blue+(.7,)]

    kmf = lifelines.KaplanMeierFitter()
    df2test=tcga_data.clinical_bigbets_df_filt
    i=0
    for name,gdf in df2test.groupby(var):
        if re.search("WT",name):
            ls=':'
        else:
            ls='-'
        kmf.fit(gdf["os_5yr"], gdf["censOS_5yr"], label=name)
        kmf.plot(ax=a,ci_show=False,c=cols[i],linestyle=ls,
                 show_censors=True, censor_styles={'ms': 5, 'marker': '+'})
        i+=1


    handles, labels = a.get_legend_handles_labels()
    new_labels=['Low-BiG-BETS DDR Mut','Low-BiG-BETS DDR WT','Low-BiG-BETS DDR Mut','Low-BiG-BETS DDR WT']
    l=a.legend(loc=1,bbox_to_anchor=(.85,1.0),fontsize=14,
               frameon=False,handles=handles,labels=new_labels)
    for i,text in enumerate(l.get_texts()):
        plt.setp(text, color = cols[i])

    a.annotate(s='TMB-H',fontsize=14,xy=(.83,.925),xytext=(.86,.925),
           arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
           xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

    a.annotate(s='TMB-L',fontsize=14,xy=(.83,.825),xytext=(.86,.825),
           arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
           xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

    a.spines['right'].set_visible(False)
    a.spines['top'].set_visible(False)

    a.set_xlabel("months",fontsize=20)
    a.set_ylabel("5 yr overall survival",fontsize=20)

    # a.set_title("Kaplan-Meier Curve by TMB + low TMB Assoc.DDR Genes",fontsize=18,fontweight='bold')
    pval_df=bigbets.bipartite_helper_functions.get_os_stats(clust=clust,os='os_5yr',censOS='censOS_5yr',
                                                            samp_df=tcga_data.clinical_bigbets_df_filt)
    pval=pval_df['llr_pval'].values[0]
    a.text(x=.85,y=.05,s="CPH pval={:.1e}".format(pval),horizontalalignment='center',
           fontsize=14,transform=a.transAxes)



    a=plt.subplot2grid((nrows,ncols),(nrows1,0),rowspan=nrows-nrows1,colspan=1)
    # a=plt.subplot(1,2,2)
    # a.text(s='B)',fontsize=18,fontweight='bold',x=0.0,y=.95,transform=a.transAxes)
    # a.text(s='B)',fontsize=18,fontweight='bold',x=-.07,y=1.0,transform=a.transAxes)

    xlim_min=np.min(summary['coef']-1.96*summary['se(coef)'])
    xlim_max=np.max(summary['coef']+1.96*summary['se(coef)'])

    for i,ind in enumerate(summary.index):
        expcoef=summary.loc[ind,'exp(coef)']
        up=summary.loc[ind,'exp(coef) upper 95%']-expcoef
        low=expcoef-summary.loc[ind,'exp(coef) lower 95%']
        ebars=np.array([[low,up]]).T
        a.errorbar(x=[expcoef],alpha=.7,
                   y=[summary.shape[0]-1-i],marker='s',color='k',uplims=True, lolims=True,
                   xerr=ebars
    #                xerr=[1.96*summary.loc[ind,'se(coef)'],
                        )


    a.vlines(x=1.0,linestyle='--',alpha=.6,linewidth=1,color='k',
             ymin=0,ymax=summary.shape[0]-.9)

    a.set_xscale('log')
    a.set_xlim([.0000025,30])
    a.spines['bottom'].set_position(('data', -.4))
    a.spines['bottom'].set_bounds( 0.1,5)

    a.spines['left'].set_visible(False)
    a.spines['right'].set_visible(False)
    a.spines['top'].set_visible(False)
    a.set_yticks([])
    a.set_xticks([.1,1,5])
    a.xaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
    plt.minorticks_off()
    a.set_ylim([-2,3])


    # a.text(s="LLR pval={:.2e}".format(p_value),fontsize=18,
    #        x=.2,y=.8,transform=a.transAxes)



    axis_to_data = a.transAxes + a.transData.inverted()
    data_to_axis = axis_to_data.inverted()

    y=data_to_axis.transform((.1,summary.shape[0]-.55))[1]

    a.text(s="Covariate".format(p_value),fontsize=20,
           x=.01,y=y,transform=a.transAxes)

    a.text(s="HR (95% CI)".format(p_value),fontsize=20,
           x=.375,y=y,transform=a.transAxes)

    a.text(s="P-value".format(p_value),fontsize=20,
           x=.85,y=y,transform=a.transAxes)

    a.hlines(y=y-.02,xmin=-2,xmax=50,color='k',transform=a.transAxes,linewidth=3,linestyle='-')
    # a.hlines(y=y-.03,xmin=-1,xmax=2,transform=a.transAxes,linewidth=1,linestyle='-')

    for i,ind in enumerate(summary.index):
        y=data_to_axis.transform((.1,summary.shape[0]-i-1.2))[1]
        if summary.loc[ind,'p']<.05:
            a.text(s="{}*".format(ind),fontsize=20,
           x=-.1,y=y,transform=a.transAxes)
        else:
            a.text(s=ind,fontsize=20,
               x=-.1,y=y,
               transform=a.transAxes)
        hrtext="{:.2f}  ({:.2f}-{:.2f})".format(*summary.loc[ind,['exp(coef)',
                                                             'exp(coef) lower 95%','exp(coef) upper 95%']])
        pvaltext="{:.2e}".format(*summary.loc[ind,['p']])
        a.text(s=hrtext,fontsize=20,
           x=.35,y=y,
               transform=a.transAxes)
        a.text(s=pvaltext,fontsize=20,
           x=.85,y=y,
               transform=a.transAxes)

        x1,y1=data_to_axis.transform((.01,summary.shape[0]-i*.9-1.5))
        x2,y2=data_to_axis.transform((.01,summary.shape[0]-i*.9-.8))


        if i%2==0:
            crect=patches.Rectangle((-.1,y1),width=1.2,height=y2-y1,transform=a.transAxes,fill=True,
                                   alpha=.05,color='k',clip_on=False)
    #         crect2=patches.Rectangle((x2,y1),width=1.1-x2,height=y2-y1,transform=a.transAxes,fill=True,
    #                                alpha=.05,color='k')
            a.add_patch(crect)
    #         a.add_patch(crect2)




    # a.set_title("CPH Model Survival",fontsize=18,fontweight='bold')
    # cph.plot(ax=a)
    a.text(s="Hazard Ratio",fontsize=18,x=1.25,
           y=-1.1,
           horizontalalignment='center')

    f.suptitle('{:}'.format("_".join(ctype)),fontsize=22,x=.5,y=.97,transform=f.transFigure)

    f.subplots_adjust(top=.93,bottom=-.05,right=.95,left=.12,wspace=.0,hspace=1.5)
    f.savefig(coutfile,dpi=200)
    f.savefig(re.sub("\.png",".pdf",coutfile)) #save as pdf as well
    plt.close()
# Out:
# ['BLCA'] 0.0001382860061987797
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/lifelines/fitters/kaplan_meier_fitter.py:268: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   self.confidence_interval_ = self._bounds(cumulative_sq_[:, None], alpha, ci_labels)
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/lifelines/fitters/kaplan_meier_fitter.py:268: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   self.confidence_interval_ = self._bounds(cumulative_sq_[:, None], alpha, ci_labels)
# ...

# %%
#We see here in the BRCA data there are few events observed in the 5 yr time horizon  and in fact none for 
#the TMB-L_MUT group which makes the estimate unstable.
temp=tcga_data.clinical_bigbets_df.loc[tcga_data.clinical_bigbets_df['type']=='BRCA',:]
print(temp.groupby(["DDR_low_z_TMB"]).size())
temp.groupby('DDR_low_z_TMB')['censOS_5yr'].mean()
# Out:
# DDR_low_z_TMB
# TMB-H_MUT      9
# TMB-H_WT      18
# TMB-L_MUT     43
# TMB-L_WT     925
# dtype: int64
# DDR_low_z_TMB
# TMB-H_MUT    0.000000
# TMB-H_WT     0.055556
# TMB-L_MUT    0.023256
# TMB-L_WT     0.091892
# Name: censOS_5yr, dtype: float64

# %%
#We combine all of these together.  
letters=['A','B','C','D','E']

files=dict(zip(letters,outfiles))

outfile=os.path.join(graphics_dir,'combined_tcga_individual_tumor.pdf')
plt.close()
f=plt.gcf()

# f.set_size_inches((8.5,6.75))
f.set_size_inches((7.5*2,10*2))
nrows=2
ncols=2
                  
for i,ofile in enumerate(files):
    if i<4:     
        a=plt.subplot2grid((nrows,ncols),(i//2,i%2),colspan=1,rowspan=1)
    else:
        continue
#         a=plt.subplot2grid((nrows,ncols),(1,2),colspan=1,rowspan=2)
        
    im=mpimg.imread(files[letters[i]])
    a.set_axis_off()
    plt.imshow(im)
    a.text(s=letters[i],fontsize=20,fontweight='bold',x=0.01,y=.92,transform=a.transAxes)

# f.suptitle("Low BiG-BETS DDR Mutation by Tumor Types",x=.5,y=.99,fontsize=25,fontweight='bold')
f.subplots_adjust(top=.985,bottom=0,right=1.0,left=.01,hspace=0,wspace=0.05)
f.savefig(outfile,dpi=200)
plt.show()

# %% [markdown]
# ### High BiG-BETS DDR TCGA Survival

# %%
#High bigbets DDR genes survival analysis
outfile=os.path.join(supplements_dir,'tcga_data_survival_high_zscore.pdf')

cph = lifelines.CoxPHFitter()
# vars2keep=['high_TMB','DDR','DDR:highTMB']
vars2keep=['DDR_high_z']

#filter the types here to match those that are present in Samstein
tcga_types2keep=['LUAD','LUSC','BRCA','LGG',"SKCM",'COAD','ESCA','KIRC']
df_filt=tcga_data.clinical_bigbets_df.loc[tcga_data.clinical_bigbets_df['type'].isin(tcga_types2keep),:]

df_filt=df_filt.dropna(how='any',axis=0)


dummy_df=df_filt.loc[:,['os_5yr','censOS_5yr']]

for var in vars2keep:
    cdf=pd.get_dummies(df_filt.loc[:,var])
    cdf.columns=map(lambda x: var+"_"+str(x),cdf.columns.values)
    dummy_df=pd.concat([dummy_df,cdf.iloc[:,:-1]],axis=1)

dummy_df['log(TMB)']=np.log1p(df_filt.loc[:,'TMB'])
# dummy_df['TMB']=df_filt.loc[:,'high_TMB']
dummy_df['DDRhigh:highTMB']=df_filt.loc[:,'DDRhighz:highTMB']

res=cph.fit(dummy_df, 'os_5yr', event_col='censOS_5yr')
llrstat=cph.log_likelihood_ratio_test()
llr=llrstat.test_statistic
df=llrstat.degrees_freedom
p_value=llrstat.p_value
summary=res.summary
print(res.summary)

var='DDR_high_z_TMB'



coms=df_filt[var].unique()
commap=dict(zip(coms,range(len(coms))))
clust=list(map(lambda x: commap[x],df_filt[var]))

plt.close()
f,a=plt.subplots(1,2,figsize=(7.5,10))

nrows=10
ncols=1

ncols1=1
nrows1=6

a=plt.subplot2grid((nrows,ncols),(0,0),rowspan=nrows1,colspan=1)

# cols = [red + (1.0,), red + (.5,), blue + (1.0,), blue + (.5,)]
cols=[red+(1.0,),red+(.7,),blue+(1.0,),blue+(.7,)]

kmf = lifelines.KaplanMeierFitter()
df2test=df_filt
i=0
for name,gdf in df2test.groupby(var):
    if re.search("WT",name):
        ls=':'
    else:
        ls='-'
    kmf.fit(gdf["os_5yr"], gdf["censOS_5yr"], label=name)
    kmf.plot(ax=a,ci_show=False,c=cols[i],linestyle=ls,
             show_censors=True, censor_styles={'ms': 3, 'marker': '+'})
    i+=1
# lg_lines=lg.get_lines()
# for j,ln in enumerate(a.get_lines()):
#     ln.set_color(cols[j])
#     lg_lines[j].set_color(cols[j])

handles, labels = a.get_legend_handles_labels()
new_labels=['High-BiG-BETS DDR Mut','High-BiG-BETS DDR WT','High-BiG-BETS DDR Mut','High-BiG-BETS DDR WT']
l=a.legend(loc=1,bbox_to_anchor=(.85,1.0),fontsize=14,
           frameon=False,handles=handles,labels=new_labels)
for i,text in enumerate(l.get_texts()):
    plt.setp(text, color = cols[i])
    
a.annotate(s='TMB-H',fontsize=14,xy=(.83,.925),xytext=(.86,.925),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.annotate(s='TMB-L',fontsize=14,xy=(.83,.825),xytext=(.86,.825),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

a.set_xlabel("months",fontsize=20)
a.set_ylabel("overall 5yr survival",fontsize=20)

# a.set_title("Kaplan-Meier Curve by TMB + High TMB Assoc.DDR Genes",fontsize=18,fontweight='bold')
pval_df=bigbets.bipartite_helper_functions.get_os_stats(clust=clust,samp_df=df_filt)
pval=pval_df['llr_pval'].values[0]
a.text(x=.85,y=.03,s="CPH pval={:.1e}".format(pval),horizontalalignment='center',
       fontsize=16,transform=a.transAxes)



a=plt.subplot2grid((nrows,ncols),(nrows1,0),rowspan=nrows-nrows1,colspan=1)
# a=plt.subplot(1,2,2)
# a.text(s='B)',fontsize=18,fontweight='bold',x=0.0,y=.95,transform=a.transAxes)
# a.text(s='B)',fontsize=18,fontweight='bold',x=-.07,y=1.0,transform=a.transAxes)

xlim_min=np.min(summary['coef']-1.96*summary['se(coef)'])
xlim_max=np.max(summary['coef']+1.96*summary['se(coef)'])

for i,ind in enumerate(summary.index):
    expcoef=summary.loc[ind,'exp(coef)']
    up=summary.loc[ind,'exp(coef) upper 95%']-expcoef
    low=expcoef-summary.loc[ind,'exp(coef) lower 95%']
    ebars=np.array([[low,up]]).T
    a.errorbar(x=[expcoef],alpha=.7,
               y=[summary.shape[0]-1-i],marker='s',color='k',uplims=True, lolims=True,
               xerr=ebars
#                xerr=[1.96*summary.loc[ind,'se(coef)'],
                    )

    
a.vlines(x=1.0,linestyle='--',alpha=.6,linewidth=1,color='k',
         ymin=0,ymax=summary.shape[0]-.9)

a.set_xscale('log')
a.set_xlim([.0000025,30])
a.spines['bottom'].set_position(('data', -.4))
a.spines['bottom'].set_bounds( 0.1,5)

a.spines['left'].set_visible(False)
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)
a.set_yticks([])
a.set_xticks([.1,1,5])
a.xaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
plt.minorticks_off()
a.set_ylim([-2,3])


# a.text(s="LLR pval={:.2e}".format(p_value),fontsize=18,
#        x=.2,y=.8,transform=a.transAxes)



axis_to_data = a.transAxes + a.transData.inverted()
data_to_axis = axis_to_data.inverted()

y=data_to_axis.transform((.1,summary.shape[0]-.55))[1]

print('y',y)
a.text(s="Covariate".format(p_value),fontsize=20,
       x=.01,y=y,transform=a.transAxes)

a.text(s="HR (95% CI)".format(p_value),fontsize=20,
       x=.375,y=y,transform=a.transAxes)

a.text(s="P-value".format(p_value),fontsize=20,
       x=.85,y=y,transform=a.transAxes)

a.hlines(y=y-.02,xmin=-2,xmax=50,color='k',transform=a.transAxes,linewidth=3,linestyle='-')
# a.hlines(y=y-.03,xmin=-1,xmax=2,transform=a.transAxes,linewidth=1,linestyle='-')

for i,ind in enumerate(summary.index):
    y=data_to_axis.transform((.1,summary.shape[0]-i-1.2))[1]
    print('y',y)
    if summary.loc[ind,'p']<.05:
        a.text(s="{}*".format(ind),fontsize=20,
       x=-.1,y=y,transform=a.transAxes)
    else:
        a.text(s=ind,fontsize=20,
           x=-.1,y=y,
           transform=a.transAxes)
    hrtext="{:.2f}  ({:.2f}-{:.2f})".format(*summary.loc[ind,['exp(coef)',
                                                         'exp(coef) lower 95%','exp(coef) upper 95%']])
    pvaltext="{:.2e}".format(*summary.loc[ind,['p']])
    a.text(s=hrtext,fontsize=20,
       x=.35,y=y,
           transform=a.transAxes)
    a.text(s=pvaltext,fontsize=20,
       x=.85,y=y,
           transform=a.transAxes)
    
    x1,y1=data_to_axis.transform((.01,summary.shape[0]-i*.9-1.5))
    x2,y2=data_to_axis.transform((.01,summary.shape[0]-i*.9-.8))
    

    if i%2==0:
        crect=patches.Rectangle((-.1,y1),width=1.2,height=y2-y1,transform=a.transAxes,fill=True,
                               alpha=.05,color='k',clip_on=False)
#         crect2=patches.Rectangle((x2,y1),width=1.1-x2,height=y2-y1,transform=a.transAxes,fill=True,
#                                alpha=.05,color='k')
        a.add_patch(crect)
#         a.add_patch(crect2)
        
    
    

# a.set_title("CPH Model Survival",fontsize=18,fontweight='bold')
# cph.plot(ax=a)
a.text(s="Hazard Ratio",fontsize=18,x=1.25,
       y=-1.1,
       horizontalalignment='center')

f.suptitle('TCGA Pan-Cancer',fontsize=22,x=.5,y=.97,transform=f.transFigure)

f.subplots_adjust(top=.93,bottom=-.05,right=.95,left=.12,wspace=.0,hspace=1.5)
f.savefig(outfile,dpi=200)
plt.show()
# Out:
#                      coef  exp(coef)  se(coef)  coef lower 95%  \
# DDR_high_z_MUT   0.579827   1.785730  0.192495        0.202545
# log(TMB)         0.227556   1.255528  0.036979        0.155079
# DDRhigh:highTMB -0.938962   0.391033  0.270402       -1.468940
#
#                  coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%  \
# DDR_high_z_MUT         0.957110             1.224515             2.604159
# log(TMB)               0.300034             1.167750             1.349905
# DDRhigh:highTMB       -0.408984             0.230169             0.664325
#
#                         z             p   -log2(p)
# DDR_high_z_MUT   3.012175  2.593833e-03   8.590699
# log(TMB)         6.153654  7.571792e-10  30.298646
# DDRhigh:highTMB -3.472468  5.156962e-04  10.921191
# ...

# %%
#low bigbets DDR genes survival analysis
outfile=os.path.join(supplements_dir,'tcga_data_survival_subsetted_high_zscore.pdf')

cph = lifelines.CoxPHFitter()
# vars2keep=['high_TMB','DDR','DDR:highTMB']
vars2keep=['DDR_high_z']

#filter the types here to match those that are present in Samstein
df_filt=tcga_data.clinical_bigbets_data_type_filt.dropna(axis=0)

dummy_df=df_filt.loc[:,['os_5yr','censOS_5yr']]

for var in vars2keep:
    cdf=pd.get_dummies(df_filt.loc[:,var])
    cdf.columns=map(lambda x: var+"_"+str(x),cdf.columns.values)
    dummy_df=pd.concat([dummy_df,cdf.iloc[:,:-1]],axis=1)

dummy_df['log(TMB)']=np.log1p(df_filt.loc[:,'TMB'])
# dummy_df['TMB']=df_filt.loc[:,'high_TMB']
dummy_df['DDRhigh:highTMB']=df_filt.loc[:,'DDRhighz:highTMB']

res=cph.fit(dummy_df, 'os_5yr', event_col='censOS_5yr')
llrstat=cph.log_likelihood_ratio_test()
llr=llrstat.test_statistic
df=llrstat.degrees_freedom
p_value=llrstat.p_value
summary=res.summary
print(res.summary)

var='DDR_high_z_TMB'



coms=df_filt[var].unique()
commap=dict(zip(coms,range(len(coms))))
clust=list(map(lambda x: commap[x],df_filt[var]))

plt.close()
f,a=plt.subplots(1,2,figsize=(7.5,10))

nrows=10
ncols=1

ncols1=1
nrows1=6

a=plt.subplot2grid((nrows,ncols),(0,0),rowspan=nrows1,colspan=1)

# cols = [red + (1.0,), red + (.5,), blue + (1.0,), blue + (.5,)]
cols=[red+(1.0,),red+(.4,),blue+(1.0,),blue+(.4,)]

kmf = lifelines.KaplanMeierFitter()
df2test=df_filt
i=0
for name,gdf in df2test.groupby(var):
    if re.search("WT",name):
        ls=':'
    else:
        ls='-'
    kmf.fit(gdf["os_5yr"], gdf["censOS_5yr"], label=name)
    kmf.plot(ax=a,ci_show=False,c=cols[i],linestyle=ls,
             show_censors=True, censor_styles={'ms': 2, 'marker': '+'})
    i+=1
# lg_lines=lg.get_lines()
# for j,ln in enumerate(a.get_lines()):
#     ln.set_color(cols[j])
#     lg_lines[j].set_color(cols[j])

handles, labels = a.get_legend_handles_labels()
new_labels=['High-BiG-BETS DDR Mut','High-BiG-BETS DDR WT','High-BiG-BETS DDR Mut','High-BiG-BETS DDR WT']
l=a.legend(loc=1,bbox_to_anchor=(.85,1.0),fontsize=14,
           frameon=False,handles=handles,labels=new_labels)
for i,text in enumerate(l.get_texts()):
    plt.setp(text, color = cols[i])
    
a.annotate(s='TMB-H',fontsize=14,xy=(.83,.925),xytext=(.86,.925),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.annotate(s='TMB-L',fontsize=14,xy=(.83,.825),xytext=(.86,.825),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

a.set_xlabel("months",fontsize=20)
a.set_ylabel("overall 5yr survival",fontsize=20)

# a.set_title("Kaplan-Meier Curve by TMB + low TMB Assoc.DDR Genes",fontsize=18,fontweight='bold')
pval_df=bigbets.bipartite_helper_functions.get_os_stats(clust=clust,samp_df=df_filt)
pval=pval_df['llr_pval'].values[0]
a.text(x=.85,y=.03,s="CPH pval={:.1e}".format(pval),horizontalalignment='center',
       fontsize=16,transform=a.transAxes)



a=plt.subplot2grid((nrows,ncols),(nrows1,0),rowspan=nrows-nrows1,colspan=1)
# a=plt.subplot(1,2,2)
# a.text(s='B)',fontsize=18,fontweight='bold',x=0.0,y=.95,transform=a.transAxes)
# a.text(s='B)',fontsize=18,fontweight='bold',x=-.07,y=1.0,transform=a.transAxes)

xlim_min=np.min(summary['coef']-1.96*summary['se(coef)'])
xlim_max=np.max(summary['coef']+1.96*summary['se(coef)'])

for i,ind in enumerate(summary.index):
    expcoef=summary.loc[ind,'exp(coef)']
    up=summary.loc[ind,'exp(coef) upper 95%']-expcoef
    low=expcoef-summary.loc[ind,'exp(coef) lower 95%']
    ebars=np.array([[low,up]]).T
    a.errorbar(x=[expcoef],alpha=.7,
               y=[summary.shape[0]-1-i],marker='s',color='k',uplims=True, lolims=True,
               xerr=ebars
#                xerr=[1.96*summary.loc[ind,'se(coef)'],
                    )

    
a.vlines(x=1.0,linestyle='--',alpha=.6,linewidth=1,color='k',
         ymin=0,ymax=summary.shape[0]-.9)

a.set_xscale('log')
a.set_xlim([.0000025,30])
a.spines['bottom'].set_position(('data', -.4))
a.spines['bottom'].set_bounds( 0.1,5)

a.spines['left'].set_visible(False)
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)
a.set_yticks([])
a.set_xticks([.1,1,5])
a.xaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
plt.minorticks_off()
a.set_ylim([-2,3])


# a.text(s="LLR pval={:.2e}".format(p_value),fontsize=18,
#        x=.2,y=.8,transform=a.transAxes)



axis_to_data = a.transAxes + a.transData.inverted()
data_to_axis = axis_to_data.inverted()

y=data_to_axis.transform((.1,summary.shape[0]-.55))[1]

print('y',y)
a.text(s="Covariate".format(p_value),fontsize=20,
       x=.01,y=y,transform=a.transAxes)

a.text(s="HR (95% CI)".format(p_value),fontsize=20,
       x=.375,y=y,transform=a.transAxes)

a.text(s="P-value".format(p_value),fontsize=20,
       x=.85,y=y,transform=a.transAxes)

a.hlines(y=y-.02,xmin=-2,xmax=50,color='k',transform=a.transAxes,linewidth=3,linestyle='-')
# a.hlines(y=y-.03,xmin=-1,xmax=2,transform=a.transAxes,linewidth=1,linestyle='-')

for i,ind in enumerate(summary.index):
    y=data_to_axis.transform((.1,summary.shape[0]-i-1.2))[1]
    print('y',y)
    if summary.loc[ind,'p']<.05:
        a.text(s="{}*".format(ind),fontsize=20,
       x=-.1,y=y,transform=a.transAxes)
    else:
        a.text(s=ind,fontsize=20,
           x=-.1,y=y,
           transform=a.transAxes)
    hrtext="{:.2f}  ({:.2f}-{:.2f})".format(*summary.loc[ind,['exp(coef)',
                                                         'exp(coef) lower 95%','exp(coef) upper 95%']])
    pvaltext="{:.2e}".format(*summary.loc[ind,['p']])
    a.text(s=hrtext,fontsize=20,
       x=.35,y=y,
           transform=a.transAxes)
    a.text(s=pvaltext,fontsize=20,
       x=.85,y=y,
           transform=a.transAxes)
    
    x1,y1=data_to_axis.transform((.01,summary.shape[0]-i*.9-1.5))
    x2,y2=data_to_axis.transform((.01,summary.shape[0]-i*.9-.8))
    

    if i%2==0:
        crect=patches.Rectangle((-.1,y1),width=1.2,height=y2-y1,transform=a.transAxes,fill=True,
                               alpha=.05,color='k',clip_on=False)
#         crect2=patches.Rectangle((x2,y1),width=1.1-x2,height=y2-y1,transform=a.transAxes,fill=True,
#                                alpha=.05,color='k')
        a.add_patch(crect)
#         a.add_patch(crect2)
        
    
    

# a.set_title("CPH Model Survival",fontsize=18,fontweight='bold')
# cph.plot(ax=a)
a.text(s="Hazard Ratio",fontsize=18,x=1.25,
       y=-1.1,
       horizontalalignment='center')

f.suptitle('TCGA (Subseted)',fontsize=22,x=.5,y=.97,transform=f.transFigure)

f.subplots_adjust(top=.93,bottom=-.05,right=.95,left=.132,wspace=.0,hspace=1.5)
f.savefig(outfile,dpi=200)
plt.show()
# Out:
#                      coef  exp(coef)  se(coef)  coef lower 95%  \
# DDR_high_z_MUT   0.604809   1.830902  0.159477        0.292241
# log(TMB)         0.190302   1.209615  0.034638        0.122413
# DDRhigh:highTMB -0.986891   0.372734  0.233712       -1.444959
#
#                  coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%  \
# DDR_high_z_MUT         0.917377             1.339425             2.502718
# log(TMB)               0.258190             1.130221             1.294585
# DDRhigh:highTMB       -0.528823             0.235756             0.589298
#
#                         z             p   -log2(p)
# DDR_high_z_MUT   3.792462  1.491609e-04  12.710843
# log(TMB)         5.494083  3.927453e-08  24.601831
# DDRhigh:highTMB -4.222671  2.414246e-05  15.338068
# ...

# %%
tcga_data.clinical_bigbets_data_type_filt.groupby(['DDR_low_z_TMB']).size()
# Out:
# DDR_low_z_TMB
# TMB-H_MUT     157
# TMB-H_WT      725
# TMB-L_MUT     183
# TMB-L_WT     3222
# dtype: int64

# %% [markdown]
# ## immune signatures analysis

# %%
tcga_data.load_rnaseq_data()
tcga_data.get_cancer_types_filtered()
tcga_data.get_GSEA_signatures()
tcga_data.get_GSEA_signatures(use_filtered=True)
# Out:
# 2021-12-31 08:39:21,208:bigbets.load_tcga_dataset:INFO:Loading TCGA RNAseq data
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/numpy/lib/function_base.py:3405: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/numpy/lib/function_base.py:3405: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# ...

# %% [markdown]
# ### All tumor types

# %%
#TCGA all samples immune signatures for high TMB samples MUT vs WT
outfile=os.path.join(supplements_dir,'R1_Figure_S6B-E_tcga_data_signatures_by_low_z-ddrmut.pdf')
high_TMB_samps=tcga_data.clinical_bigbets_df.loc[tcga_data.clinical_bigbets_df['high_TMB']=='TMB-H',:]

design_mat=(high_TMB_samps.loc[:,'DDR_low_z']=='MUT').to_frame(name='DDRlowmutated')
#drop samples that don't have RNAseq
design_mat=design_mat.loc[design_mat.index.isin(tcga_data.ig_signatures.index),:]
# signatures_2_show={'IFNG':['Ayers_IFNG',"Higgs_IFNG",'50_HALLMARK_INFN_GAMMA_RESPONSE'],
#                    'Ayers_ICB_Sig':['Ayers_ICB_Response_predict'],
#                    "STING+IRF3":['ISHIKAWA_STING_SIGNALING','GRANDVAUX_IRF3_TARGETS_UP'],
#                   'T-cells':['13_T_Cell_EntrezID','18_Iglesia_CD8_cluster_EntrezID','25_Bindea_CD8_T_cells_EntrezID'],
#                   'EMT':['5_EMT_DOWN_EntrezID','6_EMT_UP_EntrezID','EMT_stroma_core_18','FTBRS']}


signatures_2_show={"ISHIKAWA STING Signaling":['ISHIKAWA_STING_SIGNALING'],
                   "Grandvaux IRF3 Targets UP":['GRANDVAUX_IRF3_TARGETS_UP'],
                  'T-cell':['13_T_Cell_EntrezID','18_Iglesia_CD8_cluster_EntrezID','25_Bindea_CD8_T_cells_EntrezID'],
                   'Immune Microenvironment':['EMT_stroma_core_18','FTBRS'],
                    'INFG':['50_HALLMARK_INFN_GAMMA_RESPONSE','Ayers_IFNG',"Higgs_IFNG"]}

sigs2names={'ISHIKAWA_STING_SIGNALING':"ISHIKAWA STING\nSIGNALING",
                  'GRANDVAUX_IRF3_TARGETS_UP':"GRANDVAUX IRF3\nTargets UP",
                  '13_T_Cell_EntrezID':'T_Cell',
                  '18_Iglesia_CD8_cluster_EntrezID':'Iglesia CD8\nCluster',
                  '25_Bindea_CD8_T_cells_EntrezID':"Bindea CD8\nT_cells",
                  'EMT_stroma_core_18':'EMT_stroma\nCore_18',
                  'FTBRS':'FTBRS',
                  '50_HALLMARK_INFN_GAMMA_RESPONSE':"Hallmark_IFN\nGamma_Response",
                  'Ayers_IFNG':'Ayers_IFNG','Higgs_IFNG':'Higgs_IFNG'}

letters=['B',"",'C','D','E']

all_sigs2show = [val for vals in signatures_2_show.values() for val in vals ]


plt.close()

pvals_df=pd.DataFrame(columns=['mwu_stat','mwu_pval'])
cols=sbn.color_palette('Set1',n_colors=2)
cols.reverse()
# cols=[blue,red]

ncols=len(all_sigs2show)*3

f=plt.gcf()
f.set_size_inches(23,6)

ii=0
cnt=0

colwidths={0:4,1:4,2:8,3:6,4:8}


for name,sig_set in signatures_2_show.items():
    print(ii,name)
    a=plt.subplot2grid((1,ncols),(0,cnt),colspan=colwidths[ii])
    combined_df=pd.DataFrame()
    for i,sig in enumerate(sig_set):
        cdf=tcga_data.ig_signatures.loc[:,[sig]]
        cdf.columns=['score']
        cdf.loc[:,'sample']=cdf.index.values
        cdf.loc[:,'IG_signature']=sig
        cdf.loc[design_mat.index,'lowzDDR_mut']=design_mat['DDRlowmutated'].apply(lambda x:  'MUT' if x else 'WT')
        
        mwu,pval=stats.mannwhitneyu(cdf[cdf['lowzDDR_mut']=='WT']['score'],
                                   cdf[cdf['lowzDDR_mut']=='MUT']['score'])
        pvals_df.loc[sig,['mwu_stat','mwu_pval']]=mwu,pval
        combined_df=pd.concat([combined_df,cdf])
    
    
    bp=sbn.boxplot(data=combined_df,x='IG_signature',palette=cols,
               y='score',hue='lowzDDR_mut',ax=a,fliersize=0)
    
#     adjust_box_widths(f, 0.9)
    
    a.set_ylim([-3,6])
    a.spines['right'].set_visible(False)
    a.spines['top'].set_visible(False)
    
    for i,sig in enumerate(combined_df['IG_signature'].unique()):
        ymax=combined_df[combined_df['IG_signature']==sig]['score'].max()
        pval=pvals_df.loc[sig,'mwu_pval']
        if pval<.05:
            a.text(s="p={:.1e}*".format(pval),horizontalalignment='center',fontsize=18,
              x=i,y=4)
        else:
#             a.text(s="{:.1e}".format(pval),horizontalalignment='center',fontsize=18,
#               x=i,y=4)
            a.text(s="n.s.".format(pval),horizontalalignment='center',fontsize=18,
              x=i,y=4)
    
        a.text(s="{:}".format(sigs2names[sig]),horizontalalignment='center',fontsize=16,
          x=i,y=6)
        

    a.set_ylabel('z-score',fontsize=18)
    
    a.get_legend().set_visible(False)
        
#         a.get_yaxis().set_visible(False)

    
#     a.text(s=name,x=.5,y=.9,horizontalalignment='center',transform=a.transAxes,
#            fontsize=18,fontweight='bold')

    a.text(s=letters[ii],x=0,y=1.02,horizontalalignment='center',transform=a.transAxes,
           fontsize=14,fontweight='bold')
    new_labs=['WT','MUT']*len(sig_set)
    new_ticks=[j for jj in [[j-.24,j+.24] for j in range(len(sig_set))] for j in jj]
    a.set_xticks(new_ticks)        
    a.set_xticklabels(new_labs,fontsize=14)
    a.set_xlabel("")
    
    for j in range(1,len(sig_set)+1):
        xcoord=j/len(sig_set)-.5/len(sig_set)
        a.annotate(s='Low BiG-BET DDR',fontsize=12,xy=(xcoord,-.07),xytext=(xcoord,-.11),
           arrowprops=dict(arrowstyle='-[, widthB=4, lengthB=0', lw=1.0),
           xycoords='axes fraction',verticalalignment='center',horizontalalignment='center',transform=a.transAxes)
#     cnt+=len(sig_set)
    cnt+=colwidths[ii]
    ii+=1

f.subplots_adjust(left=0.035,right=.98,bottom=.12,top=.9,wspace=3.1)
# f.suptitle("tcga_data210 Expression Data (TMB-H)",x=.5,y=1.05,fontsize=18,fontweight='bold')
f.savefig(outfile,dpi=200)

plt.show()
# Out:
# 0 ISHIKAWA STING Signaling
# 1 Grandvaux IRF3 Targets UP
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:118: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:118: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# 2 T-cell
# 3 Immune Microenvironment
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:118: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# ...

# %% [markdown]
# ### Filtered to match samstein
# types2keep=['LUAD','LUSC','BRCA',"SKCM",'COAD','ESCA','KIRC','BLCA','HNSC']

# %%
#TCGA (filtered by types) immune signatures for high TMB samples MUT vs WT
outfile=os.path.join(supplements_dir,'R1_Figure_S6B-E_tcga_data_types_filtered_signatures_by_low_z-ddrmut.pdf')
high_TMB_samps=tcga_data.clinical_bigbets_data_type_filt.loc[tcga_data.clinical_bigbets_data_type_filt['high_TMB']=='TMB-H',:]

design_mat=(high_TMB_samps.loc[:,'DDR_low_z']=='MUT').to_frame(name='DDRlowmutated')
#drop samples that don't have RNAseq
design_mat=design_mat.loc[design_mat.index.isin(tcga_data.ig_signatures_type_filt.index),:]


signatures_2_show={"ISHIKAWA STING Signaling":['ISHIKAWA_STING_SIGNALING'],
                   "Grandvaux IRF3 Targets UP":['GRANDVAUX_IRF3_TARGETS_UP'],
                  'T-cell':['13_T_Cell_EntrezID','18_Iglesia_CD8_cluster_EntrezID','25_Bindea_CD8_T_cells_EntrezID'],
                   'Immune Microenvironment':['EMT_stroma_core_18','FTBRS'],
                    'INFG':['50_HALLMARK_INFN_GAMMA_RESPONSE','Ayers_IFNG',"Higgs_IFNG"]}

sigs2names={'ISHIKAWA_STING_SIGNALING':"ISHIKAWA STING\nSIGNALING",
                  'GRANDVAUX_IRF3_TARGETS_UP':"GRANDVAUX IRF3\nTargets UP",
                  '13_T_Cell_EntrezID':'T_Cell',
                  '18_Iglesia_CD8_cluster_EntrezID':'Iglesia CD8\nCluster',
                  '25_Bindea_CD8_T_cells_EntrezID':"Bindea CD8\nT_cells",
                  'EMT_stroma_core_18':'EMT_stroma\nCore_18',
                  'FTBRS':'FTBRS',
                  '50_HALLMARK_INFN_GAMMA_RESPONSE':"Hallmark_IFN\nGamma_Response",
                  'Ayers_IFNG':'Ayers_IFNG','Higgs_IFNG':'Higgs_IFNG'}

letters=['D',"",'E','F','G']

all_sigs2show = [val for vals in signatures_2_show.values() for val in vals ]


plt.close()

pvals_df=pd.DataFrame(columns=['mwu_stat','mwu_pval'])
cols=sbn.color_palette('Set1',n_colors=2)
cols.reverse()
# cols=[blue,red]

ncols=len(all_sigs2show)*3

f=plt.gcf()
f.set_size_inches(23,6)

ii=0
cnt=0

colwidths={0:4,1:4,2:8,3:6,4:8}


for name,sig_set in signatures_2_show.items():
    print(ii,name)
    a=plt.subplot2grid((1,ncols),(0,cnt),colspan=colwidths[ii])
    combined_df=pd.DataFrame()
    for i,sig in enumerate(sig_set):
        cdf=tcga_data.ig_signatures_type_filt.loc[:,[sig]]
        cdf.columns=['score']
        cdf.loc[:,'sample']=cdf.index.values
        cdf.loc[:,'IG_signature']=sig
        cdf.loc[design_mat.index,'lowzDDR_mut']=design_mat['DDRlowmutated'].apply(lambda x:  'MUT' if x else 'WT')
        
        mwu,pval=stats.mannwhitneyu(cdf[cdf['lowzDDR_mut']=='WT']['score'],
                                   cdf[cdf['lowzDDR_mut']=='MUT']['score'])
        pvals_df.loc[sig,['mwu_stat','mwu_pval']]=mwu,pval
        combined_df=pd.concat([combined_df,cdf])
    
    
    bp=sbn.boxplot(data=combined_df,x='IG_signature',palette=cols,
               y='score',hue='lowzDDR_mut',ax=a,fliersize=0)
    
#     adjust_box_widths(f, 0.9)
    
    a.set_ylim([-3,6])
    a.spines['right'].set_visible(False)
    a.spines['top'].set_visible(False)
    
    for i,sig in enumerate(combined_df['IG_signature'].unique()):
        ymax=combined_df[combined_df['IG_signature']==sig]['score'].max()
        pval=pvals_df.loc[sig,'mwu_pval']
        if pval<.05:
            a.text(s="p={:.1e}*".format(pval),horizontalalignment='center',fontsize=18,
              x=i,y=4)
        else:
#             a.text(s="{:.1e}".format(pval),horizontalalignment='center',fontsize=18,
#               x=i,y=4)
            a.text(s="n.s.".format(pval),horizontalalignment='center',fontsize=18,
              x=i,y=4)
    
        a.text(s="{:}".format(sigs2names[sig]),horizontalalignment='center',fontsize=16,
          x=i,y=6)
        

    a.set_ylabel('z-score',fontsize=18)
    
    a.get_legend().set_visible(False)
        
#         a.get_yaxis().set_visible(False)

    
#     a.text(s=name,x=.5,y=.9,horizontalalignment='center',transform=a.transAxes,
#            fontsize=18,fontweight='bold')

    a.text(s=letters[ii],x=0,y=1.02,horizontalalignment='center',transform=a.transAxes,
           fontsize=14,fontweight='bold')
    new_labs=['WT','MUT']*len(sig_set)
    new_ticks=[j for jj in [[j-.24,j+.24] for j in range(len(sig_set))] for j in jj]
    a.set_xticks(new_ticks)        
    a.set_xticklabels(new_labs,fontsize=14)
    a.set_xlabel("")
    
    for j in range(1,len(sig_set)+1):
        print(j/len(sig_set))
        xcoord=j/len(sig_set)-.5/len(sig_set)
        a.annotate(s='Low BiG-BET DDR',fontsize=12,xy=(xcoord,-.07),xytext=(xcoord,-.11),
           arrowprops=dict(arrowstyle='-[, widthB=4, lengthB=0', lw=1.0),
           xycoords='axes fraction',verticalalignment='center',horizontalalignment='center',transform=a.transAxes)
#     cnt+=len(sig_set)
    cnt+=colwidths[ii]
    ii+=1

f.subplots_adjust(left=0.035,right=.98,bottom=.12,top=.9,wspace=3.1)
# f.suptitle("tcga_data210 Expression Data (TMB-H)",x=.5,y=1.05,fontsize=18,fontweight='bold')
f.savefig(outfile,dpi=200)

plt.show()
# Out:
# 0 ISHIKAWA STING Signaling
# 1.0
# 1 Grandvaux IRF3 Targets UP
# 1.0
# 2 T-cell
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:114: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:114: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# 0.3333333333333333
# 0.6666666666666666
# 1.0
# 3 Immune Microenvironment
# 0.5
# 1.0
# 4 INFG
# ...

# %% [markdown]
# ###  BLCA only

# %%
tcga_data.get_cancer_types_filtered(types2keep=['BLCA'])
tcga_data.get_GSEA_signatures(use_filtered=True)
print(tcga_data.clinical_bigbets_data_type_filt.shape)
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/numpy/lib/function_base.py:3405: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# (408, 34)

# %%
#TCGA (filtered by types) immune signatures for high TMB samples MUT vs WT
outfile=os.path.join(supplements_dir,'tcga_data_signatures_BLCAonly_by_low_z-ddrmut.pdf')
high_TMB_samps=tcga_data.clinical_bigbets_data_type_filt.loc[tcga_data.clinical_bigbets_data_type_filt['high_TMB']=='TMB-H',:]

design_mat=(high_TMB_samps.loc[:,'DDR_low_z']=='MUT').to_frame(name='DDRlowmutated')
#drop samples that don't have RNAseq
design_mat=design_mat.loc[design_mat.index.isin(tcga_data.ig_signatures_type_filt.index),:]


signatures_2_show={"ISHIKAWA STING Signaling":['ISHIKAWA_STING_SIGNALING'],
                   "Grandvaux IRF3 Targets UP":['GRANDVAUX_IRF3_TARGETS_UP'],
                  'T-cell':['13_T_Cell_EntrezID','18_Iglesia_CD8_cluster_EntrezID','25_Bindea_CD8_T_cells_EntrezID'],
                   'Immune Microenvironment':['EMT_stroma_core_18','FTBRS'],
                    'INFG':['50_HALLMARK_INFN_GAMMA_RESPONSE','Ayers_IFNG',"Higgs_IFNG"]}

sigs2names={'ISHIKAWA_STING_SIGNALING':"ISHIKAWA STING\nSIGNALING",
                  'GRANDVAUX_IRF3_TARGETS_UP':"GRANDVAUX IRF3\nTargets UP",
                  '13_T_Cell_EntrezID':'T_Cell',
                  '18_Iglesia_CD8_cluster_EntrezID':'Iglesia CD8\nCluster',
                  '25_Bindea_CD8_T_cells_EntrezID':"Bindea CD8\nT_cells",
                  'EMT_stroma_core_18':'EMT_stroma\nCore_18',
                  'FTBRS':'FTBRS',
                  '50_HALLMARK_INFN_GAMMA_RESPONSE':"Hallmark_IFN\nGamma_Response",
                  'Ayers_IFNG':'Ayers_IFNG','Higgs_IFNG':'Higgs_IFNG'}

letters=['D',"",'E','F','G']

all_sigs2show = [val for vals in signatures_2_show.values() for val in vals ]


plt.close()

pvals_df=pd.DataFrame(columns=['mwu_stat','mwu_pval'])
cols=sbn.color_palette('Set1',n_colors=2)
cols.reverse()
# cols=[blue,red]

ncols=len(all_sigs2show)*3

f=plt.gcf()
f.set_size_inches(23,6)

ii=0
cnt=0

colwidths={0:4,1:4,2:8,3:6,4:8}


for name,sig_set in signatures_2_show.items():
    print(ii,name)
    a=plt.subplot2grid((1,ncols),(0,cnt),colspan=colwidths[ii])
    combined_df=pd.DataFrame()
    for i,sig in enumerate(sig_set):
        cdf=tcga_data.ig_signatures.loc[:,[sig]]
        cdf.columns=['score']
        cdf.loc[:,'sample']=cdf.index.values
        cdf.loc[:,'IG_signature']=sig
        cdf.loc[design_mat.index,'lowzDDR_mut']=design_mat['DDRlowmutated'].apply(lambda x:  'MUT' if x else 'WT')
        
        mwu,pval=stats.mannwhitneyu(cdf[cdf['lowzDDR_mut']=='WT']['score'],
                                   cdf[cdf['lowzDDR_mut']=='MUT']['score'])
        pvals_df.loc[sig,['mwu_stat','mwu_pval']]=mwu,pval
        combined_df=pd.concat([combined_df,cdf])
    
    
    bp=sbn.boxplot(data=combined_df,x='IG_signature',palette=cols,
               y='score',hue='lowzDDR_mut',ax=a,fliersize=0)
    
#     adjust_box_widths(f, 0.9)
    
    a.set_ylim([-3,6])
    a.spines['right'].set_visible(False)
    a.spines['top'].set_visible(False)
    
    for i,sig in enumerate(combined_df['IG_signature'].unique()):
        ymax=combined_df[combined_df['IG_signature']==sig]['score'].max()
        pval=pvals_df.loc[sig,'mwu_pval']
        if pval<.05:
            a.text(s="p={:.1e}*".format(pval),horizontalalignment='center',fontsize=18,
              x=i,y=4)
        else:
#             a.text(s="{:.1e}".format(pval),horizontalalignment='center',fontsize=18,
#               x=i,y=4)
            a.text(s="n.s.".format(pval),horizontalalignment='center',fontsize=18,
              x=i,y=4)
    
        a.text(s="{:}".format(sigs2names[sig]),horizontalalignment='center',fontsize=16,
          x=i,y=6)
        

    a.set_ylabel('z-score',fontsize=18)
    
    a.get_legend().set_visible(False)
        
#         a.get_yaxis().set_visible(False)

    
#     a.text(s=name,x=.5,y=.9,horizontalalignment='center',transform=a.transAxes,
#            fontsize=18,fontweight='bold')

    a.text(s=letters[ii],x=0,y=1.02,horizontalalignment='center',transform=a.transAxes,
           fontsize=14,fontweight='bold')
    new_labs=['WT','MUT']*len(sig_set)
    new_ticks=[j for jj in [[j-.24,j+.24] for j in range(len(sig_set))] for j in jj]
    a.set_xticks(new_ticks)        
    a.set_xticklabels(new_labs,fontsize=14)
    a.set_xlabel("")
    
    for j in range(1,len(sig_set)+1):
        xcoord=j/len(sig_set)-.5/len(sig_set)
        a.annotate(s='Low BiG-BET DDR',fontsize=12,xy=(xcoord,-.07),xytext=(xcoord,-.11),
           arrowprops=dict(arrowstyle='-[, widthB=4, lengthB=0', lw=1.0),
           xycoords='axes fraction',verticalalignment='center',horizontalalignment='center',transform=a.transAxes)
#     cnt+=len(sig_set)
    cnt+=colwidths[ii]
    ii+=1

f.subplots_adjust(left=0.035,right=.98,bottom=.12,top=.9,wspace=3.1)
# f.suptitle("tcga_data210 Expression Data (TMB-H)",x=.5,y=1.05,fontsize=18,fontweight='bold')
f.savefig(outfile,dpi=200)

plt.show()
# Out:
# 0 ISHIKAWA STING Signaling
# 1 Grandvaux IRF3 Targets UP
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:113: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:113: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:113: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# 2 T-cell
# 3 Immune Microenvironment
# ...

# %% [markdown]
# # Other datasets

# %% [markdown]
# ## Braun et all 2020 RCC dataset

# %%
#this one takes forever to load since it is WES 
braun=bigbets.Braun2020Dataset()
# Out:
# 2021-12-31 10:40:52,557:bigbets.load_clinical_datasets:INFO:loading Braun genomic data
# 2021-12-31 10:44:15,454:bigbets.load_clinical_datasets:INFO:loading Braun clinical data
# vars2keep 30448
# ../bigbets/load_clinical_datasets.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ddr_bigbets_filt_df.sort_values(by='bigbets', inplace=True)
# 2021-12-31 10:47:27,940:root:INFO:BER 10
# 2021-12-31 10:47:27,997:root:INFO:NER 26
# 2021-12-31 10:47:28,056:root:INFO:MMR 18
# 2021-12-31 10:47:28,112:root:INFO:FA 11
# 2021-12-31 10:47:28,165:root:INFO:HR 41
# 2021-12-31 10:47:28,221:root:INFO:NHEJ 10
# 2021-12-31 10:47:28,276:root:INFO:DS 31
# 2021-12-31 10:47:28,370:root:INFO:histone_modification_pathway 372
# 2021-12-31 10:47:28,482:root:INFO:chromatin_remodel 355

# %% [markdown]
# ### Survival Analyses

# %% [markdown]
# #### Low Big_BETS DDR Mutations

# %%
#low bigbets DDR genes survival analysis
outfile=os.path.join(supplements_dir,'R1_Figure_S5C_braun_survival_low_zscore.pdf')

cph = lifelines.CoxPHFitter()
# vars2keep=['high_TMB','DDR','DDR:highTMB']
vars2keep=['DDR_low_z']

dummy_df=braun.clinical_bigbets_df.loc[:,['os','censOS']]

for var in vars2keep:
    cdf=pd.get_dummies(braun.clinical_bigbets_df.loc[:,var])
    cdf.columns=map(lambda x: var+"_"+str(x),cdf.columns.values)
    dummy_df=pd.concat([dummy_df,cdf.iloc[:,:-1]],axis=1)

dummy_df['log(TMB)']=np.log1p(braun.clinical_bigbets_df.loc[:,'TMB'])
# dummy_df['TMB']=braun.clinical_bigbets_df.loc[:,'high_TMB']

dummy_df['DDRlow:highTMB']=braun.clinical_bigbets_df.loc[:,'DDRlowz:highTMB']

res=cph.fit(dummy_df, 'os', event_col='censOS')
llrstat=cph.log_likelihood_ratio_test()
llr=llrstat.test_statistic
df=llrstat.degrees_freedom
p_value=llrstat.p_value
summary=res.summary
print(res.summary)

var='DDR_low_z_TMB'



coms=braun.clinical_bigbets_df[var].unique()
commap=dict(zip(coms,range(len(coms))))
clust=list(map(lambda x: commap[x],braun.clinical_bigbets_df[var]))

plt.close()
f,a=plt.subplots(1,2,figsize=(7.5,10))

nrows=10
ncols=1

ncols1=1
nrows1=6

a=plt.subplot2grid((nrows,ncols),(0,0),rowspan=nrows1,colspan=1)

cols = [red + (1.0,), red + (.5,), blue + (1.0,), blue + (.5,)]
cols=[red+(1.0,),red+(.7,),blue+(1.0,),blue+(.7,)]

kmf = lifelines.KaplanMeierFitter()
df2test=braun.clinical_bigbets_df
i=0
for name,gdf in df2test.groupby(var):
    if re.search("WT",name):
        ls=':'
    else:
        ls='-'
    kmf.fit(gdf["os"], gdf["censOS"], label=name)
    kmf.plot(ax=a,ci_show=False,c=cols[i],linestyle=ls,
             show_censors=True, censor_styles={'ms': 5, 'marker': '+'})
    i+=1
# lg_lines=lg.get_lines()
# for j,ln in enumerate(a.get_lines()):
#     ln.set_color(cols[j])
#     lg_lines[j].set_color(cols[j])

handles, labels = a.get_legend_handles_labels()
new_labels=['Low-BiG-BETS DDR Mut','Low-BiG-BETS DDR WT','Low-BiG-BETS DDR Mut','Low-BiG-BETS DDR WT']
l=a.legend(loc=1,bbox_to_anchor=(.85,1.0),fontsize=14,
           frameon=False,handles=handles,labels=new_labels)
for i,text in enumerate(l.get_texts()):
    plt.setp(text, color = cols[i])
    
a.annotate(s='TMB-H',fontsize=14,xy=(.83,.925),xytext=(.86,.925),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.annotate(s='TMB-L',fontsize=14,xy=(.83,.825),xytext=(.86,.825),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

a.set_xlabel("months",fontsize=20)
a.set_ylabel("overall survival",fontsize=20)

# a.set_title("Kaplan-Meier Curve by TMB + low TMB Assoc.DDR Genes",fontsize=18,fontweight='bold')
pval_df=bigbets.bipartite_helper_functions.get_os_stats(clust=clust,samp_df=braun.clinical_bigbets_df)
pval=pval_df['llr_pval'].values[0]
a.text(x=.85,y=.05,s="CPH pval={:.1e}".format(pval),horizontalalignment='center',
       fontsize=14,transform=a.transAxes)



a=plt.subplot2grid((nrows,ncols),(nrows1,0),rowspan=nrows-nrows1,colspan=1)
# a=plt.subplot(1,2,2)
# a.text(s='B)',fontsize=18,fontweight='bold',x=0.0,y=.95,transform=a.transAxes)
# a.text(s='B)',fontsize=18,fontweight='bold',x=-.07,y=1.0,transform=a.transAxes)

xlim_min=np.min(summary['coef']-1.96*summary['se(coef)'])
xlim_max=np.max(summary['coef']+1.96*summary['se(coef)'])

for i,ind in enumerate(summary.index):
    expcoef=summary.loc[ind,'exp(coef)']
    up=summary.loc[ind,'exp(coef) upper 95%']-expcoef
    low=expcoef-summary.loc[ind,'exp(coef) lower 95%']
    ebars=np.array([[low,up]]).T
    a.errorbar(x=[expcoef],alpha=.7,
               y=[summary.shape[0]-1-i],marker='s',color='k',uplims=True, lolims=True,
               xerr=ebars
#                xerr=[1.96*summary.loc[ind,'se(coef)'],
                    )

    
a.vlines(x=1.0,linestyle='--',alpha=.6,linewidth=1,color='k',
         ymin=0,ymax=summary.shape[0]-.9)

a.set_xscale('log')
a.set_xlim([.0000025,30])
a.spines['bottom'].set_position(('data', -.4))
a.spines['bottom'].set_bounds( 0.1,5)

a.spines['left'].set_visible(False)
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)
a.set_yticks([])
a.set_xticks([.1,1,5])
a.xaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
plt.minorticks_off()
a.set_ylim([-2,3])


# a.text(s="LLR pval={:.2e}".format(p_value),fontsize=18,
#        x=.2,y=.8,transform=a.transAxes)



axis_to_data = a.transAxes + a.transData.inverted()
data_to_axis = axis_to_data.inverted()

y=data_to_axis.transform((.1,summary.shape[0]-.55))[1]

print('y',y)
a.text(s="Covariate".format(p_value),fontsize=20,
       x=.01,y=y,transform=a.transAxes)

a.text(s="HR (95% CI)".format(p_value),fontsize=20,
       x=.375,y=y,transform=a.transAxes)

a.text(s="P-value".format(p_value),fontsize=20,
       x=.85,y=y,transform=a.transAxes)

a.hlines(y=y-.02,xmin=-2,xmax=50,color='k',transform=a.transAxes,linewidth=3,linestyle='-')
# a.hlines(y=y-.03,xmin=-1,xmax=2,transform=a.transAxes,linewidth=1,linestyle='-')

for i,ind in enumerate(summary.index):
    y=data_to_axis.transform((.1,summary.shape[0]-i-1.2))[1]
    print('y',y)
    if summary.loc[ind,'p']<.05:
        a.text(s="{}*".format(ind),fontsize=20,
       x=-.1,y=y,transform=a.transAxes)
    else:
        a.text(s=ind,fontsize=20,
           x=-.1,y=y,
           transform=a.transAxes)
    hrtext="{:.2f}  ({:.2f}-{:.2f})".format(*summary.loc[ind,['exp(coef)',
                                                         'exp(coef) lower 95%','exp(coef) upper 95%']])
    pvaltext="{:.2e}".format(*summary.loc[ind,['p']])
    a.text(s=hrtext,fontsize=20,
       x=.35,y=y,
           transform=a.transAxes)
    a.text(s=pvaltext,fontsize=20,
       x=.85,y=y,
           transform=a.transAxes)
    
    x1,y1=data_to_axis.transform((.01,summary.shape[0]-i*.9-1.5))
    x2,y2=data_to_axis.transform((.01,summary.shape[0]-i*.9-.8))
    

    if i%2==0:
        crect=patches.Rectangle((-.1,y1),width=1.2,height=y2-y1,transform=a.transAxes,fill=True,
                               alpha=.05,color='k',clip_on=False)
#         crect2=patches.Rectangle((x2,y1),width=1.1-x2,height=y2-y1,transform=a.transAxes,fill=True,
#                                alpha=.05,color='k')
        a.add_patch(crect)
#         a.add_patch(crect2)
        
    
    

# a.set_title("CPH Model Survival",fontsize=18,fontweight='bold')
# cph.plot(ax=a)
a.text(s="Hazard Ratio",fontsize=18,x=1.25,
       y=-1.1,
       horizontalalignment='center')

f.suptitle('Braun et al. 2020',fontsize=22,x=.5,y=.97,transform=f.transFigure)

f.subplots_adjust(top=.93,bottom=-.05,right=.95,left=.12,wspace=.0,hspace=1.5)
f.savefig(outfile,dpi=200)
plt.show()
# Out:
#                     coef  exp(coef)  se(coef)  coef lower 95%  coef upper 95%  \
# DDR_low_z_MUT   0.400801   1.493020  0.186517        0.035235        0.766367
# log(TMB)        0.009466   1.009511  0.115121       -0.216167        0.235099
# DDRlow:highTMB -0.526766   0.590511  0.356792       -1.226066        0.172534
#
#                 exp(coef) lower 95%  exp(coef) upper 95%         z         p  \
# DDR_low_z_MUT              1.035864             2.151934  2.148877  0.031644
# log(TMB)                   0.805601             1.265034  0.082228  0.934465
# DDRlow:highTMB             0.293445             1.188312 -1.476395  0.139838
#
#                 -log2(p)
# DDR_low_z_MUT   4.981917
# log(TMB)        0.097787
# DDRlow:highTMB  2.838173
# ...

# %% [markdown]
# #### High Big_BETS DDR Mutations

# %%
#high bigbets DDR genes survival analysis
outfile=os.path.join(supplements_dir,'braun_survival_high_zscore.pdf')

cph = lifelines.CoxPHFitter()
# vars2keep=['high_TMB','DDR','DDR:highTMB']
vars2keep=['DDR_high_z']

dummy_df=braun.clinical_bigbets_df.loc[:,['os','censOS']]

for var in vars2keep:
    cdf=pd.get_dummies(braun.clinical_bigbets_df.loc[:,var])
    cdf.columns=map(lambda x: var+"_"+str(x),cdf.columns.values)
    dummy_df=pd.concat([dummy_df,cdf.iloc[:,:-1]],axis=1)

dummy_df['log(TMB)']=np.log1p(braun.clinical_bigbets_df.loc[:,'TMB'])
# dummy_df['TMB']=braun.clinical_bigbets_df.loc[:,'high_TMB']

dummy_df['DDRhigh:highTMB']=braun.clinical_bigbets_df.loc[:,'DDRhighz:highTMB']

res=cph.fit(dummy_df, 'os', event_col='censOS')
llrstat=cph.log_likelihood_ratio_test()
llr=llrstat.test_statistic
df=llrstat.degrees_freedom
p_value=llrstat.p_value
summary=res.summary
print(res.summary)

var='DDR_high_z_TMB'



coms=braun.clinical_bigbets_df[var].unique()
commap=dict(zip(coms,range(len(coms))))
clust=list(map(lambda x: commap[x],braun.clinical_bigbets_df[var]))

plt.close()
f,a=plt.subplots(1,2,figsize=(7.5,10))

nrows=10
ncols=1

ncols1=1
nrows1=6

a=plt.subplot2grid((nrows,ncols),(0,0),rowspan=nrows1,colspan=1)

cols = [red + (1.0,), red + (.5,), blue + (1.0,), blue + (.5,)]
cols=[red+(1.0,),red+(.7,),blue+(1.0,),blue+(.7,)]

kmf = lifelines.KaplanMeierFitter()
df2test=braun.clinical_bigbets_df
i=0
for name,gdf in df2test.groupby(var):
    if re.search("WT",name):
        ls=':'
    else:
        ls='-'
    kmf.fit(gdf["os"], gdf["censOS"], label=name)
    kmf.plot(ax=a,ci_show=False,c=cols[i],linestyle=ls,
             show_censors=True, censor_styles={'ms': 5, 'marker': '+'})
    i+=1
# lg_lines=lg.get_lines()
# for j,ln in enumerate(a.get_lines()):
#     ln.set_color(cols[j])
#     lg_lines[j].set_color(cols[j])

handles, labels = a.get_legend_handles_labels()
new_labels=['High-BiG-BETS DDR Mut','High-BiG-BETS DDR WT','High-BiG-BETS DDR Mut','High-BiG-BETS DDR WT']
l=a.legend(loc=1,bbox_to_anchor=(.85,1.0),fontsize=14,
           frameon=False,handles=handles,labels=new_labels)
for i,text in enumerate(l.get_texts()):
    plt.setp(text, color = cols[i])
    
a.annotate(s='TMB-H',fontsize=14,xy=(.83,.925),xytext=(.86,.925),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.annotate(s='TMB-L',fontsize=14,xy=(.83,.825),xytext=(.86,.825),
       arrowprops=dict(arrowstyle='-[, widthB=1.1, lengthB=0', lw=1.0),
       xycoords='axes fraction',verticalalignment='center',transform=a.transAxes)

a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

a.set_xlabel("months",fontsize=20)
a.set_ylabel("overall survival",fontsize=20)

# a.set_title("Kaplan-Meier Curve by TMB + low TMB Assoc.DDR Genes",fontsize=18,fontweight='bold')
pval_df=bigbets.bipartite_helper_functions.get_os_stats(clust=clust,samp_df=braun.clinical_bigbets_df)
pval=pval_df['llr_pval'].values[0]
a.text(x=.85,y=.05,s="CPH pval={:.1e}".format(pval),horizontalalignment='center',
       fontsize=14,transform=a.transAxes)



a=plt.subplot2grid((nrows,ncols),(nrows1,0),rowspan=nrows-nrows1,colspan=1)
# a=plt.subplot(1,2,2)
# a.text(s='B)',fontsize=18,fontweight='bold',x=0.0,y=.95,transform=a.transAxes)
# a.text(s='B)',fontsize=18,fontweight='bold',x=-.07,y=1.0,transform=a.transAxes)

xlim_min=np.min(summary['coef']-1.96*summary['se(coef)'])
xlim_max=np.max(summary['coef']+1.96*summary['se(coef)'])

for i,ind in enumerate(summary.index):
    expcoef=summary.loc[ind,'exp(coef)']
    up=summary.loc[ind,'exp(coef) upper 95%']-expcoef
    low=expcoef-summary.loc[ind,'exp(coef) lower 95%']
    ebars=np.array([[low,up]]).T
    a.errorbar(x=[expcoef],alpha=.7,
               y=[summary.shape[0]-1-i],marker='s',color='k',uplims=True, lolims=True,
               xerr=ebars
#                xerr=[1.96*summary.loc[ind,'se(coef)'],
                    )

    
a.vlines(x=1.0,linestyle='--',alpha=.6,linewidth=1,color='k',
         ymin=0,ymax=summary.shape[0]-.9)

a.set_xscale('log')
a.set_xlim([.0000025,30])
a.spines['bottom'].set_position(('data', -.4))
a.spines['bottom'].set_bounds( 0.1,5)

a.spines['left'].set_visible(False)
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)
a.set_yticks([])
a.set_xticks([.1,1,5])
a.xaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
plt.minorticks_off()
a.set_ylim([-2,3])


# a.text(s="LLR pval={:.2e}".format(p_value),fontsize=18,
#        x=.2,y=.8,transform=a.transAxes)



axis_to_data = a.transAxes + a.transData.inverted()
data_to_axis = axis_to_data.inverted()

y=data_to_axis.transform((.1,summary.shape[0]-.55))[1]

print('y',y)
a.text(s="Covariate".format(p_value),fontsize=20,
       x=.01,y=y,transform=a.transAxes)

a.text(s="HR (95% CI)".format(p_value),fontsize=20,
       x=.375,y=y,transform=a.transAxes)

a.text(s="P-value".format(p_value),fontsize=20,
       x=.85,y=y,transform=a.transAxes)

a.hlines(y=y-.02,xmin=-2,xmax=50,color='k',transform=a.transAxes,linewidth=3,linestyle='-')
# a.hlines(y=y-.03,xmin=-1,xmax=2,transform=a.transAxes,linewidth=1,linestyle='-')

for i,ind in enumerate(summary.index):
    y=data_to_axis.transform((.1,summary.shape[0]-i-1.2))[1]
    print('y',y)
    if summary.loc[ind,'p']<.05:
        a.text(s="{}*".format(ind),fontsize=20,
       x=-.1,y=y,transform=a.transAxes)
    else:
        a.text(s=ind,fontsize=20,
           x=-.1,y=y,
           transform=a.transAxes)
    hrtext="{:.2f}  ({:.2f}-{:.2f})".format(*summary.loc[ind,['exp(coef)',
                                                         'exp(coef) lower 95%','exp(coef) upper 95%']])
    pvaltext="{:.2e}".format(*summary.loc[ind,['p']])
    a.text(s=hrtext,fontsize=20,
       x=.35,y=y,
           transform=a.transAxes)
    a.text(s=pvaltext,fontsize=20,
       x=.85,y=y,
           transform=a.transAxes)
    
    x1,y1=data_to_axis.transform((.01,summary.shape[0]-i*.9-1.5))
    x2,y2=data_to_axis.transform((.01,summary.shape[0]-i*.9-.8))
    

    if i%2==0:
        crect=patches.Rectangle((-.1,y1),width=1.2,height=y2-y1,transform=a.transAxes,fill=True,
                               alpha=.05,color='k',clip_on=False)
#         crect2=patches.Rectangle((x2,y1),width=1.1-x2,height=y2-y1,transform=a.transAxes,fill=True,
#                                alpha=.05,color='k')
        a.add_patch(crect)
#         a.add_patch(crect2)
        
    
    

# a.set_title("CPH Model Survival",fontsize=18,fontweight='bold')
# cph.plot(ax=a)
a.text(s="Hazard Ratio",fontsize=18,x=1.25,
       y=-1.1,
       horizontalalignment='center')

f.suptitle('Braun et al. 2020',fontsize=22,x=.5,y=.97,transform=f.transFigure)

f.subplots_adjust(top=.93,bottom=-.05,right=.95,left=.12,wspace=.0,hspace=1.5)
f.savefig(outfile,dpi=200)
plt.show()
# Out:
#                      coef  exp(coef)  se(coef)  coef lower 95%  \
# DDR_high_z_MUT   0.083737   1.087343  0.186749       -0.282284
# log(TMB)        -0.040311   0.960491  0.113309       -0.262392
# DDRhigh:highTMB  0.125580   1.133806  0.326441       -0.514232
#
#                  coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%  \
# DDR_high_z_MUT         0.449759              0.75406             1.567933
# log(TMB)               0.181770              0.76921             1.199339
# DDRhigh:highTMB        0.765393              0.59796             2.149839
#
#                         z         p  -log2(p)
# DDR_high_z_MUT   0.448395  0.653868  0.612928
# log(TMB)        -0.355760  0.722021  0.469888
# DDRhigh:highTMB  0.384696  0.700463  0.513619
# ...

# %% [markdown]
# ## ICB Response Analyses

# %%
#Response by low BIGBETS DDR genes
df_low=bigbets.bipartite_helper_functions.get_percents_bar_by_group(braun.clinical_bigbets_df,['high_TMB','DDR_low_z'],'binaryResponse')
outfile=os.path.join(supplements_dir,"R1_Figure_S5C_braun_response_by_low_zscore_mut_tmb.pdf")


plt.close()
f,a=plt.subplots(1,1,figsize=(4,5))

pivot=df_low.loc[:,['Response','group','percent']].pivot(index='group',columns='Response',values='percent')
pivot=pivot.loc[['TMB-L_WT','TMB-L_MUT','TMB-H_WT','TMB-H_MUT'],:]
stat,pval,_,_=stats.chi2_contingency(df_low.groupby(['group','Response'])['count'].max().unstack(fill_value=0))

ctab_false=df_low.groupby(['group','Response'])['count'].max().unstack().loc[['TMB-L_WT','TMB-L_MUT'],:]
ctab_true=df_low.groupby(['group','Response'])['count'].max().unstack().loc[['TMB-H_WT','TMB-H_MUT'],:]
s1,pval1=stats.fisher_exact(ctab_false,'less')
s2,pval2=stats.fisher_exact(ctab_true,'less')

a.bar(x=range(pivot.shape[0]),height=pivot['CR/PR'],color=blue)
a.set_ylim([0,1.2])
a.set_ylim([0,.8])
a.set_title("Low BiG-BETS DDR Pts\n(Braun 2020 RCC)",fontsize=18)


# a.text(x=.025,y=.85,s=r"p={:.2e}".format(pval1),
#        fontsize=16,transform=a.transAxes)
a.annotate(s='n.s',fontsize=18,xy=(.25,.32),xytext=(.25,.35),
           arrowprops=dict(arrowstyle='-[, widthB=1.5, lengthB=0', lw=1.0),
           xycoords='axes fraction',horizontalalignment='center',transform=a.transAxes)

a.annotate(s=r"n.s".format(pval2),fontsize=18,xy=(.75,.26),xytext=(.75,.295),
           arrowprops=dict(arrowstyle='-[, widthB=1.5, lengthB=0', lw=1.0),
           xycoords='axes fraction',horizontalalignment='center',transform=a.transAxes)

# a.text(x=.57,y=.85,s=r"p={:.2e}".format(pval2),
#        fontsize=16,transform=a.transAxes)

a.set_xlabel("")
a.set_ylabel("% response (CR/PR)",fontsize=18)

    
a.get_xaxis().set_visible(False)
scale=.8

a.text(s="TMB-L",x=.5,y=-.19*scale,fontsize=20,horizontalalignment='center')     
a.text(s="TMB-H",x=2.5,y=-.19*scale,fontsize=20,horizontalalignment='center') 

a.text(s="WT",x=0,y=-.07*scale,fontsize=20,horizontalalignment='center')     
a.text(s="MUT",x=1,y=-.07*scale,fontsize=20,horizontalalignment='center')
a.text(s="WT",x=2,y=-.07*scale,fontsize=20,horizontalalignment='center')     
a.text(s="MUT",x=3,y=-.07*scale,fontsize=20,horizontalalignment='center')

#tick marks 

# for i in range(4):
#     line = lines.Line2D(xdata=[i,i], ydata=[0*scale,-.03*scale],color='k', lw=2,
#                         linestyle='-', alpha=.8,clip_on=False)
#     a.add_line(line)
    
# for i in range(4):
#     line = lines.Line2D(xdata=[i,i], ydata=[-.067*scale,-.12*scale],color='k', lw=2,
#                         linestyle='-', alpha=.8,clip_on=False)
#     a.add_line(line)
    
for i in range(2):
    line = lines.Line2D(xdata=[i*2-.2,i*2+1.2], ydata=[-.1*scale,-.1*scale],color='k', lw=2,
                        linestyle='-', alpha=.8,clip_on=False)
    a.add_line(line)
# for i in range(2):
#     line = lines.Line2D(xdata=[i*2+.5,i*2+.5], ydata=[-.12*scale,-.15*scale],color='k', lw=2,
#                         linestyle='-', alpha=.8,clip_on=False)
#     a.add_line(line)
    
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

# l=a.legend(fontsize=18,bbox_to_anchor=(.6,.95),ncol=2,loc=10,
#           handletextpad=.4,columnspacing=.7,framealpha=1)
# l.set_visible(True)

f.subplots_adjust(top=.85,bottom=.18,right=.87,left=.21)
f.savefig(outfile,dpi=200)

plt.show()
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:28: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:32: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.

# %%
#Response by high BiGbets DDR 
df_high=bigbets.bipartite_helper_functions.get_percents_bar_by_group(braun.clinical_bigbets_df,['high_TMB','DDR_high_z'],'binaryResponse')
outfile=os.path.join(supplements_dir,"braun_response_by_high_zscore_mut_tmb.pdf")

plt.close()
f,a=plt.subplots(1,1,figsize=(4,5))

pivot=df_high.loc[:,['Response','group','percent']].pivot(index='group',columns='Response',values='percent')
pivot=pivot.loc[['TMB-L_WT','TMB-L_MUT','TMB-H_WT','TMB-H_MUT'],:]
stat,pval,_,_=stats.chi2_contingency(df_high.groupby(['group','Response'])['count'].max().unstack(fill_value=0))

ctab_false=df_high.groupby(['group','Response'])['count'].max().unstack().loc[['TMB-L_WT','TMB-L_MUT'],:]
ctab_true=df_high.groupby(['group','Response'])['count'].max().unstack().loc[['TMB-H_WT','TMB-H_MUT'],:]
s1,pval1=stats.fisher_exact(ctab_false,'less')
s2,pval2=stats.fisher_exact(ctab_true,'less')

a.bar(x=range(pivot.shape[0]),height=pivot['CR/PR'],color=blue)
a.set_ylim([0,1.2])
a.set_ylim([0,.8])
a.set_title("High BiG-BETS DDR Pts\n(Braun 2020 RCC)",fontsize=18)


# a.text(x=.025,y=.85,s=r"p={:.2e}".format(pval1),
#        fontsize=16,transform=a.transAxes)
a.annotate(s='n.s',fontsize=18,xy=(.25,.32),xytext=(.25,.35),
           arrowprops=dict(arrowstyle='-[, widthB=1.5, lengthB=0', lw=1.0),
           xycoords='axes fraction',horizontalalignment='center',transform=a.transAxes)

a.annotate(s=r"p={:.3f}".format(pval2),fontsize=18,xy=(.75,.26),xytext=(.75,.295),
           arrowprops=dict(arrowstyle='-[, widthB=1.5, lengthB=0', lw=1.0),
           xycoords='axes fraction',horizontalalignment='center',transform=a.transAxes)

# a.text(x=.57,y=.85,s=r"p={:.2e}".format(pval2),
#        fontsize=16,transform=a.transAxes)

a.set_xlabel("")
a.set_ylabel("% response (CR/PR)",fontsize=18)

    
a.get_xaxis().set_visible(False)
scale=.8

a.text(s="TMB-L",x=.5,y=-.1875*scale,fontsize=20,horizontalalignment='center')     
a.text(s="TMB-H",x=2.5,y=-.1875*scale,fontsize=20,horizontalalignment='center') 

a.text(s="WT",x=0,y=-.07*scale,fontsize=20,horizontalalignment='center')     
a.text(s="MUT",x=1,y=-.07*scale,fontsize=20,horizontalalignment='center')
a.text(s="WT",x=2,y=-.07*scale,fontsize=20,horizontalalignment='center')     
a.text(s="MUT",x=3,y=-.07*scale,fontsize=20,horizontalalignment='center')

#tick marks 

# for i in range(4):
#     line = lines.Line2D(xdata=[i,i], ydata=[0*scale,-.03*scale],color='k', lw=2,
#                         linestyle='-', alpha=.8,clip_on=False)
#     a.add_line(line)
    
# for i in range(4):
#     line = lines.Line2D(xdata=[i,i], ydata=[-.067*scale,-.12*scale],color='k', lw=2,
#                         linestyle='-', alpha=.8,clip_on=False)
#     a.add_line(line)
    
for i in range(2):
    line = lines.Line2D(xdata=[i*2-.2,i*2+1.2], ydata=[-.1*scale,-.1*scale],color='k', lw=2,
                        linestyle='-', alpha=.8,clip_on=False)
    a.add_line(line)
# for i in range(2):
#     line = lines.Line2D(xdata=[i*2+.5,i*2+.5], ydata=[-.12*scale,-.15*scale],color='k', lw=2,
#                         linestyle='-', alpha=.8,clip_on=False)
#     a.add_line(line)
    
a.spines['right'].set_visible(False)
a.spines['top'].set_visible(False)

# l=a.legend(fontsize=18,bbox_to_anchor=(.6,.95),ncol=2,loc=10,
#           handletextpad=.4,columnspacing=.7,framealpha=1)
# l.set_visible(True)

f.subplots_adjust(top=.85,bottom=.18,right=.87,left=.21)
f.savefig(outfile,dpi=200)

plt.show()
